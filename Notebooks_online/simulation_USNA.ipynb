# %%
import sys
sys.path.append('..')

# %%
from config_simulation import (
    simulation_linear_regression,
    simulation_logistic_regression,
    simulation_geometric_median,
    simulation_spherical_distribution,
    simulation_p_means,
    eval_covtype,
    n,
    N,
    nu_list,
    gamma_list,
)
from optimization_algorithms import USNA


optimizer_class = USNA
optimizer_list = [optimizer_class(gamma=gamma) for gamma in gamma_list]

# %%
simulation = simulation_linear_regression(optimizer_list=optimizer_list)
simulation.run_multiple_datasets(N=N, n=n)

# %%
simulation = simulation_logistic_regression(optimizer_list=optimizer_list)
simulation.run_multiple_datasets(N=N, n=n)

# %%
simulation = simulation_geometric_median(optimizer_list=optimizer_list)
simulation.run_multiple_datasets(N=N, n=n)

# %%
simulation = simulation_spherical_distribution(optimizer_list=optimizer_list)
simulation.run_multiple_datasets(N=N, n=n)

# %%
simulation = simulation_p_means(optimizer_list=optimizer_list)
simulation.run_multiple_datasets(N=N, n=n)

# %%
eval = eval_covtype(optimizer_list=optimizer_list)
_, _ = eval.run()
# Out:
# Optimizers:   0%|          | 0/6 [00:00<?, ?it/s]
# Data:   0%|          | 0/464809 [00:00<?, ?it/s]
# <style type="text/css">
# #T_65a87_row0_col0, #T_65a87_row1_col0 {
#   font-weight: bold;
# }
# </style>
# <table id="T_65a87">
#   <caption>Accuracy on covtype</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_65a87_level0_col0" class="col_heading level0 col0" >USNA γ=0.45</th>
#       <th id="T_65a87_level0_col1" class="col_heading level0 col1" >USNA γ=0.5</th>
#       <th id="T_65a87_level0_col2" class="col_heading level0 col2" >USNA γ=0.66</th>
#       <th id="T_65a87_level0_col3" class="col_heading level0 col3" >USNA γ=0.75</th>
#       <th id="T_65a87_level0_col4" class="col_heading level0 col4" >USNA γ=1.0</th>
#       <th id="T_65a87_level0_col5" class="col_heading level0 col5" >USNA γ=1.05</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_65a87_level0_row0" class="row_heading level0 row0" >Training Accuracy</th>
#       <td id="T_65a87_row0_col0" class="data row0 col0" >74.480000</td>
#       <td id="T_65a87_row0_col1" class="data row0 col1" >62.040000</td>
#       <td id="T_65a87_row0_col2" class="data row0 col2" >63.570000</td>
#       <td id="T_65a87_row0_col3" class="data row0 col3" >58.170000</td>
#       <td id="T_65a87_row0_col4" class="data row0 col4" >56.350000</td>
#       <td id="T_65a87_row0_col5" class="data row0 col5" >38.270000</td>
#     </tr>
#     <tr>
#       <th id="T_65a87_level0_row1" class="row_heading level0 row1" >Test Accuracy</th>
#       <td id="T_65a87_row1_col0" class="data row1 col0" >74.530000</td>
#       <td id="T_65a87_row1_col1" class="data row1 col1" >62.180000</td>
#       <td id="T_65a87_row1_col2" class="data row1 col2" >63.460000</td>
#       <td id="T_65a87_row1_col3" class="data row1 col3" >58.150000</td>
#       <td id="T_65a87_row1_col4" class="data row1 col4" >56.300000</td>
#       <td id="T_65a87_row1_col5" class="data row1 col5" >38.350000</td>
#     </tr>
#   </tbody>
# </table>
