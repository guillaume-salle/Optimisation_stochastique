# %%
import sys
sys.path.append('..')

# %%
from config_simulation import (
    simulation_linear_regression,
    simulation_logistic_regression,
    simulation_geometric_median,
    simulation_spherical_distribution,
    simulation_p_means,
    eval_covtype,
    n,
    N,
    nu_list,
    batch_size,
)
from algorithms_numpy_online import SGD

optimizer_class = SGD
optimizer_list = [optimizer_class(nu=nu) for nu in nu_list]
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[2], line 13
#       1 from config_simulation import (
#       2     simulation_linear_regression,
#       3     simulation_logistic_regression,
#    (...)
#      11     batch_size,
#      12 )
# ---> 13 from optimization_algorithms import SGD
#      15 optimizer_class = SGD
#      16 optimizer_list = [optimizer_class(nu=nu) for nu in nu_list]
#
# ModuleNotFoundError: No module named 'optimization_algorithms'

# %%
simulation = simulation_linear_regression(optimizer_list=optimizer_list)
simulation.run_multiple_datasets(N=N, n=n, batch_size=batch_size)

# %%
simulation = simulation_logistic_regression(optimizer_list=optimizer_list)
simulation.run_multiple_datasets(N=N, n=n, batch_size=batch_size)

# %%
simulation = simulation_geometric_median(optimizer_list=optimizer_list)
simulation.run_multiple_datasets(N=N, n=n, batch_size=batch_size)

# %%
simulation = simulation_spherical_distribution(optimizer_list=optimizer_list)
simulation.run_multiple_datasets(N=N, n=n, batch_size=batch_size)

# %%
simulation = simulation_p_means(optimizer_list=optimizer_list)
simulation.run_multiple_datasets(N=N, n=n, batch_size=batch_size)

# %%
eval = eval_covtype(optimizer_list=optimizer_list)
_, _ = eval.run(batch_size=batch_size)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[8], line 2
#       1 eval = eval_covtype(optimizer_list=optimizer_list)
# ----> 2 _, _ = eval.run()
#
# TypeError: Simulation.run() missing 1 required positional argument: 'batch_size'
