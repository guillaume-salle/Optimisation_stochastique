# %%
import sys
sys.path.append('..')

# %%
from config_simulation import (
    simulation_linear_regression,
    simulation_logistic_regression,
    simulation_geometric_median,
    simulation_spherical_distribution,
    simulation_p_means,
    eval_covtype,
    n,
    N,
    nu_list,
    gamma_list,
)
from optimization_algorithms import USNA


optimizer_class = USNA
optimizer_list = [
    optimizer_class(gamma=gamma, generate_Z="canonic") for gamma in gamma_list
]

# %%
simulation = simulation_linear_regression(optimizer_list=optimizer_list)
simulation.run_multiple_datasets(N=N, n=n)

# %%
simulation = simulation_logistic_regression(optimizer_list=optimizer_list)
simulation.run_multiple_datasets(N=N, n=n)

# %%
simulation = simulation_geometric_median(optimizer_list=optimizer_list)
simulation.run_multiple_datasets(N=N, n=n)

# %%
simulation = simulation_spherical_distribution(optimizer_list=optimizer_list)
simulation.run_multiple_datasets(N=N, n=n)

# %%
simulation = simulation_p_means(optimizer_list=optimizer_list)
simulation.run_multiple_datasets(N=N, n=n)

# %%
eval = eval_covtype(optimizer_list=optimizer_list)
_, _ = eval.run()
# Out:
# Optimizers:   0%|          | 0/6 [00:00<?, ?it/s]
# Data:   0%|          | 0/464809 [00:00<?, ?it/s]
# <style type="text/css">
# #T_fbf9d_row0_col0, #T_fbf9d_row1_col0 {
#   font-weight: bold;
# }
# </style>
# <table id="T_fbf9d">
#   <caption>Accuracy on covtype</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_fbf9d_level0_col0" class="col_heading level0 col0" >USNA γ=0.45 Z~canonic</th>
#       <th id="T_fbf9d_level0_col1" class="col_heading level0 col1" >USNA γ=0.5 Z~canonic</th>
#       <th id="T_fbf9d_level0_col2" class="col_heading level0 col2" >USNA γ=0.66 Z~canonic</th>
#       <th id="T_fbf9d_level0_col3" class="col_heading level0 col3" >USNA γ=0.75 Z~canonic</th>
#       <th id="T_fbf9d_level0_col4" class="col_heading level0 col4" >USNA γ=1.0 Z~canonic</th>
#       <th id="T_fbf9d_level0_col5" class="col_heading level0 col5" >USNA γ=1.05 Z~canonic</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_fbf9d_level0_row0" class="row_heading level0 row0" >Training Accuracy</th>
#       <td id="T_fbf9d_row0_col0" class="data row0 col0" >69.610000</td>
#       <td id="T_fbf9d_row0_col1" class="data row0 col1" >59.100000</td>
#       <td id="T_fbf9d_row0_col2" class="data row0 col2" >63.930000</td>
#       <td id="T_fbf9d_row0_col3" class="data row0 col3" >57.070000</td>
#       <td id="T_fbf9d_row0_col4" class="data row0 col4" >59.540000</td>
#       <td id="T_fbf9d_row0_col5" class="data row0 col5" >59.470000</td>
#     </tr>
#     <tr>
#       <th id="T_fbf9d_level0_row1" class="row_heading level0 row1" >Test Accuracy</th>
#       <td id="T_fbf9d_row1_col0" class="data row1 col0" >69.900000</td>
#       <td id="T_fbf9d_row1_col1" class="data row1 col1" >59.390000</td>
#       <td id="T_fbf9d_row1_col2" class="data row1 col2" >63.740000</td>
#       <td id="T_fbf9d_row1_col3" class="data row1 col3" >56.740000</td>
#       <td id="T_fbf9d_row1_col4" class="data row1 col4" >59.500000</td>
#       <td id="T_fbf9d_row1_col5" class="data row1 col5" >59.320000</td>
#     </tr>
#   </tbody>
# </table>
