# %%
import sys
sys.path.append('..')

# %%
from config_simulation import (
    algo,
    simulation_linear_regression,
    simulation_logistic_regression,
    simulation_geometric_median,
    simulation_spherical_distribution,
    simulation_p_means,
    eval_covtype,
    N,
    n,
)

from functools import partial
optimizer_list = [
    # WASGD
    partial(algo.SGD, averaged=True, lr_add_iter=10),

    # WAAdaGrad
    partial(algo.AdaGrad, averaged=True, lr_add_iter=10),
    
    # WASNA
    partial(algo.SNA, averaged=True, lr_add_iter=10),
    
    # UWASNA
    partial(algo.USNA, averaged=True, lr_add_iter=10, proj=True),
]

# %%
# N = 2
# n = 1000

# %%
simulation = simulation_linear_regression(optimizer_list=optimizer_list)
simulation.run_multiple_track_errors(N=N, n=n)

# %%
simulation.run_multiple_track_time(N=N, n=n)

# %%
simulation = simulation_logistic_regression(optimizer_list=optimizer_list)
simulation.run_multiple_track_errors(N=N, n=n)

# %%
simulation.run_multiple_track_time(N=N, n=n)

# %%
simulation = simulation_geometric_median(optimizer_list=optimizer_list)
simulation.run_multiple_track_errors(N=N, n=n)

# %%
simulation.run_multiple_track_time(N=N, n=n)
# Out:
#   0%|          | 0/20 [00:00<?, ?it/s]
# Optimizers:   0%|          | 0/4 [00:00<?, ?it/s]
# Data:   0%|          | 0/10000 [00:00<?, ?it/s]

# %%
simulation = simulation_spherical_distribution( optimizer_list=optimizer_list)
simulation.run_multiple_track_errors(N=N, n=n)

# %%
simulation.run_multiple_track_time(N=N, n=n)

# %%
simulation = simulation_p_means(optimizer_list=optimizer_list)
simulation.run_multiple_track_errors(N=N, n=n)

# %%
simulation.run_multiple_track_time(N=N, n=n)

# %%
eval = eval_covtype(optimizer_list=optimizer_list)
_, _ = eval.run_track_time()
# Out:
# Optimizers:   0%|          | 0/6 [00:00<?, ?it/s]
# Data:   0%|          | 0/464809 [00:00<?, ?it/s]
# <style type="text/css">
# #T_5e4d8_row0_col0, #T_5e4d8_row1_col2, #T_5e4d8_row1_col3, #T_5e4d8_row2_col2, #T_5e4d8_row2_col3 {
#   font-weight: bold;
# }
# </style>
# <table id="T_5e4d8">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_5e4d8_level0_col0" class="col_heading level0 col0" >WASGD α=0.67</th>
#       <th id="T_5e4d8_level0_col1" class="col_heading level0 col1" >WAAda α=0.67</th>
#       <th id="T_5e4d8_level0_col2" class="col_heading level0 col2" >SNA α=1.0 SM</th>
#       <th id="T_5e4d8_level0_col3" class="col_heading level0 col3" >SNA α=1.0 SM (1)</th>
#       <th id="T_5e4d8_level0_col4" class="col_heading level0 col4" >WASNA α=0.67 SM</th>
#       <th id="T_5e4d8_level0_col5" class="col_heading level0 col5" >UWASNA P α=0.67</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_5e4d8_level0_row0" class="row_heading level0 row0" >Execution Time</th>
#       <td id="T_5e4d8_row0_col0" class="data row0 col0" >5.421343</td>
#       <td id="T_5e4d8_row0_col1" class="data row0 col1" >6.286808</td>
#       <td id="T_5e4d8_row0_col2" class="data row0 col2" >9.645624</td>
#       <td id="T_5e4d8_row0_col3" class="data row0 col3" >9.649768</td>
#       <td id="T_5e4d8_row0_col4" class="data row0 col4" >10.778130</td>
#       <td id="T_5e4d8_row0_col5" class="data row0 col5" >14.113939</td>
#     </tr>
#     <tr>
#       <th id="T_5e4d8_level0_row1" class="row_heading level0 row1" >Training Accuracy</th>
#       <td id="T_5e4d8_row1_col0" class="data row1 col0" >0.729334</td>
#       <td id="T_5e4d8_row1_col1" class="data row1 col1" >0.761610</td>
#       <td id="T_5e4d8_row1_col2" class="data row1 col2" >0.765710</td>
#       <td id="T_5e4d8_row1_col3" class="data row1 col3" >0.765710</td>
#       <td id="T_5e4d8_row1_col4" class="data row1 col4" >0.721156</td>
#       <td id="T_5e4d8_row1_col5" class="data row1 col5" >0.728600</td>
#     </tr>
#     <tr>
#       <th id="T_5e4d8_level0_row2" class="row_heading level0 row2" >Test Accuracy</th>
#       <td id="T_5e4d8_row2_col0" class="data row2 col0" >0.731702</td>
#       <td id="T_5e4d8_row2_col1" class="data row2 col1" >0.763130</td>
#       <td id="T_5e4d8_row2_col2" class="data row2 col2" >0.767278</td>
#       <td id="T_5e4d8_row2_col3" class="data row2 col3" >0.767278</td>
#       <td id="T_5e4d8_row2_col4" class="data row2 col4" >0.724766</td>
#       <td id="T_5e4d8_row2_col5" class="data row2 col5" >0.732537</td>
#     </tr>
#   </tbody>
# </table>

# %%
eval = eval_covtype(optimizer_list=optimizer_list)
_, _ = eval.run_track_time()
# Out:
# Optimizers:   0%|          | 0/6 [00:00<?, ?it/s]
# Data:   0%|          | 0/464809 [00:00<?, ?it/s]
# <style type="text/css">
# #T_99bd5_row0_col0, #T_99bd5_row1_col2, #T_99bd5_row1_col3, #T_99bd5_row2_col2, #T_99bd5_row2_col3 {
#   font-weight: bold;
# }
# </style>
# <table id="T_99bd5">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_99bd5_level0_col0" class="col_heading level0 col0" >WASGD α=0.67</th>
#       <th id="T_99bd5_level0_col1" class="col_heading level0 col1" >WAAda α=0.67</th>
#       <th id="T_99bd5_level0_col2" class="col_heading level0 col2" >SNA α=1.0 SM</th>
#       <th id="T_99bd5_level0_col3" class="col_heading level0 col3" >SNA α=1.0 SM (1)</th>
#       <th id="T_99bd5_level0_col4" class="col_heading level0 col4" >WASNA α=0.67 SM</th>
#       <th id="T_99bd5_level0_col5" class="col_heading level0 col5" >UWASNA P α=0.67</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_99bd5_level0_row0" class="row_heading level0 row0" >Execution Time</th>
#       <td id="T_99bd5_row0_col0" class="data row0 col0" >5.467511</td>
#       <td id="T_99bd5_row0_col1" class="data row0 col1" >6.176456</td>
#       <td id="T_99bd5_row0_col2" class="data row0 col2" >9.667066</td>
#       <td id="T_99bd5_row0_col3" class="data row0 col3" >9.675729</td>
#       <td id="T_99bd5_row0_col4" class="data row0 col4" >10.834417</td>
#       <td id="T_99bd5_row0_col5" class="data row0 col5" >14.113138</td>
#     </tr>
#     <tr>
#       <th id="T_99bd5_level0_row1" class="row_heading level0 row1" >Training Accuracy</th>
#       <td id="T_99bd5_row1_col0" class="data row1 col0" >0.729334</td>
#       <td id="T_99bd5_row1_col1" class="data row1 col1" >0.761610</td>
#       <td id="T_99bd5_row1_col2" class="data row1 col2" >0.765710</td>
#       <td id="T_99bd5_row1_col3" class="data row1 col3" >0.765710</td>
#       <td id="T_99bd5_row1_col4" class="data row1 col4" >0.721156</td>
#       <td id="T_99bd5_row1_col5" class="data row1 col5" >0.725530</td>
#     </tr>
#     <tr>
#       <th id="T_99bd5_level0_row2" class="row_heading level0 row2" >Test Accuracy</th>
#       <td id="T_99bd5_row2_col0" class="data row2 col0" >0.731702</td>
#       <td id="T_99bd5_row2_col1" class="data row2 col1" >0.763130</td>
#       <td id="T_99bd5_row2_col2" class="data row2 col2" >0.767278</td>
#       <td id="T_99bd5_row2_col3" class="data row2 col3" >0.767278</td>
#       <td id="T_99bd5_row2_col4" class="data row2 col4" >0.724766</td>
#       <td id="T_99bd5_row2_col5" class="data row2 col5" >0.728484</td>
#     </tr>
#   </tbody>
# </table>
