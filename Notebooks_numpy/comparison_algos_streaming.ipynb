# %%
import sys
sys.path.append('..')

# %%
from config_simulation import (
    algo,
    simulation_linear_regression,
    simulation_logistic_regression,
    simulation_geometric_median,
    simulation_spherical_distribution,
    simulation_p_means,
    eval_covtype,
    N,
    n,
)

from functools import partial
optimizer_list = [
    # WASGD
    partial(algo.SGD, averaged=True, lr_add_iter=10),

    # WAAdaGrad
    partial(algo.AdaGrad, averaged=True, lr_add_iter=10),
    
    # WASNA
    partial(algo.SNA, averaged=True, lr_add_iter=10),
    
    # UWASNA
    partial(algo.USNA, averaged=True, lr_add_iter=10, proj=True),

    # Streaming WASNA and UWASNA
    partial(algo.SNA, averaged=True, lr_add_iter=10, batch_size_power=1),
    partial(algo.USNA, averaged=True, lr_add_iter=10, proj=True, batch_size_power=1),
]

# %%
# N = 2
# n = 1000

# %%
simulation = simulation_linear_regression(optimizer_list=optimizer_list)
simulation.run_multiple_track_errors(N=N, n=n)

# %%
simulation.run_multiple_track_time(N=N, n=n)

# %%
simulation = simulation_logistic_regression(optimizer_list=optimizer_list)
simulation.run_multiple_track_errors(N=N, n=n)

# %%
simulation.run_multiple_track_time(N=N, n=n)

# %%
simulation = simulation_geometric_median(optimizer_list=optimizer_list)
simulation.run_multiple_track_errors(N=N, n=n)

# %%
simulation.run_multiple_track_time(N=N, n=n)

# %%
simulation = simulation_spherical_distribution( optimizer_list=optimizer_list)
simulation.run_multiple_track_errors(N=N, n=n)
# Out:
#   0%|          | 0/20 [00:00<?, ?it/s]
# Optimizers:   0%|          | 0/5 [00:00<?, ?it/s]
# Data:   0%|          | 0/10000 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# LinAlgError                               Traceback (most recent call last)
# Cell In[10], line 2
#       1 simulation = simulation_spherical_distribution( optimizer_list=optimizer_list)
# ----> 2 simulation.run_multiple_track_errors(N=N, n=n)
#
# File ~/Optimisation_stochastique/Notebooks_numpy_online/../simulation/simulation.py:375, in Simulation.run_multiple_track_errors(self, N, n, eval_time)
#     372 self.generate_initial_param(variance=variance)
#     374 # Run the experiment for each optimizer
# --> 375 param_errors, matrix_errors = self.run_track_errors(
#     376     pbars=[optimizer_pbar, data_pbar]
#     377 )
#     379 # Average the errors over the runs
#     380 for name, errors in param_errors.items():
#
# File ~/Optimisation_stochastique/Notebooks_numpy_online/../simulation/simulation.py:205, in Simulation.run_track_errors(self, pbars)
#     203 # Run the optimizer on the dataset
#     204 for data in data_loader:
# --> 205     optimizer.step(data)
#     206     n += batch_size
#     207     self.logging_estimation_error(param_errors, matrix_errors, optimizer, n)
#
# File ~/Optimisation_stochastique/Notebooks_numpy_online/../algorithms_numpy/SNA.py:113, in SNA.step(self, data)
#     111     self.param_not_averaged -= learning_rate * self.hessian_inv @ grad
#     112 else:  # faster and more stable, no need to compute the whole inverse
# --> 113     self.param_not_averaged -= learning_rate * np.linalg.solve(self.hessian_bar, grad)
#     115 if self.averaged:
#     116     self.update_averaged_param()
#
# File ~/AppImage/miniconda3/envs/env/lib/python3.13/site-packages/numpy/linalg/_linalg.py:410, in solve(a, b)
#     407 signature = 'DD->D' if isComplexType(t) else 'dd->d'
#     408 with errstate(call=_raise_linalgerror_singular, invalid='call',
#     409               over='ignore', divide='ignore', under='ignore'):
# --> 410     r = gufunc(a, b, signature=signature)
#     412 return wrap(r.astype(result_t, copy=False))
#
# File ~/AppImage/miniconda3/envs/env/lib/python3.13/site-packages/numpy/linalg/_linalg.py:104, in _raise_linalgerror_singular(err, flag)
#     103 def _raise_linalgerror_singular(err, flag):
# --> 104     raise LinAlgError("Singular matrix")
#
# LinAlgError: Singular matrix

# %%
simulation.run_multiple_track_time(N=N, n=n)

# %%
simulation = simulation_p_means(optimizer_list=optimizer_list)
simulation.run_multiple_track_errors(N=N, n=n)

# %%
simulation.run_multiple_track_time(N=N, n=n)

# %%
eval = eval_covtype(optimizer_list=optimizer_list)
_, _ = eval.run_track_time()
# Out:
# Optimizers:   0%|          | 0/3 [00:00<?, ?it/s]
# Data:   0%|          | 0/464809 [00:00<?, ?it/s]
# <style type="text/css">
# #T_525f5_row0_col0, #T_525f5_row1_col1, #T_525f5_row2_col1 {
#   font-weight: bold;
# }
# </style>
# <table id="T_525f5">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_525f5_level0_col0" class="col_heading level0 col0" >WASGD α=0.67</th>
#       <th id="T_525f5_level0_col1" class="col_heading level0 col1" >SNA α=1.0 SM</th>
#       <th id="T_525f5_level0_col2" class="col_heading level0 col2" >WASNA α=0.67 SM</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_525f5_level0_row0" class="row_heading level0 row0" >Execution Time</th>
#       <td id="T_525f5_row0_col0" class="data row0 col0" >5.387938</td>
#       <td id="T_525f5_row0_col1" class="data row0 col1" >9.554794</td>
#       <td id="T_525f5_row0_col2" class="data row0 col2" >10.596660</td>
#     </tr>
#     <tr>
#       <th id="T_525f5_level0_row1" class="row_heading level0 row1" >Training Accuracy</th>
#       <td id="T_525f5_row1_col0" class="data row1 col0" >0.729334</td>
#       <td id="T_525f5_row1_col1" class="data row1 col1" >0.765710</td>
#       <td id="T_525f5_row1_col2" class="data row1 col2" >0.721156</td>
#     </tr>
#     <tr>
#       <th id="T_525f5_level0_row2" class="row_heading level0 row2" >Test Accuracy</th>
#       <td id="T_525f5_row2_col0" class="data row2 col0" >0.731702</td>
#       <td id="T_525f5_row2_col1" class="data row2 col1" >0.767278</td>
#       <td id="T_525f5_row2_col2" class="data row2 col2" >0.724766</td>
#     </tr>
#   </tbody>
# </table>

# %%
eval = eval_covtype(optimizer_list=optimizer_list)
_, _ = eval.run_track_time()
# Out:
# Optimizers:   0%|          | 0/3 [00:00<?, ?it/s]
# Data:   0%|          | 0/464809 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[15], line 2
#       1 eval = eval_covtype(optimizer_list=optimizer_list)
# ----> 2 _, _ = eval.run_track_time()
#
# File ~/Optimisation_stochastique/Notebooks_numpy_online/../simulation/simulation.py:278, in Simulation.run_track_time(self, pbars)
#     276 for data in data_loader:
#     277     optimizer.step(data)
# --> 278     data_pbar.update(batch_size)
#     280 time_end = time.time()
#     281 execution_times[optimizer.name] = time_end - time_start
#
# File ~/AppImage/miniconda3/envs/env/lib/python3.13/site-packages/tqdm/notebook.py:260, in tqdm_notebook.update(self, n)
#     256         raise
#     257     # NB: don't `finally: close()`
#     258     # since this could be a shared bar which the user will `reset()`
# --> 260 def update(self, n=1):
#     261     try:
#     262         return super().update(n=n)
#
# KeyboardInterrupt:
