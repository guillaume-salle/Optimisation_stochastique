# %%
import sys
sys.path.append('../..')

# %%
from config_simulation import (
    algo,
    simulation_linear_regression,
    simulation_linear_regression_toeplitz,
    simulation_linear_regression_toeplitz_diag,
    simulation_logistic_regression,
    simulation_logistic_regression_toeplitz,
    simulation_logistic_regression_toeplitz_diag,
    simulation_geometric_median,
    simulation_p_means,
    eval_covtype,
    N,
    n,
)

from functools import partial
mult=False
optimizer_list = [
    # # WASGD
    # partial(algo.SGD, averaged=True),

    # WAAdaGrad
    partial(algo.AdaGrad, averaged=True),
    partial(algo.AdaGrad, averaged=False, true_ada=True),
    partial(algo.AdaGrad, averaged=True, true_ada=True),
    
    # # WASNA
    # partial(algo.SNA, averaged=True),
    # partial(algo.SNA, averaged=True, compute_inverse=True),
    
    # # UWASNA
    # partial(algo.USNA, averaged=True, proj=True),

    # # # Streaming WASNA and UWASNA
    # partial(algo.SGD, averaged=True, mini_batch_power=1, multiply_lr_const=mult),
    # partial(algo.AdaGrad, averaged=True, mini_batch_power=1, multiply_lr_const =mult),
    # partial(algo.SNA, averaged=True, mini_batch_power=1, multiply_lr_const=mult),
    # partial(algo.USNA, averaged=True, proj=True, mini_batch_power=1, multiply_lr_const=mult),
]

# %%
# N = 2
# n = 1000

# %%
simulation = simulation_linear_regression(optimizer_list=optimizer_list)
simulation.run_multiple_track_errors(N=N, n=n)
# Out:
#   0%|          | 0/20 [00:00<?, ?it/s]
# Optimizers:   0%|          | 0/3 [00:00<?, ?it/s]
# Data:   0%|          | 0/100000 [00:00<?, ?it/s]

# %%
simulation.run_multiple_track_time(N=N, n=n)
# Out:
#   0%|          | 0/20 [00:00<?, ?it/s]
# Optimizers:   0%|          | 0/3 [00:00<?, ?it/s]
# Data:   0%|          | 0/100000 [00:00<?, ?it/s]

# %%
simulation = simulation_linear_regression_toeplitz(optimizer_list=optimizer_list)
simulation.run_multiple_track_errors(N=N, n=n)
# Out:
#   0%|          | 0/20 [00:00<?, ?it/s]
# Optimizers:   0%|          | 0/3 [00:00<?, ?it/s]
# Data:   0%|          | 0/100000 [00:00<?, ?it/s]

# %%
simulation.run_multiple_track_time(N=N, n=n)
# Out:
#   0%|          | 0/20 [00:00<?, ?it/s]
# Optimizers:   0%|          | 0/3 [00:00<?, ?it/s]
# Data:   0%|          | 0/100000 [00:00<?, ?it/s]

# %%
simulation = simulation_linear_regression_toeplitz_diag(optimizer_list=optimizer_list)
simulation.run_multiple_track_errors(N=N, n=n)
# Out:
#   0%|          | 0/20 [00:00<?, ?it/s]
# Optimizers:   0%|          | 0/3 [00:00<?, ?it/s]
# Data:   0%|          | 0/100000 [00:00<?, ?it/s]

# %%
simulation.run_multiple_track_time(N=N, n=n)
# Out:
#   0%|          | 0/20 [00:00<?, ?it/s]
# Optimizers:   0%|          | 0/3 [00:00<?, ?it/s]
# Data:   0%|          | 0/100000 [00:00<?, ?it/s]

# %%
simulation = simulation_logistic_regression(optimizer_list=optimizer_list)
simulation.run_multiple_track_errors(N=N, n=n)
# Out:
#   0%|          | 0/20 [00:00<?, ?it/s]
# Optimizers:   0%|          | 0/3 [00:00<?, ?it/s]
# Data:   0%|          | 0/100000 [00:00<?, ?it/s]

# %%
simulation.run_multiple_track_time(N=N, n=n)
# Out:
#   0%|          | 0/20 [00:00<?, ?it/s]
# Optimizers:   0%|          | 0/3 [00:00<?, ?it/s]
# Data:   0%|          | 0/100000 [00:00<?, ?it/s]

# %%
simulation = simulation_logistic_regression_toeplitz(optimizer_list=optimizer_list)
simulation.run_multiple_track_errors(N=N, n=n)
# Out:
#   0%|          | 0/20 [00:00<?, ?it/s]
# Optimizers:   0%|          | 0/3 [00:00<?, ?it/s]
# Data:   0%|          | 0/100000 [00:00<?, ?it/s]

# %%
simulation.run_multiple_track_time(N=N, n=n)
# Out:
#   0%|          | 0/20 [00:00<?, ?it/s]
# Optimizers:   0%|          | 0/3 [00:00<?, ?it/s]
# Data:   0%|          | 0/100000 [00:00<?, ?it/s]

# %%
simulation = simulation_logistic_regression_toeplitz_diag(optimizer_list=optimizer_list)
simulation.run_multiple_track_errors(N=N, n=n)
# Out:
#   0%|          | 0/20 [00:00<?, ?it/s]
# Optimizers:   0%|          | 0/3 [00:00<?, ?it/s]
# Data:   0%|          | 0/100000 [00:00<?, ?it/s]

# %%
simulation.run_multiple_track_time(N=N, n=n)
# Out:
#   0%|          | 0/20 [00:00<?, ?it/s]
# Optimizers:   0%|          | 0/3 [00:00<?, ?it/s]
# Data:   0%|          | 0/100000 [00:00<?, ?it/s]

# %%
simulation = simulation_geometric_median(optimizer_list=optimizer_list)
simulation.run_multiple_track_errors(N=N, n=n)
# Out:
#   0%|          | 0/20 [00:00<?, ?it/s]
# Optimizers:   0%|          | 0/3 [00:00<?, ?it/s]
# Data:   0%|          | 0/100000 [00:00<?, ?it/s]

# %%
simulation.run_multiple_track_time(N=N, n=n)
# Out:
#   0%|          | 0/20 [00:00<?, ?it/s]
# Optimizers:   0%|          | 0/3 [00:00<?, ?it/s]
# Data:   0%|          | 0/100000 [00:00<?, ?it/s]

# %%
simulation = simulation_p_means(optimizer_list=optimizer_list)
simulation.run_multiple_track_errors(N=N, n=n)
# Out:
#   0%|          | 0/20 [00:00<?, ?it/s]
# Optimizers:   0%|          | 0/3 [00:00<?, ?it/s]
# Data:   0%|          | 0/100000 [00:00<?, ?it/s]

# %%
simulation.run_multiple_track_time(N=N, n=n)
# Out:
#   0%|          | 0/20 [00:00<?, ?it/s]
# Optimizers:   0%|          | 0/3 [00:00<?, ?it/s]
# Data:   0%|          | 0/100000 [00:00<?, ?it/s]

# %%
eval = eval_covtype(optimizer_list=optimizer_list)
_, _ = eval.run_track_time()
# Out:
# Optimizers:   0%|          | 0/3 [00:00<?, ?it/s]
# Data:   0%|          | 0/464809 [00:00<?, ?it/s]
# <style type="text/css">
# #T_ea042_row0_col1, #T_ea042_row1_col0, #T_ea042_row2_col0 {
#   font-weight: bold;
# }
# </style>
# <table id="T_ea042">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_ea042_level0_col0" class="col_heading level0 col0" >AAda α=0.67</th>
#       <th id="T_ea042_level0_col1" class="col_heading level0 col1" >Ada T α=1.0</th>
#       <th id="T_ea042_level0_col2" class="col_heading level0 col2" >AAda T α=0.67</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_ea042_level0_row0" class="row_heading level0 row0" >Execution Time</th>
#       <td id="T_ea042_row0_col0" class="data row0 col0" >6.582252</td>
#       <td id="T_ea042_row0_col1" class="data row0 col1" >5.128397</td>
#       <td id="T_ea042_row0_col2" class="data row0 col2" >6.229233</td>
#     </tr>
#     <tr>
#       <th id="T_ea042_level0_row1" class="row_heading level0 row1" >Training Accuracy</th>
#       <td id="T_ea042_row1_col0" class="data row1 col0" >0.761403</td>
#       <td id="T_ea042_row1_col1" class="data row1 col1" >0.753533</td>
#       <td id="T_ea042_row1_col2" class="data row1 col2" >0.759219</td>
#     </tr>
#     <tr>
#       <th id="T_ea042_level0_row2" class="row_heading level0 row2" >Test Accuracy</th>
#       <td id="T_ea042_row2_col0" class="data row2 col0" >0.762984</td>
#       <td id="T_ea042_row2_col1" class="data row2 col1" >0.755084</td>
#       <td id="T_ea042_row2_col2" class="data row2 col2" >0.760609</td>
#     </tr>
#   </tbody>
# </table>
