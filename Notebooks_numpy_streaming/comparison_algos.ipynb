# %%
import sys
sys.path.append('..')

# %%
from config_simulation import (
    algo,
    simulation_linear_regression,
    simulation_logistic_regression,
    simulation_geometric_median,
    simulation_spherical_distribution,
    simulation_p_means,
    eval_covtype,
    N,
    n,
)

from functools import partial
mult=False
optimizer_list = [
    # # WASGD
    partial(algo.SGD, averaged=True),

    # # WAAdaGrad
    partial(algo.AdaGrad, averaged=True),
    
    # WASNA
    partial(algo.SNA, averaged=True),
    
    # UWASNA
    partial(algo.USNA, averaged=True, proj=True),

    # # Streaming WASNA and UWASNA
    partial(algo.SGD, averaged=True, batch_size_power=1, multiply_lr_const=mult),
    partial(algo.AdaGrad, averaged=True, batch_size_power=1, multiply_lr_const =mult),
    partial(algo.SNA, averaged=True, batch_size_power=1, multiply_lr_const=mult),
    partial(algo.USNA, averaged=True, proj=True, batch_size_power=1, multiply_lr_const=mult),
]

# %%
# N = 2
# n = 1000
N = 10

# %%
simulation = simulation_linear_regression(optimizer_list=optimizer_list)
simulation.run_multiple_track_errors(N=N, n=n)
# Out:
#   0%|          | 0/10 [00:00<?, ?it/s]
# Optimizers:   0%|          | 0/8 [00:00<?, ?it/s]
# Data:   0%|          | 0/10000 [00:00<?, ?it/s]

# %%
simulation.run_multiple_track_time(N=N, n=n)
# Out:
#   0%|          | 0/10 [00:00<?, ?it/s]
# Optimizers:   0%|          | 0/8 [00:00<?, ?it/s]
# Data:   0%|          | 0/10000 [00:00<?, ?it/s]

# %%
simulation = simulation_logistic_regression(optimizer_list=optimizer_list)
simulation.run_multiple_track_errors(N=N, n=n)
# Out:
#   0%|          | 0/10 [00:00<?, ?it/s]
# Optimizers:   0%|          | 0/8 [00:00<?, ?it/s]
# Data:   0%|          | 0/10000 [00:00<?, ?it/s]

# %%
simulation.run_multiple_track_time(N=N, n=n)
# Out:
#   0%|          | 0/10 [00:00<?, ?it/s]
# Optimizers:   0%|          | 0/8 [00:00<?, ?it/s]
# Data:   0%|          | 0/10000 [00:00<?, ?it/s]

# %%
simulation = simulation_geometric_median(optimizer_list=optimizer_list)
simulation.run_multiple_track_errors(N=N, n=n)
# Out:
#   0%|          | 0/10 [00:00<?, ?it/s]
# Optimizers:   0%|          | 0/8 [00:00<?, ?it/s]
# Data:   0%|          | 0/10000 [00:00<?, ?it/s]

# %%
simulation.run_multiple_track_time(N=N, n=n)
# Out:
#   0%|          | 0/10 [00:00<?, ?it/s]
# Optimizers:   0%|          | 0/8 [00:00<?, ?it/s]
# Data:   0%|          | 0/10000 [00:00<?, ?it/s]

# %%
simulation = simulation_spherical_distribution( optimizer_list=optimizer_list)
simulation.run_multiple_track_errors(N=N, n=n)
# Out:
#   0%|          | 0/10 [00:00<?, ?it/s]
# Optimizers:   0%|          | 0/8 [00:00<?, ?it/s]
# Data:   0%|          | 0/10000 [00:00<?, ?it/s]

# %%
simulation.run_multiple_track_time(N=N, n=n)
# Out:
#   0%|          | 0/10 [00:00<?, ?it/s]
# Optimizers:   0%|          | 0/8 [00:00<?, ?it/s]
# Data:   0%|          | 0/10000 [00:00<?, ?it/s]

# %%
simulation = simulation_p_means(optimizer_list=optimizer_list)
simulation.run_multiple_track_errors(N=N, n=n)
# Out:
#   0%|          | 0/10 [00:00<?, ?it/s]
# Optimizers:   0%|          | 0/8 [00:00<?, ?it/s]
# Data:   0%|          | 0/10000 [00:00<?, ?it/s]

# %%
simulation.run_multiple_track_time(N=N, n=n)
# Out:
#   0%|          | 0/10 [00:00<?, ?it/s]
# Optimizers:   0%|          | 0/8 [00:00<?, ?it/s]
# Data:   0%|          | 0/10000 [00:00<?, ?it/s]

# %%
eval = eval_covtype(optimizer_list=optimizer_list)
_, _ = eval.run_track_time()
# Out:
# Optimizers:   0%|          | 0/8 [00:00<?, ?it/s]
# Data:   0%|          | 0/464809 [00:00<?, ?it/s]
# <style type="text/css">
# #T_da71b_row0_col5, #T_da71b_row1_col6, #T_da71b_row2_col6 {
#   font-weight: bold;
# }
# </style>
# <table id="T_da71b">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_da71b_level0_col0" class="col_heading level0 col0" >ASGD α=None</th>
#       <th id="T_da71b_level0_col1" class="col_heading level0 col1" >WAAda α=None c_α=None</th>
#       <th id="T_da71b_level0_col2" class="col_heading level0 col2" >ASNA α=None</th>
#       <th id="T_da71b_level0_col3" class="col_heading level0 col3" >AUSNA P α=None</th>
#       <th id="T_da71b_level0_col4" class="col_heading level0 col4" >SASGD α=None</th>
#       <th id="T_da71b_level0_col5" class="col_heading level0 col5" >SWAAda α=None c_α=None</th>
#       <th id="T_da71b_level0_col6" class="col_heading level0 col6" >SASNA α=None</th>
#       <th id="T_da71b_level0_col7" class="col_heading level0 col7" >SAUSNA P α=None</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_da71b_level0_row0" class="row_heading level0 row0" >Execution Time</th>
#       <td id="T_da71b_row0_col0" class="data row0 col0" >6.047004</td>
#       <td id="T_da71b_row0_col1" class="data row0 col1" >6.831683</td>
#       <td id="T_da71b_row0_col2" class="data row0 col2" >23.079012</td>
#       <td id="T_da71b_row0_col3" class="data row0 col3" >18.179391</td>
#       <td id="T_da71b_row0_col4" class="data row0 col4" >0.178062</td>
#       <td id="T_da71b_row0_col5" class="data row0 col5" >0.170253</td>
#       <td id="T_da71b_row0_col6" class="data row0 col6" >2.599479</td>
#       <td id="T_da71b_row0_col7" class="data row0 col7" >0.389401</td>
#     </tr>
#     <tr>
#       <th id="T_da71b_level0_row1" class="row_heading level0 row1" >Training Accuracy</th>
#       <td id="T_da71b_row1_col0" class="data row1 col0" >0.729190</td>
#       <td id="T_da71b_row1_col1" class="data row1 col1" >0.761289</td>
#       <td id="T_da71b_row1_col2" class="data row1 col2" >0.714259</td>
#       <td id="T_da71b_row1_col3" class="data row1 col3" >0.725145</td>
#       <td id="T_da71b_row1_col4" class="data row1 col4" >0.664174</td>
#       <td id="T_da71b_row1_col5" class="data row1 col5" >0.747894</td>
#       <td id="T_da71b_row1_col6" class="data row1 col6" >0.764056</td>
#       <td id="T_da71b_row1_col7" class="data row1 col7" >0.651055</td>
#     </tr>
#     <tr>
#       <th id="T_da71b_level0_row2" class="row_heading level0 row2" >Test Accuracy</th>
#       <td id="T_da71b_row2_col0" class="data row2 col0" >0.731694</td>
#       <td id="T_da71b_row2_col1" class="data row2 col1" >0.763130</td>
#       <td id="T_da71b_row2_col2" class="data row2 col2" >0.717047</td>
#       <td id="T_da71b_row2_col3" class="data row2 col3" >0.728234</td>
#       <td id="T_da71b_row2_col4" class="data row2 col4" >0.666936</td>
#       <td id="T_da71b_row2_col5" class="data row2 col5" >0.750463</td>
#       <td id="T_da71b_row2_col6" class="data row2 col6" >0.766030</td>
#       <td id="T_da71b_row2_col7" class="data row2 col7" >0.652591</td>
#     </tr>
#   </tbody>
# </table>

# %%
eval = eval_covtype(optimizer_list=optimizer_list)
_, _ = eval.run_track_time()
# Out:
# Optimizers:   0%|          | 0/8 [00:00<?, ?it/s]
# Data:   0%|          | 0/464809 [00:00<?, ?it/s]
# <style type="text/css">
# #T_0ae89_row0_col4, #T_0ae89_row1_col6, #T_0ae89_row2_col6 {
#   font-weight: bold;
# }
# </style>
# <table id="T_0ae89">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_0ae89_level0_col0" class="col_heading level0 col0" >ASGD α=None</th>
#       <th id="T_0ae89_level0_col1" class="col_heading level0 col1" >WAAda α=None c_α=None</th>
#       <th id="T_0ae89_level0_col2" class="col_heading level0 col2" >ASNA α=None</th>
#       <th id="T_0ae89_level0_col3" class="col_heading level0 col3" >AUSNA P α=None</th>
#       <th id="T_0ae89_level0_col4" class="col_heading level0 col4" >SASGD α=None</th>
#       <th id="T_0ae89_level0_col5" class="col_heading level0 col5" >SWAAda α=None c_α=None</th>
#       <th id="T_0ae89_level0_col6" class="col_heading level0 col6" >SASNA α=None</th>
#       <th id="T_0ae89_level0_col7" class="col_heading level0 col7" >SAUSNA P α=None</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_0ae89_level0_row0" class="row_heading level0 row0" >Execution Time</th>
#       <td id="T_0ae89_row0_col0" class="data row0 col0" >6.103940</td>
#       <td id="T_0ae89_row0_col1" class="data row0 col1" >6.926503</td>
#       <td id="T_0ae89_row0_col2" class="data row0 col2" >23.616312</td>
#       <td id="T_0ae89_row0_col3" class="data row0 col3" >18.617343</td>
#       <td id="T_0ae89_row0_col4" class="data row0 col4" >0.162293</td>
#       <td id="T_0ae89_row0_col5" class="data row0 col5" >0.167905</td>
#       <td id="T_0ae89_row0_col6" class="data row0 col6" >2.611096</td>
#       <td id="T_0ae89_row0_col7" class="data row0 col7" >0.391063</td>
#     </tr>
#     <tr>
#       <th id="T_0ae89_level0_row1" class="row_heading level0 row1" >Training Accuracy</th>
#       <td id="T_0ae89_row1_col0" class="data row1 col0" >0.729190</td>
#       <td id="T_0ae89_row1_col1" class="data row1 col1" >0.761289</td>
#       <td id="T_0ae89_row1_col2" class="data row1 col2" >0.714259</td>
#       <td id="T_0ae89_row1_col3" class="data row1 col3" >0.725242</td>
#       <td id="T_0ae89_row1_col4" class="data row1 col4" >0.664174</td>
#       <td id="T_0ae89_row1_col5" class="data row1 col5" >0.747894</td>
#       <td id="T_0ae89_row1_col6" class="data row1 col6" >0.764056</td>
#       <td id="T_0ae89_row1_col7" class="data row1 col7" >0.651162</td>
#     </tr>
#     <tr>
#       <th id="T_0ae89_level0_row2" class="row_heading level0 row2" >Test Accuracy</th>
#       <td id="T_0ae89_row2_col0" class="data row2 col0" >0.731694</td>
#       <td id="T_0ae89_row2_col1" class="data row2 col1" >0.763130</td>
#       <td id="T_0ae89_row2_col2" class="data row2 col2" >0.717047</td>
#       <td id="T_0ae89_row2_col3" class="data row2 col3" >0.728415</td>
#       <td id="T_0ae89_row2_col4" class="data row2 col4" >0.666936</td>
#       <td id="T_0ae89_row2_col5" class="data row2 col5" >0.750463</td>
#       <td id="T_0ae89_row2_col6" class="data row2 col6" >0.766030</td>
#       <td id="T_0ae89_row2_col7" class="data row2 col7" >0.652823</td>
#     </tr>
#   </tbody>
# </table>
