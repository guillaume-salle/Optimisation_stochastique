# %%
import sys
sys.path.append('..')

# %%
from config_simulation import (
    algo,
    simulation_linear_regression,
    simulation_linear_regression_toeplitz,
    simulation_linear_regression_toeplitz_diag,
    simulation_logistic_regression,
    simulation_logistic_regression_toeplitz,
    simulation_logistic_regression_toeplitz_diag,
    simulation_geometric_median,
    simulation_p_means,
    eval_covtype,
    N,
    n,
)

from functools import partial
mult=True
optimizer_list = [
    # WASGD
    partial(algo.SGD, averaged=True),

    # WAAdaGrad
    partial(algo.AdaGrad, averaged=True, true_ada=True),
    
    # WASNA
    partial(algo.SNA, averaged=True),
    
    # UWASNA
    partial(algo.USNA, averaged=True, proj=True),

    # # Streaming WASNA and UWASNA
    partial(algo.SGD, averaged=True, mini_batch_power=1, multiply_lr=mult),
    partial(algo.AdaGrad, averaged=True, true_ada=True, mini_batch_power=1, multiply_lr =mult),
    partial(algo.SNA, averaged=True, mini_batch_power=1, multiply_lr=mult),
    partial(algo.USNA, averaged=True, proj=True, mini_batch_power=1, multiply_lr=mult),
]

# %%
# N = 2
# n = 1000

# %%
simulation = simulation_linear_regression(optimizer_list=optimizer_list)
simulation.run_multiple_track_errors(N=N, n=n)
# Out:
#   0%|          | 0/10 [00:00<?, ?it/s]
# Optimizers:   0%|          | 0/8 [00:00<?, ?it/s]
# Data:   0%|          | 0/10000 [00:00<?, ?it/s]

# %%
simulation.run_multiple_track_time(N=N, n=n)
# Out:
#   0%|          | 0/10 [00:00<?, ?it/s]
# Optimizers:   0%|          | 0/8 [00:00<?, ?it/s]
# Data:   0%|          | 0/10000 [00:00<?, ?it/s]
# Excluded optimizers (diverged) for r=5: ['SAUSNA P α=0.67 p=d^1']

# %%
simulation = simulation_linear_regression_toeplitz(optimizer_list=optimizer_list)
simulation.run_multiple_track_errors(N=N, n=n)
# Out:
#   0%|          | 0/10 [00:00<?, ?it/s]
# Optimizers:   0%|          | 0/8 [00:00<?, ?it/s]
# Data:   0%|          | 0/10000 [00:00<?, ?it/s]

# %%
simulation.run_multiple_track_time(N=N, n=n)
# Out:
#   0%|          | 0/10 [00:00<?, ?it/s]
# Optimizers:   0%|          | 0/8 [00:00<?, ?it/s]
# Data:   0%|          | 0/10000 [00:00<?, ?it/s]
# Excluded optimizers (diverged) for r=1: ['ASGD α=0.67']
# Excluded optimizers (diverged) for r=5: ['ASGD α=0.67']

# %%
simulation = simulation_linear_regression_toeplitz_diag(optimizer_list=optimizer_list)
simulation.run_multiple_track_errors(N=N, n=n)
# Out:
#   0%|          | 0/10 [00:00<?, ?it/s]
# Optimizers:   0%|          | 0/8 [00:00<?, ?it/s]
# Data:   0%|          | 0/10000 [00:00<?, ?it/s]
# /home/gs/Optimisation_stochastique/Notebooks_numpy_streaming/../algorithms_numpy/USNA.py:93: RuntimeWarning: invalid value encountered in matmul
#   self.param_not_averaged -= learning_rate * self.matrix @ grad
# /home/gs/Optimisation_stochastique/Notebooks_numpy_streaming/../algorithms_numpy/SGD.py:73: RuntimeWarning: invalid value encountered in subtract
#   self.param_not_averaged -= learning_rate * grad
# /home/gs/AppImage/miniconda3/envs/env/lib/python3.13/site-packages/matplotlib/scale.py:253: RuntimeWarning: overflow encountered in power
#   return np.power(self.base, values)

# %%
simulation.run_multiple_track_time(N=N, n=n)
# Out:
#   0%|          | 0/10 [00:00<?, ?it/s]
# Optimizers:   0%|          | 0/8 [00:00<?, ?it/s]
# Data:   0%|          | 0/10000 [00:00<?, ?it/s]

# %%
simulation = simulation_logistic_regression(optimizer_list=optimizer_list)
simulation.run_multiple_track_errors(N=N, n=n)
# Out:
#   0%|          | 0/10 [00:00<?, ?it/s]
# Optimizers:   0%|          | 0/8 [00:00<?, ?it/s]
# Data:   0%|          | 0/10000 [00:00<?, ?it/s]

# %%
simulation.run_multiple_track_time(N=N, n=n)
# Out:
#   0%|          | 0/10 [00:00<?, ?it/s]
# Optimizers:   0%|          | 0/8 [00:00<?, ?it/s]
# Data:   0%|          | 0/10000 [00:00<?, ?it/s]

# %%
simulation = simulation_logistic_regression_toeplitz(optimizer_list=optimizer_list)
simulation.run_multiple_track_errors(N=N, n=n)
# Out:
#   0%|          | 0/10 [00:00<?, ?it/s]
# Optimizers:   0%|          | 0/8 [00:00<?, ?it/s]
# Data:   0%|          | 0/10000 [00:00<?, ?it/s]

# %%
simulation.run_multiple_track_time(N=N, n=n)
# Out:
#   0%|          | 0/10 [00:00<?, ?it/s]
# Optimizers:   0%|          | 0/8 [00:00<?, ?it/s]
# Data:   0%|          | 0/10000 [00:00<?, ?it/s]

# %%
simulation = simulation_logistic_regression_toeplitz_diag(optimizer_list=optimizer_list)
simulation.run_multiple_track_errors(N=N, n=n)
# Out:
#   0%|          | 0/10 [00:00<?, ?it/s]
# Optimizers:   0%|          | 0/8 [00:00<?, ?it/s]
# Data:   0%|          | 0/10000 [00:00<?, ?it/s]

# %%
simulation.run_multiple_track_time(N=N, n=n)
# Out:
#   0%|          | 0/10 [00:00<?, ?it/s]
# Optimizers:   0%|          | 0/8 [00:00<?, ?it/s]
# Data:   0%|          | 0/10000 [00:00<?, ?it/s]

# %%
simulation = simulation_geometric_median(optimizer_list=optimizer_list)
simulation.run_multiple_track_errors(N=N, n=n)
# Out:
#   0%|          | 0/10 [00:00<?, ?it/s]
# Optimizers:   0%|          | 0/8 [00:00<?, ?it/s]
# Data:   0%|          | 0/10000 [00:00<?, ?it/s]

# %%
simulation.run_multiple_track_time(N=N, n=n)
# Out:
#   0%|          | 0/10 [00:00<?, ?it/s]
# Optimizers:   0%|          | 0/8 [00:00<?, ?it/s]
# Data:   0%|          | 0/10000 [00:00<?, ?it/s]

# %%
simulation = simulation_p_means(optimizer_list=optimizer_list)
simulation.run_multiple_track_errors(N=N, n=n)
# Out:
#   0%|          | 0/10 [00:00<?, ?it/s]
# Optimizers:   0%|          | 0/8 [00:00<?, ?it/s]
# Data:   0%|          | 0/10000 [00:00<?, ?it/s]

# %%
simulation.run_multiple_track_time(N=N, n=n)
# Out:
#   0%|          | 0/10 [00:00<?, ?it/s]
# Optimizers:   0%|          | 0/8 [00:00<?, ?it/s]
# Data:   0%|          | 0/10000 [00:00<?, ?it/s]

# %%
eval = eval_covtype(optimizer_list=optimizer_list)
_, _ = eval.run_track_time()
# Out:
# Optimizers:   0%|          | 0/8 [00:00<?, ?it/s]
# Data:   0%|          | 0/464809 [00:00<?, ?it/s]
# <style type="text/css">
# #T_903a0_row0_col4, #T_903a0_row1_col6, #T_903a0_row2_col6 {
#   font-weight: bold;
# }
# </style>
# <table id="T_903a0">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_903a0_level0_col0" class="col_heading level0 col0" >ASGD α=0.67</th>
#       <th id="T_903a0_level0_col1" class="col_heading level0 col1" >AAda α=0.67</th>
#       <th id="T_903a0_level0_col2" class="col_heading level0 col2" >ASNA α=0.67</th>
#       <th id="T_903a0_level0_col3" class="col_heading level0 col3" >AUSNA P α=0.67</th>
#       <th id="T_903a0_level0_col4" class="col_heading level0 col4" >SASGD α=0.67 p=d^1</th>
#       <th id="T_903a0_level0_col5" class="col_heading level0 col5" >SAAda α=0.67 p=d^1</th>
#       <th id="T_903a0_level0_col6" class="col_heading level0 col6" >SASNA α=0.67 p=d^1</th>
#       <th id="T_903a0_level0_col7" class="col_heading level0 col7" >SAUSNA P α=0.67 p=d^1</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_903a0_level0_row0" class="row_heading level0 row0" >Execution Time</th>
#       <td id="T_903a0_row0_col0" class="data row0 col0" >5.763045</td>
#       <td id="T_903a0_row0_col1" class="data row0 col1" >6.295710</td>
#       <td id="T_903a0_row0_col2" class="data row0 col2" >22.036755</td>
#       <td id="T_903a0_row0_col3" class="data row0 col3" >17.523945</td>
#       <td id="T_903a0_row0_col4" class="data row0 col4" >0.140713</td>
#       <td id="T_903a0_row0_col5" class="data row0 col5" >0.159002</td>
#       <td id="T_903a0_row0_col6" class="data row0 col6" >2.521444</td>
#       <td id="T_903a0_row0_col7" class="data row0 col7" >0.374628</td>
#     </tr>
#     <tr>
#       <th id="T_903a0_level0_row1" class="row_heading level0 row1" >Training Accuracy</th>
#       <td id="T_903a0_row1_col0" class="data row1 col0" >0.729190</td>
#       <td id="T_903a0_row1_col1" class="data row1 col1" >0.759219</td>
#       <td id="T_903a0_row1_col2" class="data row1 col2" >0.714259</td>
#       <td id="T_903a0_row1_col3" class="data row1 col3" >0.725782</td>
#       <td id="T_903a0_row1_col4" class="data row1 col4" >0.644755</td>
#       <td id="T_903a0_row1_col5" class="data row1 col5" >0.745954</td>
#       <td id="T_903a0_row1_col6" class="data row1 col6" >0.767010</td>
#       <td id="T_903a0_row1_col7" class="data row1 col7" >0.642425</td>
#     </tr>
#     <tr>
#       <th id="T_903a0_level0_row2" class="row_heading level0 row2" >Test Accuracy</th>
#       <td id="T_903a0_row2_col0" class="data row2 col0" >0.731694</td>
#       <td id="T_903a0_row2_col1" class="data row2 col1" >0.760609</td>
#       <td id="T_903a0_row2_col2" class="data row2 col2" >0.717047</td>
#       <td id="T_903a0_row2_col3" class="data row2 col3" >0.728751</td>
#       <td id="T_903a0_row2_col4" class="data row2 col4" >0.646584</td>
#       <td id="T_903a0_row2_col5" class="data row2 col5" >0.748191</td>
#       <td id="T_903a0_row2_col6" class="data row2 col6" >0.768483</td>
#       <td id="T_903a0_row2_col7" class="data row2 col7" >0.643925</td>
#     </tr>
#   </tbody>
# </table>
