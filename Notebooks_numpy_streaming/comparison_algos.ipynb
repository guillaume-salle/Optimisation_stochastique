# %%
import sys
sys.path.append('..')

# %%
from config_simulation import (
    algo,
    simulation_linear_regression,
    simulation_linear_regression_toeplitz,
    simulation_linear_regression_toeplitz_diag,
    simulation_logistic_regression,
    simulation_logistic_regression_toeplitz,
    simulation_logistic_regression_toeplitz_diag,
    simulation_geometric_median,
    simulation_p_means,
    eval_covtype,
    N,
    n,
)

from functools import partial
batch_size_power = 1.0
multiply_lr = 'default'
optimizer_list = [
    # WASGD
    partial(algo.SGD, averaged=True),

    # # WAAdaGrad
    # partial(algo.AdaGrad, averaged=True, true_ada=True),
    
    # # WASNA
    # partial(algo.SNA, averaged=True),
    
    # USNA and UWASNA
    partial(algo.USNA, averaged=False),
    partial(algo.USNA, averaged=True),

    # # Streaming 
    # partial(algo.SGD, averaged=True, batch_size_power=batch_size_power, multiply_lr=multiply_lr),
    # partial(algo.AdaGrad, averaged=True, true_ada=True, batch_size_power=batch_size_power, multiply_lr=multiply_lr),
    # partial(algo.SNA, averaged=True, batch_size_power=batch_size_power, multiply_lr=multiply_lr),
    partial(algo.USNA, averaged=False, proj=True, batch_size_power=batch_size_power, multiply_lr=multiply_lr),
    partial(algo.USNA, averaged=True, proj=True, batch_size_power=batch_size_power, multiply_lr=0.0),
    partial(algo.USNA, averaged=True, proj=True, batch_size_power=batch_size_power, multiply_lr=multiply_lr),
]

# %%
# N = 2
# n = 1000

# %%
simulation = simulation_linear_regression(optimizer_list=optimizer_list)
simulation.run_multiple_track_errors(N=N, n=n)
# Out:
#   0%|          | 0/10 [00:00<?, ?it/s]
# Optimizers:   0%|          | 0/5 [00:00<?, ?it/s]
# Data:   0%|          | 0/100000 [00:00<?, ?it/s]

# %%
simulation.run_multiple_track_time(N=N, n=n)
# Out:
#   0%|          | 0/10 [00:00<?, ?it/s]
# Optimizers:   0%|          | 0/5 [00:00<?, ?it/s]
# Data:   0%|          | 0/100000 [00:00<?, ?it/s]
# Excluded optimizers (diverged) for r=1: ['AUSNA α=0.67']
# Excluded optimizers (diverged) for r=2: ['AUSNA α=0.67']

# %%
simulation = simulation_linear_regression_toeplitz(optimizer_list=optimizer_list)
simulation.run_multiple_track_errors(N=N, n=n)
# Out:
#   0%|          | 0/10 [00:00<?, ?it/s]
# Optimizers:   0%|          | 0/5 [00:00<?, ?it/s]
# Data:   0%|          | 0/100000 [00:00<?, ?it/s]

# %%
simulation.run_multiple_track_time(N=N, n=n)
# Out:
#   0%|          | 0/10 [00:00<?, ?it/s]
# Optimizers:   0%|          | 0/5 [00:00<?, ?it/s]
# Data:   0%|          | 0/100000 [00:00<?, ?it/s]
# Excluded optimizers (diverged) for r=1: ['ASGD α=0.67']
# Excluded optimizers (diverged) for r=2: ['ASGD α=0.67']

# %%
simulation = simulation_linear_regression_toeplitz_diag(optimizer_list=optimizer_list)
simulation.run_multiple_track_errors(N=N, n=n)
# Out:
#   0%|          | 0/10 [00:00<?, ?it/s]
# Optimizers:   0%|          | 0/5 [00:00<?, ?it/s]
# Data:   0%|          | 0/100000 [00:00<?, ?it/s]
# /home/gs/Optimisation_stochastique/Notebooks_numpy_streaming/../algorithms_numpy/SGD.py:58: RuntimeWarning: invalid value encountered in subtract
#   self.param_not_averaged -= learning_rate * grad
# /home/gs/Optimisation_stochastique/Notebooks_numpy_streaming/../algorithms_numpy/USNA.py:93: RuntimeWarning: invalid value encountered in matmul
#   self.param_not_averaged -= learning_rate * self.matrix @ grad
# /home/gs/AppImage/miniconda3/envs/env/lib/python3.13/site-packages/matplotlib/scale.py:253: RuntimeWarning: overflow encountered in power
#   return np.power(self.base, values)

# %%
simulation.run_multiple_track_time(N=N, n=n)
# Out:
#   0%|          | 0/10 [00:00<?, ?it/s]
# Optimizers:   0%|          | 0/5 [00:00<?, ?it/s]
# Data:   0%|          | 0/100000 [00:00<?, ?it/s]

# %%
simulation = simulation_logistic_regression(optimizer_list=optimizer_list)
simulation.run_multiple_track_errors(N=N, n=n)
# Out:
#   0%|          | 0/10 [00:00<?, ?it/s]
# Optimizers:   0%|          | 0/5 [00:00<?, ?it/s]
# Data:   0%|          | 0/100000 [00:00<?, ?it/s]

# %%
simulation.run_multiple_track_time(N=N, n=n)
# Out:
#   0%|          | 0/10 [00:00<?, ?it/s]
# Optimizers:   0%|          | 0/5 [00:00<?, ?it/s]
# Data:   0%|          | 0/100000 [00:00<?, ?it/s]

# %%
simulation = simulation_logistic_regression_toeplitz(optimizer_list=optimizer_list)
simulation.run_multiple_track_errors(N=N, n=n)
# Out:
#   0%|          | 0/10 [00:00<?, ?it/s]
# Optimizers:   0%|          | 0/5 [00:00<?, ?it/s]
# Data:   0%|          | 0/100000 [00:00<?, ?it/s]

# %%
simulation.run_multiple_track_time(N=N, n=n)
# Out:
#   0%|          | 0/10 [00:00<?, ?it/s]
# Optimizers:   0%|          | 0/8 [00:00<?, ?it/s]
# Data:   0%|          | 0/100000 [00:00<?, ?it/s]
# Excluded optimizers (diverged) for r=1: ['ASGD α=0.67', 'ASNA α=0.67 SM', 'AUSNA α=0.67']
# Excluded optimizers (diverged) for r=2: ['ASGD α=0.67', 'ASNA α=0.67 SM', 'AUSNA α=0.67']

# %%
simulation = simulation_logistic_regression_toeplitz_diag(optimizer_list=optimizer_list)
simulation.run_multiple_track_errors(N=N, n=n)
# Out:
#   0%|          | 0/10 [00:00<?, ?it/s]
# Optimizers:   0%|          | 0/8 [00:00<?, ?it/s]
# Data:   0%|          | 0/100000 [00:00<?, ?it/s]

# %%
simulation.run_multiple_track_time(N=N, n=n)
# Out:
#   0%|          | 0/10 [00:00<?, ?it/s]
# Optimizers:   0%|          | 0/8 [00:00<?, ?it/s]
# Data:   0%|          | 0/100000 [00:00<?, ?it/s]

# %%
simulation = simulation_geometric_median(optimizer_list=optimizer_list)
simulation.run_multiple_track_errors(N=N, n=n)
# Out:
#   0%|          | 0/10 [00:00<?, ?it/s]
# Optimizers:   0%|          | 0/8 [00:00<?, ?it/s]
# Data:   0%|          | 0/100000 [00:00<?, ?it/s]

# %%
simulation.run_multiple_track_time(N=N, n=n)
# Out:
#   0%|          | 0/10 [00:00<?, ?it/s]
# Optimizers:   0%|          | 0/8 [00:00<?, ?it/s]
# Data:   0%|          | 0/100000 [00:00<?, ?it/s]

# %%
simulation = simulation_p_means(optimizer_list=optimizer_list)
simulation.run_multiple_track_errors(N=N, n=n)
# Out:
#   0%|          | 0/10 [00:00<?, ?it/s]
# Optimizers:   0%|          | 0/8 [00:00<?, ?it/s]
# Data:   0%|          | 0/100000 [00:00<?, ?it/s]

# %%
simulation.run_multiple_track_time(N=N, n=n)
# Out:
#   0%|          | 0/10 [00:00<?, ?it/s]
# Optimizers:   0%|          | 0/8 [00:00<?, ?it/s]
# Data:   0%|          | 0/100000 [00:00<?, ?it/s]

# %%
eval = eval_covtype(optimizer_list=optimizer_list)
_, _ = eval.run_track_time()
# Out:
# Optimizers:   0%|          | 0/8 [00:00<?, ?it/s]
# Data:   0%|          | 0/464809 [00:00<?, ?it/s]
# <style type="text/css">
# #T_9a597_row0_col4, #T_9a597_row1_col6, #T_9a597_row2_col6 {
#   font-weight: bold;
# }
# </style>
# <table id="T_9a597">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_9a597_level0_col0" class="col_heading level0 col0" >ASGD α=0.67</th>
#       <th id="T_9a597_level0_col1" class="col_heading level0 col1" >AAda α=0.67</th>
#       <th id="T_9a597_level0_col2" class="col_heading level0 col2" >ASNA α=0.67 SM</th>
#       <th id="T_9a597_level0_col3" class="col_heading level0 col3" >AUSNA α=0.67</th>
#       <th id="T_9a597_level0_col4" class="col_heading level0 col4" >SASGD α=0.67 p=32 c_α*p^0.33</th>
#       <th id="T_9a597_level0_col5" class="col_heading level0 col5" >SAAda α=0.67 p=32 c_α*p^0.33</th>
#       <th id="T_9a597_level0_col6" class="col_heading level0 col6" >SASNA α=0.67 p=32 c_α*p^0.33</th>
#       <th id="T_9a597_level0_col7" class="col_heading level0 col7" >SAUSNA α=0.67 p=32 c_α*p^0.33</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_9a597_level0_row0" class="row_heading level0 row0" >Execution Time</th>
#       <td id="T_9a597_row0_col0" class="data row0 col0" >5.772599</td>
#       <td id="T_9a597_row0_col1" class="data row0 col1" >6.205315</td>
#       <td id="T_9a597_row0_col2" class="data row0 col2" >10.379439</td>
#       <td id="T_9a597_row0_col3" class="data row0 col3" >17.387589</td>
#       <td id="T_9a597_row0_col4" class="data row0 col4" >0.207655</td>
#       <td id="T_9a597_row0_col5" class="data row0 col5" >0.223217</td>
#       <td id="T_9a597_row0_col6" class="data row0 col6" >2.896219</td>
#       <td id="T_9a597_row0_col7" class="data row0 col7" >0.593251</td>
#     </tr>
#     <tr>
#       <th id="T_9a597_level0_row1" class="row_heading level0 row1" >Training Accuracy</th>
#       <td id="T_9a597_row1_col0" class="data row1 col0" >0.729254</td>
#       <td id="T_9a597_row1_col1" class="data row1 col1" >0.759419</td>
#       <td id="T_9a597_row1_col2" class="data row1 col2" >0.709203</td>
#       <td id="T_9a597_row1_col3" class="data row1 col3" >0.726509</td>
#       <td id="T_9a597_row1_col4" class="data row1 col4" >0.687207</td>
#       <td id="T_9a597_row1_col5" class="data row1 col5" >0.750403</td>
#       <td id="T_9a597_row1_col6" class="data row1 col6" >0.765848</td>
#       <td id="T_9a597_row1_col7" class="data row1 col7" >0.650033</td>
#     </tr>
#     <tr>
#       <th id="T_9a597_level0_row2" class="row_heading level0 row2" >Test Accuracy</th>
#       <td id="T_9a597_row2_col0" class="data row2 col0" >0.731737</td>
#       <td id="T_9a597_row2_col1" class="data row2 col1" >0.760583</td>
#       <td id="T_9a597_row2_col2" class="data row2 col2" >0.712563</td>
#       <td id="T_9a597_row2_col3" class="data row2 col3" >0.729998</td>
#       <td id="T_9a597_row2_col4" class="data row2 col4" >0.690017</td>
#       <td id="T_9a597_row2_col5" class="data row2 col5" >0.752433</td>
#       <td id="T_9a597_row2_col6" class="data row2 col6" >0.767639</td>
#       <td id="T_9a597_row2_col7" class="data row2 col7" >0.651739</td>
#     </tr>
#   </tbody>
# </table>
