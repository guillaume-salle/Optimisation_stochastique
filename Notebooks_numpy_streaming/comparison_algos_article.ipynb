# %%
import sys
sys.path.append('..')

# %%
from config_simulation import (
    algo,
    simulation_linear_regression,
    simulation_linear_regression_toeplitz,
    simulation_linear_regression_toeplitz_diag,
    simulation_logistic_regression,
    simulation_logistic_regression_toeplitz,
    simulation_logistic_regression_toeplitz_diag,
    simulation_geometric_median,
    simulation_p_means,
    eval_covtype,
    N,
    n,
)

from functools import partial
mini_batch_power = 0.5
optimizer_list = [
    # WASGD
    partial(algo.SGD, averaged=True),

    # WAAdaGrad
    partial(algo.AdaGrad, averaged=True, true_ada=True),
    
    # WASNA
    partial(algo.SNA, averaged=True),
    
    # UWASNA
    partial(algo.USNA, averaged=True),

    # Streaming WASNA and UWASNA
    partial(algo.SGD, averaged=True, mini_batch_power=mini_batch_power),
    partial(algo.AdaGrad, averaged=True, true_ada=True, mini_batch_power=mini_batch_power),
    partial(algo.SNA, averaged=True, mini_batch_power=mini_batch_power),
    partial(algo.USNA, averaged=True, proj=True, mini_batch_power=mini_batch_power),
]

# %%
# N = 2
# n = 1000

# %%
simulation = simulation_linear_regression(optimizer_list=optimizer_list)
simulation.run_multiple_track_errors(N=N, n=n)
# Out:
#   0%|          | 0/10 [00:00<?, ?it/s]
# Optimizers:   0%|          | 0/8 [00:00<?, ?it/s]
# Data:   0%|          | 0/10000 [00:00<?, ?it/s]

# %%
simulation.run_multiple_track_time(N=N, n=n)
# Out:
#   0%|          | 0/10 [00:00<?, ?it/s]
# Optimizers:   0%|          | 0/8 [00:00<?, ?it/s]
# Data:   0%|          | 0/10000 [00:00<?, ?it/s]

# %%
simulation = simulation_linear_regression_toeplitz(optimizer_list=optimizer_list)
simulation.run_multiple_track_errors(N=N, n=n)
# Out:
#   0%|          | 0/10 [00:00<?, ?it/s]
# Optimizers:   0%|          | 0/8 [00:00<?, ?it/s]
# Data:   0%|          | 0/10000 [00:00<?, ?it/s]

# %%
simulation.run_multiple_track_time(N=N, n=n)
# Out:
#   0%|          | 0/10 [00:00<?, ?it/s]
# Optimizers:   0%|          | 0/8 [00:00<?, ?it/s]
# Data:   0%|          | 0/10000 [00:00<?, ?it/s]

# %%
simulation = simulation_linear_regression_toeplitz_diag(optimizer_list=optimizer_list)
simulation.run_multiple_track_errors(N=N, n=n)
# Out:
#   0%|          | 0/10 [00:00<?, ?it/s]
# Optimizers:   0%|          | 0/8 [00:00<?, ?it/s]
# Data:   0%|          | 0/10000 [00:00<?, ?it/s]

# %%
simulation.run_multiple_track_time(N=N, n=n)
# Out:
#   0%|          | 0/10 [00:00<?, ?it/s]
# Optimizers:   0%|          | 0/8 [00:00<?, ?it/s]
# Data:   0%|          | 0/10000 [00:00<?, ?it/s]
# Excluded optimizers (diverged) for r=1: ['ASGD α=0.67', 'ASNA α=0.67 SM', 'SASGD α=0.67 p=3 c_α*p^0.5', 'SASNA α=0.67 p=3 c_α*p^0.5']
# Excluded optimizers (diverged) for r=2: ['ASGD α=0.67', 'ASNA α=0.67 SM', 'SASGD α=0.67 p=3 c_α*p^0.5', 'SASNA α=0.67 p=3 c_α*p^0.5']

# %%
simulation = simulation_logistic_regression(optimizer_list=optimizer_list)
simulation.run_multiple_track_errors(N=N, n=n)
# Out:
#   0%|          | 0/10 [00:00<?, ?it/s]
# Optimizers:   0%|          | 0/8 [00:00<?, ?it/s]
# Data:   0%|          | 0/10000 [00:00<?, ?it/s]

# %%
simulation.run_multiple_track_time(N=N, n=n)
# Out:
#   0%|          | 0/10 [00:00<?, ?it/s]
# Optimizers:   0%|          | 0/8 [00:00<?, ?it/s]
# Data:   0%|          | 0/10000 [00:00<?, ?it/s]

# %%
simulation = simulation_logistic_regression_toeplitz(optimizer_list=optimizer_list)
simulation.run_multiple_track_errors(N=N, n=n)
# Out:
#   0%|          | 0/10 [00:00<?, ?it/s]
# Optimizers:   0%|          | 0/8 [00:00<?, ?it/s]
# Data:   0%|          | 0/10000 [00:00<?, ?it/s]

# %%
simulation.run_multiple_track_time(N=N, n=n)
# Out:
#   0%|          | 0/10 [00:00<?, ?it/s]
# Optimizers:   0%|          | 0/8 [00:00<?, ?it/s]
# Data:   0%|          | 0/10000 [00:00<?, ?it/s]

# %%
simulation = simulation_logistic_regression_toeplitz_diag(optimizer_list=optimizer_list)
simulation.run_multiple_track_errors(N=N, n=n)
# Out:
#   0%|          | 0/10 [00:00<?, ?it/s]
# Optimizers:   0%|          | 0/8 [00:00<?, ?it/s]
# Data:   0%|          | 0/10000 [00:00<?, ?it/s]

# %%
simulation.run_multiple_track_time(N=N, n=n)
# Out:
#   0%|          | 0/10 [00:00<?, ?it/s]
# Optimizers:   0%|          | 0/8 [00:00<?, ?it/s]
# Data:   0%|          | 0/10000 [00:00<?, ?it/s]

# %%
simulation = simulation_geometric_median(optimizer_list=optimizer_list)
simulation.run_multiple_track_errors(N=N, n=n)
# Out:
#   0%|          | 0/10 [00:00<?, ?it/s]
# Optimizers:   0%|          | 0/8 [00:00<?, ?it/s]
# Data:   0%|          | 0/10000 [00:00<?, ?it/s]

# %%
simulation.run_multiple_track_time(N=N, n=n)
# Out:
#   0%|          | 0/10 [00:00<?, ?it/s]
# Optimizers:   0%|          | 0/8 [00:00<?, ?it/s]
# Data:   0%|          | 0/10000 [00:00<?, ?it/s]

# %%
simulation = simulation_p_means(optimizer_list=optimizer_list)
simulation.run_multiple_track_errors(N=N, n=n)
# Out:
#   0%|          | 0/10 [00:00<?, ?it/s]
# Optimizers:   0%|          | 0/8 [00:00<?, ?it/s]
# Data:   0%|          | 0/10000 [00:00<?, ?it/s]

# %%
simulation.run_multiple_track_time(N=N, n=n)
# Out:
#   0%|          | 0/10 [00:00<?, ?it/s]
# Optimizers:   0%|          | 0/8 [00:00<?, ?it/s]
# Data:   0%|          | 0/10000 [00:00<?, ?it/s]

# %%
eval = eval_covtype(optimizer_list=optimizer_list)
_, _ = eval.run_track_time()
# Out:
# Optimizers:   0%|          | 0/8 [00:00<?, ?it/s]
# Data:   0%|          | 0/464809 [00:00<?, ?it/s]
# <style type="text/css">
# #T_9561e_row0_col4, #T_9561e_row1_col6, #T_9561e_row2_col6 {
#   font-weight: bold;
# }
# </style>
# <table id="T_9561e">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_9561e_level0_col0" class="col_heading level0 col0" >ASGD α=0.67</th>
#       <th id="T_9561e_level0_col1" class="col_heading level0 col1" >AAda α=0.67</th>
#       <th id="T_9561e_level0_col2" class="col_heading level0 col2" >ASNA α=0.67 SM</th>
#       <th id="T_9561e_level0_col3" class="col_heading level0 col3" >AUSNA α=0.67</th>
#       <th id="T_9561e_level0_col4" class="col_heading level0 col4" >SASGD α=0.67 p=7 c_α*p^0.5</th>
#       <th id="T_9561e_level0_col5" class="col_heading level0 col5" >SAAda α=0.67 p=7 c_α*p^0.5</th>
#       <th id="T_9561e_level0_col6" class="col_heading level0 col6" >SASNA α=0.67 p=7 c_α*p^0.5</th>
#       <th id="T_9561e_level0_col7" class="col_heading level0 col7" >SAUSNA α=0.67 p=7 c_α*p^0.5</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_9561e_level0_row0" class="row_heading level0 row0" >Execution Time</th>
#       <td id="T_9561e_row0_col0" class="data row0 col0" >5.693833</td>
#       <td id="T_9561e_row0_col1" class="data row0 col1" >6.278183</td>
#       <td id="T_9561e_row0_col2" class="data row0 col2" >10.534028</td>
#       <td id="T_9561e_row0_col3" class="data row0 col3" >17.627232</td>
#       <td id="T_9561e_row0_col4" class="data row0 col4" >0.871878</td>
#       <td id="T_9561e_row0_col5" class="data row0 col5" >0.950092</td>
#       <td id="T_9561e_row0_col6" class="data row0 col6" >5.665997</td>
#       <td id="T_9561e_row0_col7" class="data row0 col7" >2.664594</td>
#     </tr>
#     <tr>
#       <th id="T_9561e_level0_row1" class="row_heading level0 row1" >Training Accuracy</th>
#       <td id="T_9561e_row1_col0" class="data row1 col0" >0.729254</td>
#       <td id="T_9561e_row1_col1" class="data row1 col1" >0.759419</td>
#       <td id="T_9561e_row1_col2" class="data row1 col2" >0.709203</td>
#       <td id="T_9561e_row1_col3" class="data row1 col3" >0.724891</td>
#       <td id="T_9561e_row1_col4" class="data row1 col4" >0.721471</td>
#       <td id="T_9561e_row1_col5" class="data row1 col5" >0.756799</td>
#       <td id="T_9561e_row1_col6" class="data row1 col6" >0.768148</td>
#       <td id="T_9561e_row1_col7" class="data row1 col7" >0.715634</td>
#     </tr>
#     <tr>
#       <th id="T_9561e_level0_row2" class="row_heading level0 row2" >Test Accuracy</th>
#       <td id="T_9561e_row2_col0" class="data row2 col0" >0.731737</td>
#       <td id="T_9561e_row2_col1" class="data row2 col1" >0.760583</td>
#       <td id="T_9561e_row2_col2" class="data row2 col2" >0.712563</td>
#       <td id="T_9561e_row2_col3" class="data row2 col3" >0.728036</td>
#       <td id="T_9561e_row2_col4" class="data row2 col4" >0.723062</td>
#       <td id="T_9561e_row2_col5" class="data row2 col5" >0.758535</td>
#       <td id="T_9561e_row2_col6" class="data row2 col6" >0.769438</td>
#       <td id="T_9561e_row2_col7" class="data row2 col7" >0.716806</td>
#     </tr>
#   </tbody>
# </table>
