# %%
import sys
sys.path.append('..')

# %%
from config_simulation import (
    algo,
    simulation_linear_regression,
    simulation_logistic_regression,
    simulation_geometric_median,
    simulation_spherical_distribution,
    simulation_p_means,
    eval_covtype,
    N,
    n,
)

from functools import partial
mult=False
optimizer_list = [
    # # WASGD
    partial(algo.SGD, averaged=True, lr_add_iter=50),

    # # WAAdaGrad
    partial(algo.AdaGrad, averaged=True, lr_add_iter=50),
    
    # WASNA
    partial(algo.SNA, averaged=True, lr_add_iter=50),
    
    # UWASNA
    partial(algo.USNA, averaged=True, lr_add_iter=50, proj=True),

    # # Streaming WASNA and UWASNA
    partial(algo.SGD, averaged=True, lr_add_iter=50, batch_size_power=1, multiply_lr_const=mult),
    partial(algo.AdaGrad, averaged=True, lr_add_iter=50, batch_size_power=1, multiply_lr_const =mult),
    partial(algo.SNA, averaged=True, lr_add_iter=50, batch_size_power=1, multiply_lr_const=mult),
    partial(algo.USNA, averaged=True, lr_add_iter=50, proj=True, batch_size_power=1, multiply_lr_const=mult),
]

# %%
# N = 2
# n = 1000
N = 10

# %%
simulation = simulation_linear_regression(optimizer_list=optimizer_list)
simulation.run_multiple_track_errors(N=N, n=n)
# Out:
#   0%|          | 0/10 [00:00<?, ?it/s]
# Optimizers:   0%|          | 0/8 [00:00<?, ?it/s]
# Data:   0%|          | 0/10000 [00:00<?, ?it/s]

# %%
simulation.run_multiple_track_time(N=N, n=n)
# Out:
#   0%|          | 0/10 [00:00<?, ?it/s]
# Optimizers:   0%|          | 0/8 [00:00<?, ?it/s]
# Data:   0%|          | 0/10000 [00:00<?, ?it/s]

# %%
simulation = simulation_logistic_regression(optimizer_list=optimizer_list)
simulation.run_multiple_track_errors(N=N, n=n)
# Out:
#   0%|          | 0/10 [00:00<?, ?it/s]
# Optimizers:   0%|          | 0/8 [00:00<?, ?it/s]
# Data:   0%|          | 0/10000 [00:00<?, ?it/s]

# %%
simulation.run_multiple_track_time(N=N, n=n)
# Out:
#   0%|          | 0/10 [00:00<?, ?it/s]
# Optimizers:   0%|          | 0/8 [00:00<?, ?it/s]
# Data:   0%|          | 0/10000 [00:00<?, ?it/s]

# %%
simulation = simulation_geometric_median(optimizer_list=optimizer_list)
simulation.run_multiple_track_errors(N=N, n=n)
# Out:
#   0%|          | 0/10 [00:00<?, ?it/s]
# Optimizers:   0%|          | 0/8 [00:00<?, ?it/s]
# Data:   0%|          | 0/10000 [00:00<?, ?it/s]

# %%
simulation.run_multiple_track_time(N=N, n=n)
# Out:
#   0%|          | 0/10 [00:00<?, ?it/s]
# Optimizers:   0%|          | 0/8 [00:00<?, ?it/s]
# Data:   0%|          | 0/10000 [00:00<?, ?it/s]

# %%
simulation = simulation_spherical_distribution( optimizer_list=optimizer_list)
simulation.run_multiple_track_errors(N=N, n=n)
# Out:
#   0%|          | 0/10 [00:00<?, ?it/s]
# Optimizers:   0%|          | 0/8 [00:00<?, ?it/s]
# Data:   0%|          | 0/10000 [00:00<?, ?it/s]

# %%
simulation.run_multiple_track_time(N=N, n=n)
# Out:
#   0%|          | 0/10 [00:00<?, ?it/s]
# Optimizers:   0%|          | 0/8 [00:00<?, ?it/s]
# Data:   0%|          | 0/10000 [00:00<?, ?it/s]

# %%
simulation = simulation_p_means(optimizer_list=optimizer_list)
simulation.run_multiple_track_errors(N=N, n=n)
# Out:
#   0%|          | 0/10 [00:00<?, ?it/s]
# Optimizers:   0%|          | 0/8 [00:00<?, ?it/s]
# Data:   0%|          | 0/10000 [00:00<?, ?it/s]

# %%
simulation.run_multiple_track_time(N=N, n=n)
# Out:
#   0%|          | 0/10 [00:00<?, ?it/s]
# Optimizers:   0%|          | 0/8 [00:00<?, ?it/s]
# Data:   0%|          | 0/10000 [00:00<?, ?it/s]

# %%
eval = eval_covtype(optimizer_list=optimizer_list)
_, _ = eval.run_track_time()
# Out:
# Optimizers:   0%|          | 0/8 [00:00<?, ?it/s]
# Data:   0%|          | 0/464809 [00:00<?, ?it/s]
# <style type="text/css">
# #T_4ef01_row0_col4, #T_4ef01_row1_col6, #T_4ef01_row2_col6 {
#   font-weight: bold;
# }
# </style>
# <table id="T_4ef01">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_4ef01_level0_col0" class="col_heading level0 col0" >WASGD α=0.67</th>
#       <th id="T_4ef01_level0_col1" class="col_heading level0 col1" >WAAda α=0.67</th>
#       <th id="T_4ef01_level0_col2" class="col_heading level0 col2" >WASNA α=0.67</th>
#       <th id="T_4ef01_level0_col3" class="col_heading level0 col3" >WAUSNA P α=0.67</th>
#       <th id="T_4ef01_level0_col4" class="col_heading level0 col4" >SWASGD α=0.67 c_α*dim^0.3333333333333333</th>
#       <th id="T_4ef01_level0_col5" class="col_heading level0 col5" >SWAAda α=0.67 c_α*dim^0.3333333333333333</th>
#       <th id="T_4ef01_level0_col6" class="col_heading level0 col6" >SWASNA α=0.67 c_α*dim^0.3333333333333333</th>
#       <th id="T_4ef01_level0_col7" class="col_heading level0 col7" >SWAUSNA P α=0.67 c_α*dim^0.3333333333333333</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_4ef01_level0_row0" class="row_heading level0 row0" >Execution Time</th>
#       <td id="T_4ef01_row0_col0" class="data row0 col0" >5.767030</td>
#       <td id="T_4ef01_row0_col1" class="data row0 col1" >6.448236</td>
#       <td id="T_4ef01_row0_col2" class="data row0 col2" >22.478679</td>
#       <td id="T_4ef01_row0_col3" class="data row0 col3" >17.296782</td>
#       <td id="T_4ef01_row0_col4" class="data row0 col4" >0.131449</td>
#       <td id="T_4ef01_row0_col5" class="data row0 col5" >0.145863</td>
#       <td id="T_4ef01_row0_col6" class="data row0 col6" >2.650725</td>
#       <td id="T_4ef01_row0_col7" class="data row0 col7" >0.352011</td>
#     </tr>
#     <tr>
#       <th id="T_4ef01_level0_row1" class="row_heading level0 row1" >Training Accuracy</th>
#       <td id="T_4ef01_row1_col0" class="data row1 col0" >0.729190</td>
#       <td id="T_4ef01_row1_col1" class="data row1 col1" >0.761289</td>
#       <td id="T_4ef01_row1_col2" class="data row1 col2" >0.714259</td>
#       <td id="T_4ef01_row1_col3" class="data row1 col3" >0.725599</td>
#       <td id="T_4ef01_row1_col4" class="data row1 col4" >0.666596</td>
#       <td id="T_4ef01_row1_col5" class="data row1 col5" >0.747546</td>
#       <td id="T_4ef01_row1_col6" class="data row1 col6" >0.765060</td>
#       <td id="T_4ef01_row1_col7" class="data row1 col7" >0.653385</td>
#     </tr>
#     <tr>
#       <th id="T_4ef01_level0_row2" class="row_heading level0 row2" >Test Accuracy</th>
#       <td id="T_4ef01_row2_col0" class="data row2 col0" >0.731694</td>
#       <td id="T_4ef01_row2_col1" class="data row2 col1" >0.763130</td>
#       <td id="T_4ef01_row2_col2" class="data row2 col2" >0.717047</td>
#       <td id="T_4ef01_row2_col3" class="data row2 col3" >0.728510</td>
#       <td id="T_4ef01_row2_col4" class="data row2 col4" >0.669518</td>
#       <td id="T_4ef01_row2_col5" class="data row2 col5" >0.750420</td>
#       <td id="T_4ef01_row2_col6" class="data row2 col6" >0.766830</td>
#       <td id="T_4ef01_row2_col7" class="data row2 col7" >0.655697</td>
#     </tr>
#   </tbody>
# </table>

# %%
eval = eval_covtype(optimizer_list=optimizer_list)
_, _ = eval.run_track_time()
# Out:
# Optimizers:   0%|          | 0/8 [00:00<?, ?it/s]
# Data:   0%|          | 0/464809 [00:00<?, ?it/s]
# <style type="text/css">
# #T_d14ce_row0_col4, #T_d14ce_row1_col6, #T_d14ce_row2_col6 {
#   font-weight: bold;
# }
# </style>
# <table id="T_d14ce">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_d14ce_level0_col0" class="col_heading level0 col0" >WASGD α=0.67</th>
#       <th id="T_d14ce_level0_col1" class="col_heading level0 col1" >WAAda α=0.67</th>
#       <th id="T_d14ce_level0_col2" class="col_heading level0 col2" >WASNA α=0.67</th>
#       <th id="T_d14ce_level0_col3" class="col_heading level0 col3" >WAUSNA P α=0.67</th>
#       <th id="T_d14ce_level0_col4" class="col_heading level0 col4" >SWASGD α=0.67 c_α*dim^0.3333333333333333</th>
#       <th id="T_d14ce_level0_col5" class="col_heading level0 col5" >SWAAda α=0.67 c_α*dim^0.3333333333333333</th>
#       <th id="T_d14ce_level0_col6" class="col_heading level0 col6" >SWASNA α=0.67 c_α*dim^0.3333333333333333</th>
#       <th id="T_d14ce_level0_col7" class="col_heading level0 col7" >SWAUSNA P α=0.67 c_α*dim^0.3333333333333333</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_d14ce_level0_row0" class="row_heading level0 row0" >Execution Time</th>
#       <td id="T_d14ce_row0_col0" class="data row0 col0" >5.818896</td>
#       <td id="T_d14ce_row0_col1" class="data row0 col1" >6.539960</td>
#       <td id="T_d14ce_row0_col2" class="data row0 col2" >22.668376</td>
#       <td id="T_d14ce_row0_col3" class="data row0 col3" >17.731990</td>
#       <td id="T_d14ce_row0_col4" class="data row0 col4" >0.151088</td>
#       <td id="T_d14ce_row0_col5" class="data row0 col5" >0.168766</td>
#       <td id="T_d14ce_row0_col6" class="data row0 col6" >2.663012</td>
#       <td id="T_d14ce_row0_col7" class="data row0 col7" >0.362440</td>
#     </tr>
#     <tr>
#       <th id="T_d14ce_level0_row1" class="row_heading level0 row1" >Training Accuracy</th>
#       <td id="T_d14ce_row1_col0" class="data row1 col0" >0.729190</td>
#       <td id="T_d14ce_row1_col1" class="data row1 col1" >0.761289</td>
#       <td id="T_d14ce_row1_col2" class="data row1 col2" >0.714259</td>
#       <td id="T_d14ce_row1_col3" class="data row1 col3" >0.725218</td>
#       <td id="T_d14ce_row1_col4" class="data row1 col4" >0.666596</td>
#       <td id="T_d14ce_row1_col5" class="data row1 col5" >0.747546</td>
#       <td id="T_d14ce_row1_col6" class="data row1 col6" >0.765060</td>
#       <td id="T_d14ce_row1_col7" class="data row1 col7" >0.648514</td>
#     </tr>
#     <tr>
#       <th id="T_d14ce_level0_row2" class="row_heading level0 row2" >Test Accuracy</th>
#       <td id="T_d14ce_row2_col0" class="data row2 col0" >0.731694</td>
#       <td id="T_d14ce_row2_col1" class="data row2 col1" >0.763130</td>
#       <td id="T_d14ce_row2_col2" class="data row2 col2" >0.717047</td>
#       <td id="T_d14ce_row2_col3" class="data row2 col3" >0.728105</td>
#       <td id="T_d14ce_row2_col4" class="data row2 col4" >0.669518</td>
#       <td id="T_d14ce_row2_col5" class="data row2 col5" >0.750420</td>
#       <td id="T_d14ce_row2_col6" class="data row2 col6" >0.766830</td>
#       <td id="T_d14ce_row2_col7" class="data row2 col7" >0.649940</td>
#     </tr>
#   </tbody>
# </table>
