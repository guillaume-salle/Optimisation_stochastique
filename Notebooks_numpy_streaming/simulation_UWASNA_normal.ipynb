# %%
import sys
sys.path.append('..')

# %%
from config_simulation import (
    algorithms,
    simulation_linear_regression,
    simulation_logistic_regression,
    simulation_geometric_median,
    simulation_spherical_distribution,
    simulation_p_means,
    eval_covtype,
    n,
    N,
    nu_list,
    gamma_list,
)


optimizer_class = algorithms.UWASNA
optimizer_list = [optimizer_class(gamma=gamma, c_nu=5.0, add_iter_theta=200) for gamma in gamma_list]

# %%
simulation = simulation_linear_regression(optimizer_list=optimizer_list)
simulation.run_multiple_track_errors(N=N, n=n)

# %%
simulation = simulation_logistic_regression(optimizer_list=optimizer_list)
simulation.run_multiple_track_errors(N=N, n=n)

# %%
simulation = simulation_geometric_median(optimizer_list=optimizer_list)
simulation.run_multiple_track_errors(N=N, n=n)

# %%
simulation = simulation_spherical_distribution(optimizer_list=optimizer_list)
simulation.run_multiple_track_errors(N=N, n=n)

# %%
simulation = simulation_p_means(optimizer_list=optimizer_list)
simulation.run_multiple_track_errors(N=N, n=n)

# %%
eval = eval_covtype(optimizer_list=optimizer_list)
_, _ = eval.run_track_time()
# Out:
# Optimizers:   0%|          | 0/6 [00:00<?, ?it/s]
# Data:   0%|          | 0/464809 [00:00<?, ?it/s]
# <style type="text/css">
# #T_8efec_row0_col5, #T_8efec_row1_col5 {
#   font-weight: bold;
# }
# </style>
# <table id="T_8efec">
#   <caption>Accuracy on covtype dataset</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_8efec_level0_col0" class="col_heading level0 col0" >UWASNA ν=0.75 γ=0.45</th>
#       <th id="T_8efec_level0_col1" class="col_heading level0 col1" >UWASNA ν=0.75 γ=0.5</th>
#       <th id="T_8efec_level0_col2" class="col_heading level0 col2" >UWASNA ν=0.75 γ=0.66</th>
#       <th id="T_8efec_level0_col3" class="col_heading level0 col3" >UWASNA ν=0.75 γ=0.75</th>
#       <th id="T_8efec_level0_col4" class="col_heading level0 col4" >UWASNA ν=0.75 γ=1.0</th>
#       <th id="T_8efec_level0_col5" class="col_heading level0 col5" >UWASNA ν=0.75 γ=1.05</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_8efec_level0_row0" class="row_heading level0 row0" >Training Accuracy</th>
#       <td id="T_8efec_row0_col0" class="data row0 col0" >64.520000</td>
#       <td id="T_8efec_row0_col1" class="data row0 col1" >64.610000</td>
#       <td id="T_8efec_row0_col2" class="data row0 col2" >64.720000</td>
#       <td id="T_8efec_row0_col3" class="data row0 col3" >65.010000</td>
#       <td id="T_8efec_row0_col4" class="data row0 col4" >65.630000</td>
#       <td id="T_8efec_row0_col5" class="data row0 col5" >65.920000</td>
#     </tr>
#     <tr>
#       <th id="T_8efec_level0_row1" class="row_heading level0 row1" >Test Accuracy</th>
#       <td id="T_8efec_row1_col0" class="data row1 col0" >64.390000</td>
#       <td id="T_8efec_row1_col1" class="data row1 col1" >64.460000</td>
#       <td id="T_8efec_row1_col2" class="data row1 col2" >64.570000</td>
#       <td id="T_8efec_row1_col3" class="data row1 col3" >64.880000</td>
#       <td id="T_8efec_row1_col4" class="data row1 col4" >65.620000</td>
#       <td id="T_8efec_row1_col5" class="data row1 col5" >65.920000</td>
#     </tr>
#   </tbody>
# </table>
