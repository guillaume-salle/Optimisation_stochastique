# %%
import sys
sys.path.append('..')

# %%
from config_simulation import (
    algo,
    simulation_linear_regression,
    simulation_logistic_regression,
    simulation_geometric_median,
    simulation_spherical_distribution,
    simulation_p_means,
    eval_covtype,
    N,
    n,
)

from functools import partial
optimizer_list = [
    # WASGD
    partial(algo.SGD, averaged=True, lr_add_iter=10),

    # WAAdaGrad
    partial(algo.AdaGrad, averaged=True, lr_add_iter=10),
    
    # WASNA
    partial(algo.SNA, averaged=True, lr_add_iter=10),
    
    # UWASNA
    partial(algo.USNA, averaged=True, lr_add_iter=10, proj=True),

    # Streaming WASNA and UWASNA
    partial(algo.SNA, averaged=True, lr_add_iter=10, batch_size_power=1),
    partial(algo.USNA, averaged=True, lr_add_iter=10, proj=True, batch_size_power=1),
]

# %%
N = 2
n = 1000

# %%
simulation = simulation_linear_regression(optimizer_list=optimizer_list)
simulation.run_multiple_track_errors(N=N, n=n)

# %%
simulation.run_multiple_track_time(N=N, n=n)

# %%
simulation = simulation_logistic_regression(optimizer_list=optimizer_list)
simulation.run_multiple_track_errors(N=N, n=n)

# %%
simulation.run_multiple_track_time(N=N, n=n)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 simulation.run_multiple_track_time(N=N, n=n)
#
# File ~/Optimisation_stochastique/Notebooks_numpy_streaming/../simulation/simulation.py:454, in Simulation.run_multiple_track_time(self, N, n)
#     451 optimizer_pbar.close()
#     452 N_runs_pbar.close()
# --> 454 self.boxplot_time_and_errors(all_execution_times, all_metrics, N)
#
# File ~/Optimisation_stochastique/Notebooks_numpy_streaming/../simulation/simulation.py:548, in Simulation.boxplot_time_and_errors(self, all_execution_times, all_last_param_error, N)
#     546 # Boxplot with seaborn
#     547 box1 = sns.boxplot(data=all_execution_times[r], ax=ax1)
# --> 548 box2 = sns.boxplot(data=all_last_param_error[r], ax=ax2)
#     550 ax1.set_title(f"r={r}")
#     551 ax1.set_ylabel("time (s)")
#
# File ~/AppImage/miniconda3/envs/env/lib/python3.13/site-packages/seaborn/categorical.py:1634, in boxplot(data, x, y, hue, order, hue_order, orient, color, palette, saturation, fill, dodge, width, gap, whis, linecolor, linewidth, fliersize, hue_norm, native_scale, log_scale, formatter, legend, ax, **kwargs)
#    1627 color = _default_color(
#    1628     ax.fill_between, hue, color,
#    1629     {k: v for k, v in kwargs.items() if k in ["c", "color", "fc", "facecolor"]},
#    1630     saturation=saturation,
#    1631 )
#    1632 linecolor = p._complement_color(linecolor, color, p._hue_map)
# -> 1634 p.plot_boxes(
#    1635     width=width,
#    1636     dodge=dodge,
#    1637     gap=gap,
#    1638     fill=fill,
#    1639     whis=whis,
#    1640     color=color,
#    1641     linecolor=linecolor,
#    1642     linewidth=linewidth,
#    1643     fliersize=fliersize,
#    1644     plot_kws=kwargs,
#    1645 )
#    1647 p._add_axis_labels(ax)
#    1648 p._adjust_cat_axis(ax, axis=p.orient)
#
# File ~/AppImage/miniconda3/envs/env/lib/python3.13/site-packages/seaborn/categorical.py:700, in _CategoricalPlotter.plot_boxes(self, width, dodge, gap, fill, whis, color, linecolor, linewidth, fliersize, plot_kws)
#     679 default_kws = dict(
#     680     bxpstats=stats.to_dict("records"),
#     681     positions=data[self.orient],
#    (...)
#     697     )
#     698 )
#     699 boxplot_kws = {**default_kws, **plot_kws}
# --> 700 artists = ax.bxp(**boxplot_kws)
#     702 # Reset artist widths after adding so everything stays positive
#     703 ori_idx = ["x", "y"].index(self.orient)
#
# File ~/AppImage/miniconda3/envs/env/lib/python3.13/site-packages/matplotlib/_api/deprecation.py:453, in make_keyword_only.<locals>.wrapper(*args, **kwargs)
#     447 if len(args) > name_idx:
#     448     warn_deprecated(
#     449         since, message="Passing the %(name)s %(obj_type)s "
#     450         "positionally is deprecated since Matplotlib %(since)s; the "
#     451         "parameter will become keyword-only in %(removal)s.",
#     452         name=name, obj_type=f"parameter of {func.__name__}()")
# --> 453 return func(*args, **kwargs)
#
# File ~/AppImage/miniconda3/envs/env/lib/python3.13/site-packages/matplotlib/axes/_axes.py:4404, in Axes.bxp(self, bxpstats, positions, widths, vert, orientation, patch_artist, shownotches, showmeans, showcaps, showbox, showfliers, boxprops, whiskerprops, flierprops, medianprops, capprops, meanprops, meanline, manage_ticks, zorder, capwidths, label)
#    4393     return d
#    4395 box_kw = {
#    4396     'linestyle': mpl.rcParams['boxplot.boxprops.linestyle'],
#    4397     'linewidth': mpl.rcParams['boxplot.boxprops.linewidth'],
#    (...)
#    4402     **cbook.normalize_kwargs(boxprops, mpatches.PathPatch)
#    4403 } if patch_artist else merge_kw_rc('box', boxprops, usemarker=False)
# -> 4404 whisker_kw = merge_kw_rc('whisker', whiskerprops, usemarker=False)
#    4405 cap_kw = merge_kw_rc('cap', capprops, usemarker=False)
#    4406 flier_kw = merge_kw_rc('flier', flierprops)
#
# File ~/AppImage/miniconda3/envs/env/lib/python3.13/site-packages/matplotlib/axes/_axes.py:4387, in Axes.bxp.<locals>.merge_kw_rc(subkey, explicit, zdelta, usemarker)
#    4386 def merge_kw_rc(subkey, explicit, zdelta=0, usemarker=True):
# -> 4387     d = {k.split('.')[-1]: v for k, v in mpl.rcParams.items()
#    4388          if k.startswith(f'boxplot.{subkey}props')}
#    4389     d['zorder'] = zorder + zdelta
#    4390     if not usemarker:
#
# File <frozen _collections_abc>:898, in __iter__(self)
#
# File ~/AppImage/miniconda3/envs/env/lib/python3.13/site-packages/matplotlib/__init__.py:820, in RcParams.__iter__(self)
#     818 def __iter__(self):
#     819     """Yield sorted list of keys."""
# --> 820     with _api.suppress_matplotlib_deprecation_warning():
#     821         yield from sorted(dict.__iter__(self))
#
# File ~/AppImage/miniconda3/envs/env/lib/python3.13/contextlib.py:141, in _GeneratorContextManager.__enter__(self)
#     139 del self.args, self.kwds, self.func
#     140 try:
# --> 141     return next(self.gen)
#     142 except StopIteration:
#     143     raise RuntimeError("generator didn't yield") from None
#
# File ~/AppImage/miniconda3/envs/env/lib/python3.13/site-packages/matplotlib/_api/deprecation.py:507, in suppress_matplotlib_deprecation_warning()
#     505 @contextlib.contextmanager
#     506 def suppress_matplotlib_deprecation_warning():
# --> 507     with warnings.catch_warnings():
#     508         warnings.simplefilter("ignore", MatplotlibDeprecationWarning)
#     509         yield
#
# File ~/AppImage/miniconda3/envs/env/lib/python3.13/warnings.py:462, in catch_warnings.__init__(self, record, module, action, category, lineno, append)
#     442 class catch_warnings(object):
#     444     """A context manager that copies and restores the warnings filter upon
#     445     exiting the context.
#     446
#    (...)
#     459     context.
#     460     """
# --> 462     def __init__(self, *, record=False, module=None,
#     463                  action=None, category=Warning, lineno=0, append=False):
#     464         """Specify whether to record warnings and if an alternative module
#     465         should be used other than sys.modules['warnings'].
#     466
#    (...)
#     469
#     470         """
#     471         self._record = record
#
# KeyboardInterrupt:

# %%
simulation = simulation_geometric_median(optimizer_list=optimizer_list)
simulation.run_multiple_track_errors(N=N, n=n)

# %%
simulation.run_multiple_track_time(N=N, n=n)

# %%
simulation = simulation_spherical_distribution( optimizer_list=optimizer_list)
simulation.run_multiple_track_errors(N=N, n=n)

# %%
simulation.run_multiple_track_time(N=N, n=n)

# %%
simulation = simulation_p_means(optimizer_list=optimizer_list)
simulation.run_multiple_track_errors(N=N, n=n)

# %%
simulation.run_multiple_track_time(N=N, n=n)

# %%
eval = eval_covtype(optimizer_list=optimizer_list)
_, _ = eval.run_track_time()
# Out:
# Optimizers:   0%|          | 0/6 [00:00<?, ?it/s]
# Data:   0%|          | 0/464809 [00:00<?, ?it/s]
# <style type="text/css">
# #T_7f9f3_row0_col5, #T_7f9f3_row1_col4, #T_7f9f3_row2_col4 {
#   font-weight: bold;
# }
# </style>
# <table id="T_7f9f3">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_7f9f3_level0_col0" class="col_heading level0 col0" >WASGD α=0.67</th>
#       <th id="T_7f9f3_level0_col1" class="col_heading level0 col1" >WAAda α=0.67</th>
#       <th id="T_7f9f3_level0_col2" class="col_heading level0 col2" >WASNA α=0.67</th>
#       <th id="T_7f9f3_level0_col3" class="col_heading level0 col3" >UWASNA P α=0.67</th>
#       <th id="T_7f9f3_level0_col4" class="col_heading level0 col4" >WASNA α=0.67 (1)</th>
#       <th id="T_7f9f3_level0_col5" class="col_heading level0 col5" >UWASNA P α=0.67 (1)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_7f9f3_level0_row0" class="row_heading level0 row0" >Execution Time</th>
#       <td id="T_7f9f3_row0_col0" class="data row0 col0" >5.724661</td>
#       <td id="T_7f9f3_row0_col1" class="data row0 col1" >6.544527</td>
#       <td id="T_7f9f3_row0_col2" class="data row0 col2" >22.363460</td>
#       <td id="T_7f9f3_row0_col3" class="data row0 col3" >17.392776</td>
#       <td id="T_7f9f3_row0_col4" class="data row0 col4" >2.622647</td>
#       <td id="T_7f9f3_row0_col5" class="data row0 col5" >0.355004</td>
#     </tr>
#     <tr>
#       <th id="T_7f9f3_level0_row1" class="row_heading level0 row1" >Training Accuracy</th>
#       <td id="T_7f9f3_row1_col0" class="data row1 col0" >0.729351</td>
#       <td id="T_7f9f3_row1_col1" class="data row1 col1" >0.761549</td>
#       <td id="T_7f9f3_row1_col2" class="data row1 col2" >0.728359</td>
#       <td id="T_7f9f3_row1_col3" class="data row1 col3" >0.725253</td>
#       <td id="T_7f9f3_row1_col4" class="data row1 col4" >0.764006</td>
#       <td id="T_7f9f3_row1_col5" class="data row1 col5" >0.649503</td>
#     </tr>
#     <tr>
#       <th id="T_7f9f3_level0_row2" class="row_heading level0 row2" >Test Accuracy</th>
#       <td id="T_7f9f3_row2_col0" class="data row2 col0" >0.731719</td>
#       <td id="T_7f9f3_row2_col1" class="data row2 col1" >0.763130</td>
#       <td id="T_7f9f3_row2_col2" class="data row2 col2" >0.732305</td>
#       <td id="T_7f9f3_row2_col3" class="data row2 col3" >0.728553</td>
#       <td id="T_7f9f3_row2_col4" class="data row2 col4" >0.765953</td>
#       <td id="T_7f9f3_row2_col5" class="data row2 col5" >0.651076</td>
#     </tr>
#   </tbody>
# </table>

# %%
eval = eval_covtype(optimizer_list=optimizer_list)
_, _ = eval.run_track_time()
# Out:
# Optimizers:   0%|          | 0/6 [00:00<?, ?it/s]
# Data:   0%|          | 0/464809 [00:00<?, ?it/s]
# <style type="text/css">
# #T_ee297_row0_col5, #T_ee297_row1_col4, #T_ee297_row2_col4 {
#   font-weight: bold;
# }
# </style>
# <table id="T_ee297">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_ee297_level0_col0" class="col_heading level0 col0" >WASGD α=0.67</th>
#       <th id="T_ee297_level0_col1" class="col_heading level0 col1" >WAAda α=0.67</th>
#       <th id="T_ee297_level0_col2" class="col_heading level0 col2" >WASNA α=0.67</th>
#       <th id="T_ee297_level0_col3" class="col_heading level0 col3" >UWASNA P α=0.67</th>
#       <th id="T_ee297_level0_col4" class="col_heading level0 col4" >WASNA α=0.67 (1)</th>
#       <th id="T_ee297_level0_col5" class="col_heading level0 col5" >UWASNA P α=0.67 (1)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_ee297_level0_row0" class="row_heading level0 row0" >Execution Time</th>
#       <td id="T_ee297_row0_col0" class="data row0 col0" >5.664055</td>
#       <td id="T_ee297_row0_col1" class="data row0 col1" >6.508993</td>
#       <td id="T_ee297_row0_col2" class="data row0 col2" >22.538967</td>
#       <td id="T_ee297_row0_col3" class="data row0 col3" >17.474834</td>
#       <td id="T_ee297_row0_col4" class="data row0 col4" >2.577746</td>
#       <td id="T_ee297_row0_col5" class="data row0 col5" >0.349802</td>
#     </tr>
#     <tr>
#       <th id="T_ee297_level0_row1" class="row_heading level0 row1" >Training Accuracy</th>
#       <td id="T_ee297_row1_col0" class="data row1 col0" >0.729351</td>
#       <td id="T_ee297_row1_col1" class="data row1 col1" >0.761549</td>
#       <td id="T_ee297_row1_col2" class="data row1 col2" >0.728359</td>
#       <td id="T_ee297_row1_col3" class="data row1 col3" >0.725076</td>
#       <td id="T_ee297_row1_col4" class="data row1 col4" >0.764006</td>
#       <td id="T_ee297_row1_col5" class="data row1 col5" >0.654462</td>
#     </tr>
#     <tr>
#       <th id="T_ee297_level0_row2" class="row_heading level0 row2" >Test Accuracy</th>
#       <td id="T_ee297_row2_col0" class="data row2 col0" >0.731719</td>
#       <td id="T_ee297_row2_col1" class="data row2 col1" >0.763130</td>
#       <td id="T_ee297_row2_col2" class="data row2 col2" >0.732305</td>
#       <td id="T_ee297_row2_col3" class="data row2 col3" >0.728165</td>
#       <td id="T_ee297_row2_col4" class="data row2 col4" >0.765953</td>
#       <td id="T_ee297_row2_col5" class="data row2 col5" >0.656549</td>
#     </tr>
#   </tbody>
# </table>
