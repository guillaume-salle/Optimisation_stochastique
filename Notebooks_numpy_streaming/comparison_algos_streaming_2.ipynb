# %%
import sys
sys.path.append('..')

# %%
from config_simulation import (
    algo,
    simulation_linear_regression,
    simulation_logistic_regression,
    simulation_geometric_median,
    simulation_spherical_distribution,
    simulation_p_means,
    eval_covtype,
    N,
    n,
)

from functools import partial
optimizer_list = [
    # # WASGD
    partial(algo.SGD, averaged=True, lr_add_iter=10),

    # # WAAdaGrad
    partial(algo.AdaGrad, averaged=True, lr_add_iter=10),
    
    # WASNA
    partial(algo.SNA, averaged=True, lr_add_iter=10),
    
    # UWASNA
    partial(algo.USNA, averaged=True, lr_add_iter=10, proj=True),

    # # Streaming WASNA and UWASNA
    partial(algo.SNA, averaged=True, lr_add_iter=10, batch_size_power=1, multiply_lr_const=True),
    partial(algo.USNA, averaged=True, lr_add_iter=10, proj=True, batch_size_power=1, multiply_lr_const=True),
]

# %%
# N = 2
# n = 1000
n = int(1e5)

# %%
simulation = simulation_linear_regression(optimizer_list=optimizer_list)
simulation.run_multiple_track_errors(N=N, n=n)
# Out:
#   0%|          | 0/20 [00:00<?, ?it/s]
# Optimizers:   0%|          | 0/6 [00:00<?, ?it/s]
# Data:   0%|          | 0/100000 [00:00<?, ?it/s]

# %%
simulation.run_multiple_track_time(N=N, n=n)
# Out:
#   0%|          | 0/20 [00:00<?, ?it/s]
# Optimizers:   0%|          | 0/6 [00:00<?, ?it/s]
# Data:   0%|          | 0/100000 [00:00<?, ?it/s]

# %%
simulation = simulation_logistic_regression(optimizer_list=optimizer_list)
simulation.run_multiple_track_errors(N=N, n=n)
# Out:
#   0%|          | 0/20 [00:00<?, ?it/s]
# Optimizers:   0%|          | 0/6 [00:00<?, ?it/s]
# Data:   0%|          | 0/100000 [00:00<?, ?it/s]

# %%
simulation.run_multiple_track_time(N=N, n=n)
# Out:
#   0%|          | 0/20 [00:00<?, ?it/s]
# Optimizers:   0%|          | 0/6 [00:00<?, ?it/s]
# Data:   0%|          | 0/100000 [00:00<?, ?it/s]

# %%
simulation = simulation_geometric_median(optimizer_list=optimizer_list)
simulation.run_multiple_track_errors(N=N, n=n)
# Out:
#   0%|          | 0/20 [00:00<?, ?it/s]
# Optimizers:   0%|          | 0/6 [00:00<?, ?it/s]
# Data:   0%|          | 0/100000 [00:00<?, ?it/s]

# %%
simulation.run_multiple_track_time(N=N, n=n)
# Out:
#   0%|          | 0/20 [00:00<?, ?it/s]
# Optimizers:   0%|          | 0/6 [00:00<?, ?it/s]
# Data:   0%|          | 0/100000 [00:00<?, ?it/s]

# %%
simulation = simulation_spherical_distribution( optimizer_list=optimizer_list)
simulation.run_multiple_track_errors(N=N, n=n)
# Out:
#   0%|          | 0/20 [00:00<?, ?it/s]
# Optimizers:   0%|          | 0/6 [00:00<?, ?it/s]
# Data:   0%|          | 0/100000 [00:00<?, ?it/s]

# %%
simulation.run_multiple_track_time(N=N, n=n)
# Out:
#   0%|          | 0/20 [00:00<?, ?it/s]
# Optimizers:   0%|          | 0/6 [00:00<?, ?it/s]
# Data:   0%|          | 0/100000 [00:00<?, ?it/s]

# %%
simulation = simulation_p_means(optimizer_list=optimizer_list)
simulation.run_multiple_track_errors(N=N, n=n)
# Out:
#   0%|          | 0/20 [00:00<?, ?it/s]
# Optimizers:   0%|          | 0/6 [00:00<?, ?it/s]
# Data:   0%|          | 0/100000 [00:00<?, ?it/s]

# %%
simulation.run_multiple_track_time(N=N, n=n)
# Out:
#   0%|          | 0/20 [00:00<?, ?it/s]
# Optimizers:   0%|          | 0/6 [00:00<?, ?it/s]
# Data:   0%|          | 0/100000 [00:00<?, ?it/s]

# %%
eval = eval_covtype(optimizer_list=optimizer_list)
_, _ = eval.run_track_time()
# Out:
# Optimizers:   0%|          | 0/6 [00:00<?, ?it/s]
# Data:   0%|          | 0/464809 [00:00<?, ?it/s]
# <style type="text/css">
# #T_f64ba_row0_col5, #T_f64ba_row1_col4, #T_f64ba_row2_col4 {
#   font-weight: bold;
# }
# </style>
# <table id="T_f64ba">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_f64ba_level0_col0" class="col_heading level0 col0" >WASGD α=0.67</th>
#       <th id="T_f64ba_level0_col1" class="col_heading level0 col1" >WAAda α=0.67</th>
#       <th id="T_f64ba_level0_col2" class="col_heading level0 col2" >WASNA α=0.67</th>
#       <th id="T_f64ba_level0_col3" class="col_heading level0 col3" >WAUSNA P α=0.67</th>
#       <th id="T_f64ba_level0_col4" class="col_heading level0 col4" >SWASNA α=0.67 c_α*dim^0.5</th>
#       <th id="T_f64ba_level0_col5" class="col_heading level0 col5" >SWAUSNA P α=0.67 c_α*dim^0.5</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_f64ba_level0_row0" class="row_heading level0 row0" >Execution Time</th>
#       <td id="T_f64ba_row0_col0" class="data row0 col0" >5.595865</td>
#       <td id="T_f64ba_row0_col1" class="data row0 col1" >6.526309</td>
#       <td id="T_f64ba_row0_col2" class="data row0 col2" >22.881169</td>
#       <td id="T_f64ba_row0_col3" class="data row0 col3" >18.345500</td>
#       <td id="T_f64ba_row0_col4" class="data row0 col4" >2.919941</td>
#       <td id="T_f64ba_row0_col5" class="data row0 col5" >0.372922</td>
#     </tr>
#     <tr>
#       <th id="T_f64ba_level0_row1" class="row_heading level0 row1" >Training Accuracy</th>
#       <td id="T_f64ba_row1_col0" class="data row1 col0" >0.729351</td>
#       <td id="T_f64ba_row1_col1" class="data row1 col1" >0.761549</td>
#       <td id="T_f64ba_row1_col2" class="data row1 col2" >0.728359</td>
#       <td id="T_f64ba_row1_col3" class="data row1 col3" >0.725550</td>
#       <td id="T_f64ba_row1_col4" class="data row1 col4" >0.764454</td>
#       <td id="T_f64ba_row1_col5" class="data row1 col5" >0.651521</td>
#     </tr>
#     <tr>
#       <th id="T_f64ba_level0_row2" class="row_heading level0 row2" >Test Accuracy</th>
#       <td id="T_f64ba_row2_col0" class="data row2 col0" >0.731719</td>
#       <td id="T_f64ba_row2_col1" class="data row2 col1" >0.763130</td>
#       <td id="T_f64ba_row2_col2" class="data row2 col2" >0.732305</td>
#       <td id="T_f64ba_row2_col3" class="data row2 col3" >0.728785</td>
#       <td id="T_f64ba_row2_col4" class="data row2 col4" >0.766641</td>
#       <td id="T_f64ba_row2_col5" class="data row2 col5" >0.652978</td>
#     </tr>
#   </tbody>
# </table>

# %%
eval = eval_covtype(optimizer_list=optimizer_list)
_, _ = eval.run_track_time()
# Out:
# Optimizers:   0%|          | 0/6 [00:00<?, ?it/s]
# Data:   0%|          | 0/464809 [00:00<?, ?it/s]
# <style type="text/css">
# #T_b34c2_row0_col5, #T_b34c2_row1_col4, #T_b34c2_row2_col4 {
#   font-weight: bold;
# }
# </style>
# <table id="T_b34c2">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_b34c2_level0_col0" class="col_heading level0 col0" >WASGD α=0.67</th>
#       <th id="T_b34c2_level0_col1" class="col_heading level0 col1" >WAAda α=0.67</th>
#       <th id="T_b34c2_level0_col2" class="col_heading level0 col2" >WASNA α=0.67</th>
#       <th id="T_b34c2_level0_col3" class="col_heading level0 col3" >WAUSNA P α=0.67</th>
#       <th id="T_b34c2_level0_col4" class="col_heading level0 col4" >SWASNA α=0.67 c_α*dim^0.5</th>
#       <th id="T_b34c2_level0_col5" class="col_heading level0 col5" >SWAUSNA P α=0.67 c_α*dim^0.5</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_b34c2_level0_row0" class="row_heading level0 row0" >Execution Time</th>
#       <td id="T_b34c2_row0_col0" class="data row0 col0" >5.686829</td>
#       <td id="T_b34c2_row0_col1" class="data row0 col1" >6.606728</td>
#       <td id="T_b34c2_row0_col2" class="data row0 col2" >22.552507</td>
#       <td id="T_b34c2_row0_col3" class="data row0 col3" >18.074356</td>
#       <td id="T_b34c2_row0_col4" class="data row0 col4" >2.647776</td>
#       <td id="T_b34c2_row0_col5" class="data row0 col5" >0.383942</td>
#     </tr>
#     <tr>
#       <th id="T_b34c2_level0_row1" class="row_heading level0 row1" >Training Accuracy</th>
#       <td id="T_b34c2_row1_col0" class="data row1 col0" >0.729351</td>
#       <td id="T_b34c2_row1_col1" class="data row1 col1" >0.761549</td>
#       <td id="T_b34c2_row1_col2" class="data row1 col2" >0.728359</td>
#       <td id="T_b34c2_row1_col3" class="data row1 col3" >0.725618</td>
#       <td id="T_b34c2_row1_col4" class="data row1 col4" >0.764454</td>
#       <td id="T_b34c2_row1_col5" class="data row1 col5" >0.651504</td>
#     </tr>
#     <tr>
#       <th id="T_b34c2_level0_row2" class="row_heading level0 row2" >Test Accuracy</th>
#       <td id="T_b34c2_row2_col0" class="data row2 col0" >0.731719</td>
#       <td id="T_b34c2_row2_col1" class="data row2 col1" >0.763130</td>
#       <td id="T_b34c2_row2_col2" class="data row2 col2" >0.732305</td>
#       <td id="T_b34c2_row2_col3" class="data row2 col3" >0.728604</td>
#       <td id="T_b34c2_row2_col4" class="data row2 col4" >0.766641</td>
#       <td id="T_b34c2_row2_col5" class="data row2 col5" >0.653296</td>
#     </tr>
#   </tbody>
# </table>
