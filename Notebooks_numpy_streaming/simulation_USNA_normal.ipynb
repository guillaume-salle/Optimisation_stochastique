# %%
import sys
sys.path.append('..')

# %%
from config_simulation import (
    algorithms,
    simulation_linear_regression,
    simulation_logistic_regression,
    simulation_geometric_median,
    simulation_spherical_distribution,
    simulation_p_means,
    eval_covtype,
    n,
    N,
    nu_list,
    gamma_list,
)


optimizer_class = algorithms.USNA
optimizer_list = [optimizer_class(gamma=gamma, c_nu=5.0, add_iter_theta=200, generate_Z="normal") for gamma in gamma_list]

# %%
simulation = simulation_linear_regression(optimizer_list=optimizer_list)
simulation.run_multiple_track_errors(N=N, n=n)

# %%
simulation = simulation_logistic_regression(optimizer_list=optimizer_list)
simulation.run_multiple_track_errors(N=N, n=n)

# %%
simulation = simulation_geometric_median(optimizer_list=optimizer_list)
simulation.run_multiple_track_errors(N=N, n=n)

# %%
simulation = simulation_spherical_distribution(optimizer_list=optimizer_list)
simulation.run_multiple_track_errors(N=N, n=n)

# %%
simulation = simulation_p_means(optimizer_list=optimizer_list)
simulation.run_multiple_track_errors(N=N, n=n)

# %%
eval = eval_covtype(optimizer_list=optimizer_list)
_, _ = eval.run_track_time()
# Out:
# Optimizers:   0%|          | 0/6 [00:00<?, ?it/s]
# Data:   0%|          | 0/464809 [00:00<?, ?it/s]
# <style type="text/css">
# #T_f079a_row0_col0, #T_f079a_row1_col0 {
#   font-weight: bold;
# }
# </style>
# <table id="T_f079a">
#   <caption>Accuracy on covtype dataset</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_f079a_level0_col0" class="col_heading level0 col0" >USNA ν=1.0 γ=0.45 Z~normal</th>
#       <th id="T_f079a_level0_col1" class="col_heading level0 col1" >USNA ν=1.0 γ=0.5 Z~normal</th>
#       <th id="T_f079a_level0_col2" class="col_heading level0 col2" >USNA ν=1.0 γ=0.66 Z~normal</th>
#       <th id="T_f079a_level0_col3" class="col_heading level0 col3" >USNA ν=1.0 γ=0.75 Z~normal</th>
#       <th id="T_f079a_level0_col4" class="col_heading level0 col4" >USNA ν=1.0 γ=1.0 Z~normal</th>
#       <th id="T_f079a_level0_col5" class="col_heading level0 col5" >USNA ν=1.0 γ=1.05 Z~normal</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_f079a_level0_row0" class="row_heading level0 row0" >Training Accuracy</th>
#       <td id="T_f079a_row0_col0" class="data row0 col0" >65.860000</td>
#       <td id="T_f079a_row0_col1" class="data row0 col1" >39.640000</td>
#       <td id="T_f079a_row0_col2" class="data row0 col2" >64.990000</td>
#       <td id="T_f079a_row0_col3" class="data row0 col3" >60.730000</td>
#       <td id="T_f079a_row0_col4" class="data row0 col4" >55.890000</td>
#       <td id="T_f079a_row0_col5" class="data row0 col5" >62.340000</td>
#     </tr>
#     <tr>
#       <th id="T_f079a_level0_row1" class="row_heading level0 row1" >Test Accuracy</th>
#       <td id="T_f079a_row1_col0" class="data row1 col0" >66.000000</td>
#       <td id="T_f079a_row1_col1" class="data row1 col1" >39.810000</td>
#       <td id="T_f079a_row1_col2" class="data row1 col2" >65.100000</td>
#       <td id="T_f079a_row1_col3" class="data row1 col3" >60.820000</td>
#       <td id="T_f079a_row1_col4" class="data row1 col4" >55.910000</td>
#       <td id="T_f079a_row1_col5" class="data row1 col5" >62.160000</td>
#     </tr>
#   </tbody>
# </table>

# %%
optimizer_list = [optimizer_class(nu=nu, c_nu=5.0, add_iter_theta=200, generate_Z="normal") for nu in nu_list]
eval = eval_covtype(optimizer_list=optimizer_list)
_, _ = eval.run_track_time()
# Out:
# Optimizers:   0%|          | 0/6 [00:00<?, ?it/s]
# Data:   0%|          | 0/464809 [00:00<?, ?it/s]
# <style type="text/css">
# #T_862cf_row0_col4, #T_862cf_row1_col4 {
#   font-weight: bold;
# }
# </style>
# <table id="T_862cf">
#   <caption>Accuracy on covtype dataset</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_862cf_level0_col0" class="col_heading level0 col0" >USNA ν=0.45 γ=0.75 Z~normal</th>
#       <th id="T_862cf_level0_col1" class="col_heading level0 col1" >USNA ν=0.5 γ=0.75 Z~normal</th>
#       <th id="T_862cf_level0_col2" class="col_heading level0 col2" >USNA ν=0.66 γ=0.75 Z~normal</th>
#       <th id="T_862cf_level0_col3" class="col_heading level0 col3" >USNA ν=0.75 γ=0.75 Z~normal</th>
#       <th id="T_862cf_level0_col4" class="col_heading level0 col4" >USNA ν=1.0 γ=0.75 Z~normal</th>
#       <th id="T_862cf_level0_col5" class="col_heading level0 col5" >USNA ν=1.05 γ=0.75 Z~normal</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_862cf_level0_row0" class="row_heading level0 row0" >Training Accuracy</th>
#       <td id="T_862cf_row0_col0" class="data row0 col0" >36.470000</td>
#       <td id="T_862cf_row0_col1" class="data row0 col1" >36.520000</td>
#       <td id="T_862cf_row0_col2" class="data row0 col2" >36.890000</td>
#       <td id="T_862cf_row0_col3" class="data row0 col3" >37.680000</td>
#       <td id="T_862cf_row0_col4" class="data row0 col4" >66.640000</td>
#       <td id="T_862cf_row0_col5" class="data row0 col5" >66.230000</td>
#     </tr>
#     <tr>
#       <th id="T_862cf_level0_row1" class="row_heading level0 row1" >Test Accuracy</th>
#       <td id="T_862cf_row1_col0" class="data row1 col0" >36.680000</td>
#       <td id="T_862cf_row1_col1" class="data row1 col1" >36.740000</td>
#       <td id="T_862cf_row1_col2" class="data row1 col2" >37.100000</td>
#       <td id="T_862cf_row1_col3" class="data row1 col3" >37.850000</td>
#       <td id="T_862cf_row1_col4" class="data row1 col4" >66.760000</td>
#       <td id="T_862cf_row1_col5" class="data row1 col5" >66.430000</td>
#     </tr>
#   </tbody>
# </table>
