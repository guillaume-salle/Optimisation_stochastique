# %%
import sys
sys.path.append('..')

# %%
from config_simulation import (
    algo,
    simulation_linear_regression,
    simulation_linear_regression_toeplitz,
    simulation_linear_regression_toeplitz_diag,
    simulation_logistic_regression,
    simulation_logistic_regression_toeplitz,
    simulation_logistic_regression_toeplitz_diag,
    simulation_geometric_median,
    simulation_p_means,
    eval_covtype,
    N,
    n,
)

from functools import partial
batch_size = 32
averaged=False
multiply_lr = 'default'
optimizer_list = [
    # SGD
    partial(algo.SGD, averaged=averaged),

    # AdaGrad
    partial(algo.AdaGrad, averaged=averaged, true_ada=True),
    
    # SNA 
    partial(algo.SNA, averaged=averaged),
    
    # USNA 
    partial(algo.USNA, averaged=averaged),

    # Streaming 
    partial(algo.SGD, averaged=averaged, batch_size=batch_size, multiply_lr=multiply_lr),
    partial(algo.AdaGrad, averaged=averaged, true_ada=True, batch_size=batch_size, multiply_lr=multiply_lr),
    partial(algo.SNA, averaged=averaged, batch_size=batch_size, multiply_lr=multiply_lr),
    partial(algo.USNA, averaged=averaged, proj=True, batch_size=batch_size, multiply_lr=multiply_lr),
]

# %%
# N = 2
# n = 1000

# %%
simulation = simulation_linear_regression(optimizer_list=optimizer_list)
simulation.run_multiple(N=N, n=n)
# Out:
# ...
# Data:   0%|          | 0/1000000 [00:00<?, ?it/s]

# %%
simulation = simulation_linear_regression_toeplitz(optimizer_list=optimizer_list)
simulation.run_multiple(N=N, n=n)
# Out:
# ...
# Data:   0%|          | 0/1000000 [00:00<?, ?it/s]

# %%
simulation = simulation_linear_regression_toeplitz_diag(optimizer_list=optimizer_list)
simulation.run_multiple(N=N, n=n)
# Out:
# ...
# Data:   0%|          | 0/1000000 [00:00<?, ?it/s]

# %%
simulation = simulation_logistic_regression(optimizer_list=optimizer_list)
simulation.run_multiple(N=N, n=n)
# Out:
# ...
# Data:   0%|          | 0/1000000 [00:00<?, ?it/s]

# %%
simulation = simulation_logistic_regression_toeplitz(optimizer_list=optimizer_list)
simulation.run_multiple(N=N, n=n)
# Out:
# ...
# Data:   0%|          | 0/1000000 [00:00<?, ?it/s]

# %%
simulation = simulation_logistic_regression_toeplitz_diag(optimizer_list=optimizer_list)
simulation.run_multiple(N=N, n=n)
# Out:
# ...
# Data:   0%|          | 0/1000000 [00:00<?, ?it/s]

# %%
simulation = simulation_geometric_median(optimizer_list=optimizer_list)
simulation.run_multiple(N=N, n=n)
# Out:
# ...
# Data:   0%|          | 0/1000000 [00:00<?, ?it/s]
# Excluded optimizers (diverged) for r=5.0: ['SSGD α=1.0 p=32']
# Excluded optimizers (diverged) for r=5.0: ['SSGD α=1.0 p=32']

# %%
simulation = simulation_p_means(optimizer_list=optimizer_list)
simulation.run_multiple(N=N, n=n)
# Out:
# ...
# Data:   0%|          | 0/1000000 [00:00<?, ?it/s]
# Excluded optimizers (diverged) for r=5.0: ['SSGD α=1.0 p=32']
# Excluded optimizers (diverged) for r=5.0: ['SSGD α=1.0 p=32']

# %%
eval = eval_covtype(optimizer_list=optimizer_list)
times, accuracies, _ = eval.run(metric="accuracy", track_errors=False)
_ = eval.display_accuracies(times, accuracies)
# Out:
# ...
# Data:   0%|          | 0/464809 [00:00<?, ?it/s]
# <style type="text/css">
# #T_bc6a9_row0_col4, #T_bc6a9_row1_col2, #T_bc6a9_row2_col2 {
#   font-weight: bold;
# }
# </style>
# <table id="T_bc6a9">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_bc6a9_level0_col0" class="col_heading level0 col0" >SGD α=1.0</th>
#       <th id="T_bc6a9_level0_col1" class="col_heading level0 col1" >Ada α=1.0</th>
#       <th id="T_bc6a9_level0_col2" class="col_heading level0 col2" >SNA α=1.0 SM</th>
#       <th id="T_bc6a9_level0_col3" class="col_heading level0 col3" >USNA α=1.0</th>
#       <th id="T_bc6a9_level0_col4" class="col_heading level0 col4" >SSGD α=1.0 p=32</th>
#       <th id="T_bc6a9_level0_col5" class="col_heading level0 col5" >SAda α=1.0 p=32</th>
#       <th id="T_bc6a9_level0_col6" class="col_heading level0 col6" >SSNA α=1.0 p=32</th>
#       <th id="T_bc6a9_level0_col7" class="col_heading level0 col7" >SUSNA α=1.0 p=32</th>
#     </tr>
# ...
