# %%
import sys
sys.path.append('..')

# %%
from config_simulation import (
    algo,
    simulation_linear_regression,
    simulation_logistic_regression,
    simulation_geometric_median,
    simulation_spherical_distribution,
    simulation_p_means,
    eval_covtype,
    N,
    n,
)

from functools import partial
optimizer_list = [
    # USNA
    # partial(algo.USNA, averaged=False, lr_add_iter=10),
    # partial(algo.USNA, averaged=False, lr_add_iter=10, new_version=True),
    # partial(algo.USNA, averaged=False, averaged_matrix=True, lr_add_iter=10),

    # UWASNA
    # partial(algo.USNA, averaged=True, lr_add_iter=10),
    # partial(algo.USNA, averaged=True, lr_add_iter=10, new_version=True),
    partial(algo.USNA, averaged=True, lr_const=5.0, lr_add_iter=10),
    # partial(algo.USNA, averaged=True, averaged_matrix=True, lr_add_iter=10),
]

# %%
# N = 2
# n = 1000

# %%
simulation = simulation_linear_regression(optimizer_list=optimizer_list)
simulation.run_multiple_track_errors(N=N, n=n)
# Out:
#   0%|          | 0/20 [00:00<?, ?it/s]
# Optimizers:   0%|          | 0/1 [00:00<?, ?it/s]
# Data:   0%|          | 0/10000 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[4], line 2
#       1 simulation = simulation_linear_regression(optimizer_list=optimizer_list)
# ----> 2 simulation.run_multiple_track_errors(N=N, n=n)
#
# File ~/stochastic_optimization/Notebooks_numpy_online/../simulation/simulation.py:388, in Simulation.run_multiple_track_errors(self, N, n, eval_time)
#     385 self.generate_initial_param(variance=variance)
#     387 # Run the experiment for each optimizer
# --> 388 param_errors, matrix_errors = self.run_track_errors(
#     389     pbars=[optimizer_pbar, data_pbar]
#     390 )
#     392 # Average the errors over the runs
#     393 for name, errors in param_errors.items():
#
# File ~/stochastic_optimization/Notebooks_numpy_online/../simulation/simulation.py:214, in Simulation.run_track_errors(self, pbars)
#     212 # Run the optimizer on the dataset
#     213 for data in data_loader:
# --> 214     optimizer.step(data)
#     215     self.logging_estimation_error(param_errors, matrix_errors, optimizer)
#     216     data_pbar.update(batch_size)
#
# File ~/stochastic_optimization/Notebooks_numpy_online/../algorithms_numpy/USNA.py:77, in USNA.step(self, data)
#      74 self.n_iter += 1
#      76 # Update the hessian estimate and get the gradient from intermediate computation
# ---> 77 grad = self.update_hessian(data)
#      78 if self.averaged_matrix:
#      79     self.update_averaged_matrix()
#
# File ~/stochastic_optimization/Notebooks_numpy_online/../algorithms_numpy/USNA.py:118, in USNA.update_hessian(self, data)
#     116 self.matrix_not_avg[z, :] += -lr_hessian * product
#     117 self.matrix_not_avg[:, z] += -lr_hessian * product
# --> 118 self.matrix_not_avg[z, z] += lr_hessian**2 * np.einsum(
#     119     "i,ij,j", hessian_column, self.matrix_not_avg, hessian_column
#     120 )
#     121 if self.new_version:
#     122     self.matrix_not_avg[z, z] += 2 * lr_hessian * self.param_dim
#
# File ~/AppImage/anaconda3/envs/env/lib/python3.12/site-packages/numpy/core/einsumfunc.py:1001, in _einsum_dispatcher(out, optimize, *operands, **kwargs)
#     997     path = ['einsum_path'] + path
#     998     return (path, path_print)
# -> 1001 def _einsum_dispatcher(*operands, out=None, optimize=None, **kwargs):
#    1002     # Arguably we dispatch on more arguments than we really should; see note in
#    1003     # _einsum_path_dispatcher for why.
#    1004     yield from operands
#    1005     yield out
#
# KeyboardInterrupt:

# %%
simulation.run_multiple_track_time(N=N, n=n)

# %%
simulation = simulation_logistic_regression(optimizer_list=optimizer_list)
simulation.run_multiple_track_errors(N=N, n=n)

# %%
simulation.run_multiple_track_time(N=N, n=n)

# %%
simulation = simulation_geometric_median(optimizer_list=optimizer_list)
simulation.run_multiple_track_errors(N=20, n=n)

# %%
simulation.run_multiple_track_time(N=N, n=n)

# %%
simulation = simulation_spherical_distribution( optimizer_list=optimizer_list)
simulation.run_multiple_track_errors(N=N, n=n)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[10], line 2
#       1 simulation = simulation_spherical_distribution(
# ----> 2     optimizer_list=optimizer_list_without_riccati
#       3 )
#       4 simulation.run_multiple_track_errors(N=N, n=n)
#
# NameError: name 'optimizer_list_without_riccati' is not defined

# %%
simulation.run_multiple_track_time(N=N, n=n)

# %%
simulation = simulation_p_means(optimizer_list=optimizer_list)
simulation.run_multiple_track_errors(N=N, n=n)

# %%
simulation.run_multiple_track_time(N=N, n=n)

# %%
eval = eval_covtype(optimizer_list=optimizer_list)
_, _ = eval.run_track_time()
# Out:
# Optimizers:   0%|          | 0/4 [00:00<?, ?it/s]
# Data:   0%|          | 0/464809 [00:00<?, ?it/s]
# <style type="text/css">
# #T_544e7_row0_col2, #T_544e7_row1_col1, #T_544e7_row2_col2 {
#   font-weight: bold;
# }
# </style>
# <table id="T_544e7">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_544e7_level0_col0" class="col_heading level0 col0" >SGD α=1.0</th>
#       <th id="T_544e7_level0_col1" class="col_heading level0 col1" >SGD α=1.0 c_α=5.0</th>
#       <th id="T_544e7_level0_col2" class="col_heading level0 col2" >SGD α=1.0 c_α=10.0</th>
#       <th id="T_544e7_level0_col3" class="col_heading level0 col3" >SGD α=1.0 c_α=20.0</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_544e7_level0_row0" class="row_heading level0 row0" >Execution Time</th>
#       <td id="T_544e7_row0_col0" class="data row0 col0" >4.042414</td>
#       <td id="T_544e7_row0_col1" class="data row0 col1" >4.067178</td>
#       <td id="T_544e7_row0_col2" class="data row0 col2" >4.023374</td>
#       <td id="T_544e7_row0_col3" class="data row0 col3" >4.097870</td>
#     </tr>
#     <tr>
#       <th id="T_544e7_level0_row1" class="row_heading level0 row1" >Training Accuracy</th>
#       <td id="T_544e7_row1_col0" class="data row1 col0" >0.723650</td>
#       <td id="T_544e7_row1_col1" class="data row1 col1" >0.724082</td>
#       <td id="T_544e7_row1_col2" class="data row1 col2" >0.723790</td>
#       <td id="T_544e7_row1_col3" class="data row1 col3" >0.723940</td>
#     </tr>
#     <tr>
#       <th id="T_544e7_level0_row2" class="row_heading level0 row2" >Test Accuracy</th>
#       <td id="T_544e7_row2_col0" class="data row2 col0" >0.723613</td>
#       <td id="T_544e7_row2_col1" class="data row2 col1" >0.723785</td>
#       <td id="T_544e7_row2_col2" class="data row2 col2" >0.723992</td>
#       <td id="T_544e7_row2_col3" class="data row2 col3" >0.723880</td>
#     </tr>
#   </tbody>
# </table>
