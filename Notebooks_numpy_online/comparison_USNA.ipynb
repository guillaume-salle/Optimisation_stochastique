# %%
import sys
sys.path.append('..')

# %%
from config_simulation import (
    algorithms,
    simulation_linear_regression,
    simulation_logistic_regression,
    simulation_geometric_median,
    simulation_spherical_distribution,
    simulation_p_means,
    eval_covtype,
    N,
    n,
)

SGD = algorithms.SGD
WASGD = algorithms.WASGD
SNARiccati = algorithms.SNARiccati
WASNARiccati = algorithms.WASNARiccati
USNA = algorithms.USNA
UWASNA = algorithms.UWASNA
SNA = algorithms.SNA
WASNA = algorithms.WASNA


optimizer_list = [
    USNA(c_nu=5.0), 
    USNA(c_nu=5.0, sym=False),
    USNA(c_nu=5.0, generate_Z="normal"),
    USNA(c_nu=5.0, generate_Z="canonic deterministic"),
    USNA(c_nu=5.0, sym=False, generate_Z="canonic deterministic"),
    USNA(c_nu=5.0), 
]


import copy
optimizer_list_without_riccati = copy.deepcopy(optimizer_list)

# %%
# N = 2
# n = 1000

# %%
simulation = simulation_linear_regression(optimizer_list=optimizer_list)
simulation.run_multiple_track_errors(N=N, n=n)

# %%
simulation.run_multiple_track_time(N=N, n=n)

# %%
simulation = simulation_logistic_regression(optimizer_list=optimizer_list)
simulation.run_multiple_track_errors(N=N, n=n)

# %%
simulation.run_multiple_track_time(N=N, n=n)

# %%
simulation = simulation_geometric_median(optimizer_list=optimizer_list)
simulation.run_multiple_track_errors(N=20, n=n)

# %%
simulation.run_multiple_track_time(N=N, n=n)

# %%
simulation = simulation_spherical_distribution(
    optimizer_list=optimizer_list_without_riccati
)
simulation.run_multiple_track_errors(N=N, n=n)

# %%
simulation.run_multiple_track_time(N=N, n=n)

# %%
simulation = simulation_p_means(optimizer_list=optimizer_list_without_riccati)
simulation.run_multiple_track_errors(N=N, n=n)

# %%
simulation.run_multiple_track_time(N=N, n=n)

# %%
eval = eval_covtype(optimizer_list=optimizer_list)
_, _ = eval.run_track_time()
# Out:
# Optimizers:   0%|          | 0/6 [00:00<?, ?it/s]
# Data:   0%|          | 0/464809 [00:00<?, ?it/s]
# <style type="text/css">
# #T_eb859_row0_col4, #T_eb859_row1_col4, #T_eb859_row2_col4 {
#   font-weight: bold;
# }
# </style>
# <table id="T_eb859">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_eb859_level0_col0" class="col_heading level0 col0" >USNA</th>
#       <th id="T_eb859_level0_col1" class="col_heading level0 col1" >USNA NS</th>
#       <th id="T_eb859_level0_col2" class="col_heading level0 col2" >USNA Z~normal</th>
#       <th id="T_eb859_level0_col3" class="col_heading level0 col3" >USNA Z~canonic deterministic</th>
#       <th id="T_eb859_level0_col4" class="col_heading level0 col4" >USNA Z~canonic deterministic NS</th>
#       <th id="T_eb859_level0_col5" class="col_heading level0 col5" >USNA bis</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_eb859_level0_row0" class="row_heading level0 row0" >Execution Time</th>
#       <td id="T_eb859_row0_col0" class="data row0 col0" >13.492880</td>
#       <td id="T_eb859_row0_col1" class="data row0 col1" >11.578921</td>
#       <td id="T_eb859_row0_col2" class="data row0 col2" >15.100542</td>
#       <td id="T_eb859_row0_col3" class="data row0 col3" >12.330991</td>
#       <td id="T_eb859_row0_col4" class="data row0 col4" >10.528770</td>
#       <td id="T_eb859_row0_col5" class="data row0 col5" >13.419606</td>
#     </tr>
#     <tr>
#       <th id="T_eb859_level0_row1" class="row_heading level0 row1" >Training Accuracy</th>
#       <td id="T_eb859_row1_col0" class="data row1 col0" >0.579021</td>
#       <td id="T_eb859_row1_col1" class="data row1 col1" >0.591426</td>
#       <td id="T_eb859_row1_col2" class="data row1 col2" >0.576768</td>
#       <td id="T_eb859_row1_col3" class="data row1 col3" >0.517793</td>
#       <td id="T_eb859_row1_col4" class="data row1 col4" >0.617923</td>
#       <td id="T_eb859_row1_col5" class="data row1 col5" >0.590387</td>
#     </tr>
#     <tr>
#       <th id="T_eb859_level0_row2" class="row_heading level0 row2" >Test Accuracy</th>
#       <td id="T_eb859_row2_col0" class="data row2 col0" >0.581465</td>
#       <td id="T_eb859_row2_col1" class="data row2 col1" >0.592893</td>
#       <td id="T_eb859_row2_col2" class="data row2 col2" >0.577550</td>
#       <td id="T_eb859_row2_col3" class="data row2 col3" >0.518188</td>
#       <td id="T_eb859_row2_col4" class="data row2 col4" >0.619511</td>
#       <td id="T_eb859_row2_col5" class="data row2 col5" >0.591250</td>
#     </tr>
#   </tbody>
# </table>
