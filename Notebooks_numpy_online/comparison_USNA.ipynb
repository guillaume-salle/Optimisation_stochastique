# %%
import sys
sys.path.append('..')

# %%
from config_simulation import (
    algo,
    simulation_linear_regression,
    simulation_logistic_regression,
    simulation_geometric_median,
    simulation_spherical_distribution,
    simulation_p_means,
    eval_covtype,
    N,
    n,
)

from functools import partial
optimizer_list = [
    # USNA
    partial(algo.USNA, averaged=False, lr_add_iter=50),
    partial(algo.USNA, averaged=False, lr_add_iter=50, averaged_matrix=True),
    partial(algo.USNA, averaged=False, lr_add_iter=50, new_version=True),
    partial(algo.USNA, averaged=False, lr_add_iter=50, new_version=True, averaged_matrix=True),

    # UWASNA
    partial(algo.USNA, averaged=True, lr_add_iter=50),
    partial(algo.USNA, averaged=True, lr_add_iter=50, averaged_matrix=True),
    partial(algo.USNA, averaged=True, lr_add_iter=50, new_version=True),
    partial(algo.USNA, averaged=True, lr_add_iter=50, new_version=True, averaged_matrix=True),
]

# %%
# N = 2
# n = 1000

# %%
simulation = simulation_linear_regression(optimizer_list=optimizer_list)
simulation.run_multiple_track_errors(N=N, n=n)

# %%
simulation.run_multiple_track_time(N=N, n=n)

# %%
simulation = simulation_logistic_regression(optimizer_list=optimizer_list)
simulation.run_multiple_track_errors(N=N, n=n)

# %%
simulation.run_multiple_track_time(N=N, n=n)

# %%
simulation = simulation_geometric_median(optimizer_list=optimizer_list)
simulation.run_multiple_track_errors(N=20, n=n)

# %%
simulation.run_multiple_track_time(N=N, n=n)

# %%
simulation = simulation_spherical_distribution( optimizer_list=optimizer_list)
simulation.run_multiple_track_errors(N=N, n=n)

# %%
simulation.run_multiple_track_time(N=N, n=n)

# %%
simulation = simulation_p_means(optimizer_list=optimizer_list)
simulation.run_multiple_track_errors(N=N, n=n)

# %%
simulation.run_multiple_track_time(N=N, n=n)

# %%
eval = eval_covtype(optimizer_list=optimizer_list)
_, _ = eval.run_track_time()
# Out:
# Optimizers:   0%|          | 0/8 [00:00<?, ?it/s]
# Data:   0%|          | 0/464809 [00:00<?, ?it/s]
# <style type="text/css">
# #T_76601_row0_col2, #T_76601_row1_col6, #T_76601_row2_col6 {
#   font-weight: bold;
# }
# </style>
# <table id="T_76601">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_76601_level0_col0" class="col_heading level0 col0" >USNA α=1.0</th>
#       <th id="T_76601_level0_col1" class="col_heading level0 col1" >USNA AM α=1.0</th>
#       <th id="T_76601_level0_col2" class="col_heading level0 col2" >USNA NV α=1.0</th>
#       <th id="T_76601_level0_col3" class="col_heading level0 col3" >USNA AM NV α=1.0</th>
#       <th id="T_76601_level0_col4" class="col_heading level0 col4" >UWASNA α=0.67</th>
#       <th id="T_76601_level0_col5" class="col_heading level0 col5" >UWASNA AM α=0.67</th>
#       <th id="T_76601_level0_col6" class="col_heading level0 col6" >UWASNA NV α=0.67</th>
#       <th id="T_76601_level0_col7" class="col_heading level0 col7" >UWASNA AM NV α=0.67</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_76601_level0_row0" class="row_heading level0 row0" >Execution Time</th>
#       <td id="T_76601_row0_col0" class="data row0 col0" >14.586844</td>
#       <td id="T_76601_row0_col1" class="data row0 col1" >16.684709</td>
#       <td id="T_76601_row0_col2" class="data row0 col2" >13.239013</td>
#       <td id="T_76601_row0_col3" class="data row0 col3" >15.229945</td>
#       <td id="T_76601_row0_col4" class="data row0 col4" >15.978567</td>
#       <td id="T_76601_row0_col5" class="data row0 col5" >17.836327</td>
#       <td id="T_76601_row0_col6" class="data row0 col6" >14.184897</td>
#       <td id="T_76601_row0_col7" class="data row0 col7" >16.285534</td>
#     </tr>
#     <tr>
#       <th id="T_76601_level0_row1" class="row_heading level0 row1" >Training Accuracy</th>
#       <td id="T_76601_row1_col0" class="data row1 col0" >0.431153</td>
#       <td id="T_76601_row1_col1" class="data row1 col1" >0.682562</td>
#       <td id="T_76601_row1_col2" class="data row1 col2" >0.439288</td>
#       <td id="T_76601_row1_col3" class="data row1 col3" >0.696125</td>
#       <td id="T_76601_row1_col4" class="data row1 col4" >0.725044</td>
#       <td id="T_76601_row1_col5" class="data row1 col5" >0.710571</td>
#       <td id="T_76601_row1_col6" class="data row1 col6" >0.726754</td>
#       <td id="T_76601_row1_col7" class="data row1 col7" >0.710128</td>
#     </tr>
#     <tr>
#       <th id="T_76601_level0_row2" class="row_heading level0 row2" >Test Accuracy</th>
#       <td id="T_76601_row2_col0" class="data row2 col0" >0.430660</td>
#       <td id="T_76601_row2_col1" class="data row2 col1" >0.682926</td>
#       <td id="T_76601_row2_col2" class="data row2 col2" >0.438810</td>
#       <td id="T_76601_row2_col3" class="data row2 col3" >0.696144</td>
#       <td id="T_76601_row2_col4" class="data row2 col4" >0.728071</td>
#       <td id="T_76601_row2_col5" class="data row2 col5" >0.712667</td>
#       <td id="T_76601_row2_col6" class="data row2 col6" >0.730041</td>
#       <td id="T_76601_row2_col7" class="data row2 col7" >0.712193</td>
#     </tr>
#   </tbody>
# </table>

# %%
eval = eval_covtype(optimizer_list=optimizer_list)
_, _ = eval.run_track_time()
# Out:
# Optimizers:   0%|          | 0/8 [00:00<?, ?it/s]
# Data:   0%|          | 0/464809 [00:00<?, ?it/s]
# <style type="text/css">
# #T_63ffe_row0_col2, #T_63ffe_row1_col6, #T_63ffe_row2_col6 {
#   font-weight: bold;
# }
# </style>
# <table id="T_63ffe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_63ffe_level0_col0" class="col_heading level0 col0" >USNA α=1.0</th>
#       <th id="T_63ffe_level0_col1" class="col_heading level0 col1" >USNA AM α=1.0</th>
#       <th id="T_63ffe_level0_col2" class="col_heading level0 col2" >USNA NV α=1.0</th>
#       <th id="T_63ffe_level0_col3" class="col_heading level0 col3" >USNA AM NV α=1.0</th>
#       <th id="T_63ffe_level0_col4" class="col_heading level0 col4" >UWASNA α=0.67</th>
#       <th id="T_63ffe_level0_col5" class="col_heading level0 col5" >UWASNA AM α=0.67</th>
#       <th id="T_63ffe_level0_col6" class="col_heading level0 col6" >UWASNA NV α=0.67</th>
#       <th id="T_63ffe_level0_col7" class="col_heading level0 col7" >UWASNA AM NV α=0.67</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_63ffe_level0_row0" class="row_heading level0 row0" >Execution Time</th>
#       <td id="T_63ffe_row0_col0" class="data row0 col0" >14.697369</td>
#       <td id="T_63ffe_row0_col1" class="data row0 col1" >16.911543</td>
#       <td id="T_63ffe_row0_col2" class="data row0 col2" >12.990597</td>
#       <td id="T_63ffe_row0_col3" class="data row0 col3" >15.119434</td>
#       <td id="T_63ffe_row0_col4" class="data row0 col4" >15.805921</td>
#       <td id="T_63ffe_row0_col5" class="data row0 col5" >17.890601</td>
#       <td id="T_63ffe_row0_col6" class="data row0 col6" >14.160771</td>
#       <td id="T_63ffe_row0_col7" class="data row0 col7" >16.271685</td>
#     </tr>
#     <tr>
#       <th id="T_63ffe_level0_row1" class="row_heading level0 row1" >Training Accuracy</th>
#       <td id="T_63ffe_row1_col0" class="data row1 col0" >0.702706</td>
#       <td id="T_63ffe_row1_col1" class="data row1 col1" >0.712140</td>
#       <td id="T_63ffe_row1_col2" class="data row1 col2" >0.481163</td>
#       <td id="T_63ffe_row1_col3" class="data row1 col3" >0.714722</td>
#       <td id="T_63ffe_row1_col4" class="data row1 col4" >0.725147</td>
#       <td id="T_63ffe_row1_col5" class="data row1 col5" >0.710602</td>
#       <td id="T_63ffe_row1_col6" class="data row1 col6" >0.726524</td>
#       <td id="T_63ffe_row1_col7" class="data row1 col7" >0.708771</td>
#     </tr>
#     <tr>
#       <th id="T_63ffe_level0_row2" class="row_heading level0 row2" >Test Accuracy</th>
#       <td id="T_63ffe_row2_col0" class="data row2 col0" >0.702753</td>
#       <td id="T_63ffe_row2_col1" class="data row2 col1" >0.712486</td>
#       <td id="T_63ffe_row2_col2" class="data row2 col2" >0.481502</td>
#       <td id="T_63ffe_row2_col3" class="data row2 col3" >0.714982</td>
#       <td id="T_63ffe_row2_col4" class="data row2 col4" >0.728114</td>
#       <td id="T_63ffe_row2_col5" class="data row2 col5" >0.712718</td>
#       <td id="T_63ffe_row2_col6" class="data row2 col6" >0.729861</td>
#       <td id="T_63ffe_row2_col7" class="data row2 col7" >0.710902</td>
#     </tr>
#   </tbody>
# </table>

# %%
eval = eval_covtype(optimizer_list=optimizer_list)
_, _ = eval.run_track_time()
# Out:
# Optimizers:   0%|          | 0/8 [00:00<?, ?it/s]
# Data:   0%|          | 0/464809 [00:00<?, ?it/s]
# <style type="text/css">
# #T_63ffe_row0_col2, #T_63ffe_row1_col6, #T_63ffe_row2_col6 {
#   font-weight: bold;
# }
# </style>
# <table id="T_63ffe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_63ffe_level0_col0" class="col_heading level0 col0" >USNA α=1.0</th>
#       <th id="T_63ffe_level0_col1" class="col_heading level0 col1" >USNA AM α=1.0</th>
#       <th id="T_63ffe_level0_col2" class="col_heading level0 col2" >USNA NV α=1.0</th>
#       <th id="T_63ffe_level0_col3" class="col_heading level0 col3" >USNA AM NV α=1.0</th>
#       <th id="T_63ffe_level0_col4" class="col_heading level0 col4" >UWASNA α=0.67</th>
#       <th id="T_63ffe_level0_col5" class="col_heading level0 col5" >UWASNA AM α=0.67</th>
#       <th id="T_63ffe_level0_col6" class="col_heading level0 col6" >UWASNA NV α=0.67</th>
#       <th id="T_63ffe_level0_col7" class="col_heading level0 col7" >UWASNA AM NV α=0.67</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_63ffe_level0_row0" class="row_heading level0 row0" >Execution Time</th>
#       <td id="T_63ffe_row0_col0" class="data row0 col0" >14.697369</td>
#       <td id="T_63ffe_row0_col1" class="data row0 col1" >16.911543</td>
#       <td id="T_63ffe_row0_col2" class="data row0 col2" >12.990597</td>
#       <td id="T_63ffe_row0_col3" class="data row0 col3" >15.119434</td>
#       <td id="T_63ffe_row0_col4" class="data row0 col4" >15.805921</td>
#       <td id="T_63ffe_row0_col5" class="data row0 col5" >17.890601</td>
#       <td id="T_63ffe_row0_col6" class="data row0 col6" >14.160771</td>
#       <td id="T_63ffe_row0_col7" class="data row0 col7" >16.271685</td>
#     </tr>
#     <tr>
#       <th id="T_63ffe_level0_row1" class="row_heading level0 row1" >Training Accuracy</th>
#       <td id="T_63ffe_row1_col0" class="data row1 col0" >0.702706</td>
#       <td id="T_63ffe_row1_col1" class="data row1 col1" >0.712140</td>
#       <td id="T_63ffe_row1_col2" class="data row1 col2" >0.481163</td>
#       <td id="T_63ffe_row1_col3" class="data row1 col3" >0.714722</td>
#       <td id="T_63ffe_row1_col4" class="data row1 col4" >0.725147</td>
#       <td id="T_63ffe_row1_col5" class="data row1 col5" >0.710602</td>
#       <td id="T_63ffe_row1_col6" class="data row1 col6" >0.726524</td>
#       <td id="T_63ffe_row1_col7" class="data row1 col7" >0.708771</td>
#     </tr>
#     <tr>
#       <th id="T_63ffe_level0_row2" class="row_heading level0 row2" >Test Accuracy</th>
#       <td id="T_63ffe_row2_col0" class="data row2 col0" >0.702753</td>
#       <td id="T_63ffe_row2_col1" class="data row2 col1" >0.712486</td>
#       <td id="T_63ffe_row2_col2" class="data row2 col2" >0.481502</td>
#       <td id="T_63ffe_row2_col3" class="data row2 col3" >0.714982</td>
#       <td id="T_63ffe_row2_col4" class="data row2 col4" >0.728114</td>
#       <td id="T_63ffe_row2_col5" class="data row2 col5" >0.712718</td>
#       <td id="T_63ffe_row2_col6" class="data row2 col6" >0.729861</td>
#       <td id="T_63ffe_row2_col7" class="data row2 col7" >0.710902</td>
#     </tr>
#   </tbody>
# </table>
