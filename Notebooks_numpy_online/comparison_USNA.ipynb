# %%
import sys
sys.path.append('..')

# %%
from config_simulation import (
    algo,
    simulation_linear_regression,
    simulation_logistic_regression,
    simulation_geometric_median,
    simulation_spherical_distribution,
    simulation_p_means,
    eval_covtype,
    N,
    n,
)

optimizer_list = [
    algo.USNA(c_nu=5.0, algo='article', generate_Z="normal"),
    algo.USNA(c_nu=5.0, algo='article'),
    algo.USNA(c_nu=5.0, algo='article v2', generate_Z="normal"),
    algo.USNA(c_nu=5.0, algo='article v2'),
    algo.USNA(c_nu=5.0, algo='right'), 
    algo.USNA(c_nu=5.0, algo='rapport'), 
    algo.USNA(c_nu=5.0, algo='proj'), 
]

import copy
optimizer_list_without_riccati = copy.deepcopy(optimizer_list)

# %%
# N = 2
# n = 1000

# %%
simulation = simulation_linear_regression(optimizer_list=optimizer_list)
simulation.run_multiple_track_errors(N=N, n=n)

# %%
simulation.run_multiple_track_time(N=N, n=n)

# %%
simulation = simulation_logistic_regression(optimizer_list=optimizer_list)
simulation.run_multiple_track_errors(N=N, n=n)

# %%
simulation.run_multiple_track_time(N=N, n=n)

# %%
simulation = simulation_geometric_median(optimizer_list=optimizer_list)
simulation.run_multiple_track_errors(N=20, n=n)

# %%
simulation.run_multiple_track_time(N=N, n=n)

# %%
simulation = simulation_spherical_distribution(
    optimizer_list=optimizer_list_without_riccati
)
simulation.run_multiple_track_errors(N=N, n=n)

# %%
simulation.run_multiple_track_time(N=N, n=n)

# %%
simulation = simulation_p_means(optimizer_list=optimizer_list_without_riccati)
simulation.run_multiple_track_errors(N=N, n=n)

# %%
simulation.run_multiple_track_time(N=N, n=n)

# %%
eval = eval_covtype(optimizer_list=optimizer_list)
_, _ = eval.run_track_time()
# Out:
# Optimizers:   0%|          | 0/7 [00:00<?, ?it/s]
# Data:   0%|          | 0/464809 [00:00<?, ?it/s]
# <style type="text/css">
# #T_55d00_row0_col6, #T_55d00_row1_col6, #T_55d00_row2_col6 {
#   font-weight: bold;
# }
# </style>
# <table id="T_55d00">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_55d00_level0_col0" class="col_heading level0 col0" >USNA α=1.0 Z~normal article</th>
#       <th id="T_55d00_level0_col1" class="col_heading level0 col1" >USNA α=1.0 article</th>
#       <th id="T_55d00_level0_col2" class="col_heading level0 col2" >USNA α=1.0 Z~normal article v2</th>
#       <th id="T_55d00_level0_col3" class="col_heading level0 col3" >USNA α=1.0 article v2</th>
#       <th id="T_55d00_level0_col4" class="col_heading level0 col4" >USNA α=1.0 right</th>
#       <th id="T_55d00_level0_col5" class="col_heading level0 col5" >USNA α=1.0</th>
#       <th id="T_55d00_level0_col6" class="col_heading level0 col6" >USNA α=1.0 proj</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_55d00_level0_row0" class="row_heading level0 row0" >Execution Time</th>
#       <td id="T_55d00_row0_col0" class="data row0 col0" >15.301027</td>
#       <td id="T_55d00_row0_col1" class="data row0 col1" >13.681105</td>
#       <td id="T_55d00_row0_col2" class="data row0 col2" >16.046933</td>
#       <td id="T_55d00_row0_col3" class="data row0 col3" >14.779272</td>
#       <td id="T_55d00_row0_col4" class="data row0 col4" >16.523623</td>
#       <td id="T_55d00_row0_col5" class="data row0 col5" >14.441556</td>
#       <td id="T_55d00_row0_col6" class="data row0 col6" >12.509181</td>
#     </tr>
#     <tr>
#       <th id="T_55d00_level0_row1" class="row_heading level0 row1" >Training Accuracy</th>
#       <td id="T_55d00_row1_col0" class="data row1 col0" >0.541250</td>
#       <td id="T_55d00_row1_col1" class="data row1 col1" >0.592269</td>
#       <td id="T_55d00_row1_col2" class="data row1 col2" >0.637423</td>
#       <td id="T_55d00_row1_col3" class="data row1 col3" >0.729747</td>
#       <td id="T_55d00_row1_col4" class="data row1 col4" >0.676437</td>
#       <td id="T_55d00_row1_col5" class="data row1 col5" >0.718831</td>
#       <td id="T_55d00_row1_col6" class="data row1 col6" >0.734097</td>
#     </tr>
#     <tr>
#       <th id="T_55d00_level0_row2" class="row_heading level0 row2" >Test Accuracy</th>
#       <td id="T_55d00_row2_col0" class="data row2 col0" >0.541165</td>
#       <td id="T_55d00_row2_col1" class="data row2 col1" >0.594339</td>
#       <td id="T_55d00_row2_col2" class="data row2 col2" >0.637436</td>
#       <td id="T_55d00_row2_col3" class="data row2 col3" >0.730687</td>
#       <td id="T_55d00_row2_col4" class="data row2 col4" >0.675611</td>
#       <td id="T_55d00_row2_col5" class="data row2 col5" >0.720059</td>
#       <td id="T_55d00_row2_col6" class="data row2 col6" >0.735867</td>
#     </tr>
#   </tbody>
# </table>
