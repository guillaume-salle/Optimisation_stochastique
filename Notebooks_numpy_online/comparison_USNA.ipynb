# %%
import sys
sys.path.append('..')

# %%
from config_simulation import (
    algorithms,
    simulation_linear_regression,
    simulation_logistic_regression,
    simulation_geometric_median,
    simulation_spherical_distribution,
    simulation_p_means,
    eval_covtype,
)

SGD = algorithms.SGD
WASGD = algorithms.WASGD
SNARiccati = algorithms.SNARiccati
WASNARiccati = algorithms.WASNARiccati
USNA = algorithms.USNA
UWASNA = algorithms.UWASNA
SNA = algorithms.SNA
WASNA = algorithms.WASNA


N = 20
n = 10_000

optimizer_list = [
    USNA(c_nu=5.0), 
    USNA(c_nu=5.0, generate_Z="normal"),
    USNA(c_nu=5.0, generate_Z="canonic deterministic"),
    USNA(c_nu=5.0, sym=False),
]

import copy
optimizer_list_without_riccati = copy.deepcopy(optimizer_list)

# %%
# N = 2
# n = 1000

# %%
simulation = simulation_linear_regression(optimizer_list=optimizer_list)
simulation.run_multiple_track_errors(N=N, n=n)

# %%
simulation.run_multiple_track_time(N=N, n=n)

# %%
simulation = simulation_logistic_regression(optimizer_list=optimizer_list)
simulation.run_multiple_track_errors(N=N, n=n)

# %%
simulation.run_multiple_track_time(N=N, n=n)

# %%
simulation = simulation_geometric_median(optimizer_list=optimizer_list)
simulation.run_multiple_track_errors(N=20, n=n)

# %%
simulation.run_multiple_track_time(N=N, n=n)

# %%
simulation = simulation_spherical_distribution(
    optimizer_list=optimizer_list_without_riccati
)
simulation.run_multiple_track_errors(N=N, n=n)

# %%
simulation.run_multiple_track_time(N=N, n=n)

# %%
simulation = simulation_p_means(optimizer_list=optimizer_list_without_riccati)
simulation.run_multiple_track_errors(N=N, n=n)

# %%
simulation.run_multiple_track_time(N=N, n=n)

# %%
eval = eval_covtype(optimizer_list=optimizer_list)
_, _ = eval.run_track_time()
# Out:
# <style type="text/css">
# #T_f5dc4_row0_col1, #T_f5dc4_row1_col1 {
#   font-weight: bold;
# }
# </style>
# <table id="T_f5dc4">
#   <caption>Accuracy on covtype dataset, d=55, batch_size=d^0</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_f5dc4_level0_col0" class="col_heading level0 col0" >USNA ν=1.0 γ=0.75</th>
#       <th id="T_f5dc4_level0_col1" class="col_heading level0 col1" >USNA ν=1.0 γ=0.75 Z~normal</th>
#       <th id="T_f5dc4_level0_col2" class="col_heading level0 col2" >USNA ν=1.0 γ=0.75 Z~canonic deterministic</th>
#       <th id="T_f5dc4_level0_col3" class="col_heading level0 col3" >USNA ν=1.0 γ=0.75 NS</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_f5dc4_level0_row0" class="row_heading level0 row0" >Training Accuracy</th>
#       <td id="T_f5dc4_row0_col0" class="data row0 col0" >0.559873</td>
#       <td id="T_f5dc4_row0_col1" class="data row0 col1" >0.568588</td>
#       <td id="T_f5dc4_row0_col2" class="data row0 col2" >0.483506</td>
#       <td id="T_f5dc4_row0_col3" class="data row0 col3" >0.480686</td>
#     </tr>
#     <tr>
#       <th id="T_f5dc4_level0_row1" class="row_heading level0 row1" >Test Accuracy</th>
#       <td id="T_f5dc4_row1_col0" class="data row1 col0" >0.561337</td>
#       <td id="T_f5dc4_row1_col1" class="data row1 col1" >0.567326</td>
#       <td id="T_f5dc4_row1_col2" class="data row1 col2" >0.482845</td>
#       <td id="T_f5dc4_row1_col3" class="data row1 col3" >0.480900</td>
#     </tr>
#   </tbody>
# </table>
