# %%
import sys
sys.path.append('..')

# %%
from config_simulation import (
    algo,
    simulation_linear_regression,
    simulation_logistic_regression,
    simulation_geometric_median,
    simulation_spherical_distribution,
    simulation_p_means,
    eval_covtype,
    N,
    n,
)

optimizer_list = [
    algo.UWASNA(c_nu = 5.0),
    algo.UWASNA(c_nu = 5.0, sym=False),
    algo.UWASNA(c_nu = 5.0, compute_hessian_theta_avg=False),
    algo.UWASNA(c_nu = 5.0, use_hessian_avg=False),
    algo.UWASNA(c_nu = 5.0, compute_hessian_theta_avg=False, use_hessian_avg=False),
    algo.UWASNA(c_nu = 5.0, compute_hessian_theta_avg=False, use_hessian_avg=False, sym=False),
]

import copy
optimizer_list_without_riccati = copy.deepcopy(optimizer_list)

# %%
# N = 2
# n = 1000

# %%
simulation = simulation_linear_regression(optimizer_list=optimizer_list)
simulation.run_multiple_track_errors(N=N, n=n)

# %%
simulation.run_multiple_track_time(N=N, n=n)

# %%
simulation = simulation_logistic_regression(optimizer_list=optimizer_list)
simulation.run_multiple_track_errors(N=N, n=n)

# %%
simulation.run_multiple_track_time(N=N, n=n)

# %%
simulation = simulation_geometric_median(optimizer_list=optimizer_list)
simulation.run_multiple_track_errors(N=20, n=n)

# %%
simulation.run_multiple_track_time(N=N, n=n)

# %%
simulation = simulation_spherical_distribution(
    optimizer_list=optimizer_list_without_riccati
)
simulation.run_multiple_track_errors(N=N, n=n)

# %%
simulation.run_multiple_track_time(N=N, n=n)

# %%
simulation = simulation_p_means(optimizer_list=optimizer_list_without_riccati)
simulation.run_multiple_track_errors(N=N, n=n)

# %%
simulation.run_multiple_track_time(N=N, n=n)

# %%
eval = eval_covtype(optimizer_list=optimizer_list)
_, _ = eval.run_track_time()
# Out:
# Optimizers:   0%|          | 0/6 [00:00<?, ?it/s]
# Data:   0%|          | 0/464809 [00:00<?, ?it/s]
# <style type="text/css">
# #T_46540_row0_col5, #T_46540_row1_col1, #T_46540_row2_col4 {
#   font-weight: bold;
# }
# </style>
# <table id="T_46540">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_46540_level0_col0" class="col_heading level0 col0" >UWASNA α=0.75 γ=0.75</th>
#       <th id="T_46540_level0_col1" class="col_heading level0 col1" >UWASNA α=0.75 γ=0.75 NS</th>
#       <th id="T_46540_level0_col2" class="col_heading level0 col2" >UWASNA α=0.75 γ=0.75 NAT</th>
#       <th id="T_46540_level0_col3" class="col_heading level0 col3" >UWASNA α=0.75 γ=0.75 NAH</th>
#       <th id="T_46540_level0_col4" class="col_heading level0 col4" >UWASNA α=0.75 γ=0.75 NAT NAH</th>
#       <th id="T_46540_level0_col5" class="col_heading level0 col5" >UWASNA α=0.75 γ=0.75 NAT NAH NS</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_46540_level0_row0" class="row_heading level0 row0" >Execution Time</th>
#       <td id="T_46540_row0_col0" class="data row0 col0" >22.507128</td>
#       <td id="T_46540_row0_col1" class="data row0 col1" >21.562402</td>
#       <td id="T_46540_row0_col2" class="data row0 col2" >20.157092</td>
#       <td id="T_46540_row0_col3" class="data row0 col3" >19.915957</td>
#       <td id="T_46540_row0_col4" class="data row0 col4" >17.561343</td>
#       <td id="T_46540_row0_col5" class="data row0 col5" >16.844699</td>
#     </tr>
#     <tr>
#       <th id="T_46540_level0_row1" class="row_heading level0 row1" >Training Accuracy</th>
#       <td id="T_46540_row1_col0" class="data row1 col0" >0.726103</td>
#       <td id="T_46540_row1_col1" class="data row1 col1" >0.726509</td>
#       <td id="T_46540_row1_col2" class="data row1 col2" >0.726094</td>
#       <td id="T_46540_row1_col3" class="data row1 col3" >0.725978</td>
#       <td id="T_46540_row1_col4" class="data row1 col4" >0.726363</td>
#       <td id="T_46540_row1_col5" class="data row1 col5" >0.726399</td>
#     </tr>
#     <tr>
#       <th id="T_46540_level0_row2" class="row_heading level0 row2" >Test Accuracy</th>
#       <td id="T_46540_row2_col0" class="data row2 col0" >0.728785</td>
#       <td id="T_46540_row2_col1" class="data row2 col1" >0.729250</td>
#       <td id="T_46540_row2_col2" class="data row2 col2" >0.729052</td>
#       <td id="T_46540_row2_col3" class="data row2 col3" >0.728776</td>
#       <td id="T_46540_row2_col4" class="data row2 col4" >0.729267</td>
#       <td id="T_46540_row2_col5" class="data row2 col5" >0.729241</td>
#     </tr>
#   </tbody>
# </table>
