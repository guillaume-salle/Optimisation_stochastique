# %%
import sys
sys.path.append('..')

# %%
from config_simulation import (
    algo,
    simulation_linear_regression,
    simulation_logistic_regression,
    simulation_geometric_median,
    simulation_spherical_distribution,
    simulation_p_means,
    eval_covtype,
    n,
    N,
    nu_list,
    gamma_list,
)


optimizer_class = algo.WASNA
optimizer_list = [optimizer_class(nu=nu) for nu in nu_list]
optimizer_class_riccati = algo.WASNARiccati
optimizer_list_riccati = [optimizer_class_riccati(nu=nu) for nu in nu_list]

# %%
simulation = simulation_linear_regression(optimizer_list=optimizer_list_riccati)
simulation.run_multiple_track_errors(N=N, n=n)

# %%
simulation = simulation_logistic_regression(optimizer_list=optimizer_list_riccati)
simulation.run_multiple_track_errors(N=N, n=n)

# %%
simulation = simulation_geometric_median(optimizer_list=optimizer_list_riccati)
simulation.run_multiple_track_errors(N=N, n=n)

# %%
simulation = simulation_spherical_distribution(optimizer_list=optimizer_list)
simulation.run_multiple_track_errors(N=N, n=n)

# %%
simulation = simulation_p_means(optimizer_list=optimizer_list)
simulation.run_multiple_track_errors(N=N, n=n)

# %%
eval = eval_covtype(optimizer_list=optimizer_list_riccati)
_, _ = eval.run_track_time()
# Out:
# <style type="text/css">
# #T_72406_row0_col4, #T_72406_row1_col4 {
#   font-weight: bold;
# }
# </style>
# <table id="T_72406">
#   <caption>Accuracy on covtype dataset</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_72406_level0_col0" class="col_heading level0 col0" >WASNARiccati ν=0.45</th>
#       <th id="T_72406_level0_col1" class="col_heading level0 col1" >WASNARiccati ν=0.5</th>
#       <th id="T_72406_level0_col2" class="col_heading level0 col2" >WASNARiccati ν=0.66</th>
#       <th id="T_72406_level0_col3" class="col_heading level0 col3" >WASNARiccati ν=0.75</th>
#       <th id="T_72406_level0_col4" class="col_heading level0 col4" >WASNARiccati ν=1.0</th>
#       <th id="T_72406_level0_col5" class="col_heading level0 col5" >WASNARiccati ν=1.05</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_72406_level0_row0" class="row_heading level0 row0" >Training Accuracy</th>
#       <td id="T_72406_row0_col0" class="data row0 col0" >73.900000</td>
#       <td id="T_72406_row0_col1" class="data row0 col1" >73.660000</td>
#       <td id="T_72406_row0_col2" class="data row0 col2" >70.610000</td>
#       <td id="T_72406_row0_col3" class="data row0 col3" >70.560000</td>
#       <td id="T_72406_row0_col4" class="data row0 col4" >76.400000</td>
#       <td id="T_72406_row0_col5" class="data row0 col5" >76.350000</td>
#     </tr>
#     <tr>
#       <th id="T_72406_level0_row1" class="row_heading level0 row1" >Test Accuracy</th>
#       <td id="T_72406_row1_col0" class="data row1 col0" >73.970000</td>
#       <td id="T_72406_row1_col1" class="data row1 col1" >73.760000</td>
#       <td id="T_72406_row1_col2" class="data row1 col2" >70.670000</td>
#       <td id="T_72406_row1_col3" class="data row1 col3" >70.540000</td>
#       <td id="T_72406_row1_col4" class="data row1 col4" >76.570000</td>
#       <td id="T_72406_row1_col5" class="data row1 col5" >76.470000</td>
#     </tr>
#   </tbody>
# </table>
