# %%
import sys
sys.path.append('..')

# %%
from config_simulation import (
    algorithms,
    simulation_linear_regression,
    simulation_logistic_regression,
    simulation_geometric_median,
    simulation_spherical_distribution,
    simulation_p_means,
    eval_covtype,
    n,
    N,
    nu_list,
    gamma_list,
)


optimizer_class = algorithms.WASNA
optimizer_list = [optimizer_class(nu=nu) for nu in nu_list]
optimizer_class_riccati = algorithms.WASNARiccati
optimizer_list_riccati = [optimizer_class_riccati(nu=nu) for nu in nu_list]

# %%
simulation = simulation_linear_regression(optimizer_list=optimizer_list_riccati)
simulation.run_multiple_datasets(N=N, n=n)

# %%
simulation = simulation_logistic_regression(optimizer_list=optimizer_list_riccati)
simulation.run_multiple_datasets(N=N, n=n)

# %%
simulation = simulation_geometric_median(optimizer_list=optimizer_list_riccati)
simulation.run_multiple_datasets(N=N, n=n)

# %%
simulation = simulation_spherical_distribution(optimizer_list=optimizer_list)
simulation.run_multiple_datasets(N=N, n=n)

# %%
optimizer_list_short = optimizer_list[1:-1]
simulation = simulation_spherical_distribution(optimizer_list=optimizer_list_short)
simulation.run_multiple_datasets(N=N, n=n)

# %%
simulation = simulation_p_means(optimizer_list=optimizer_list)
simulation.run_multiple_datasets(N=N, n=n)

# %%
eval = eval_covtype(optimizer_list=optimizer_list_riccati)
_, _ = eval.run()
# Out:
# <style type="text/css">
# #T_92915_row0_col0, #T_92915_row1_col0 {
#   font-weight: bold;
# }
# </style>
# <table id="T_92915">
#   <caption>Accuracy on covtype dataset</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_92915_level0_col0" class="col_heading level0 col0" >WASNARiccati ν=0.45</th>
#       <th id="T_92915_level0_col1" class="col_heading level0 col1" >WASNARiccati ν=0.5</th>
#       <th id="T_92915_level0_col2" class="col_heading level0 col2" >WASNARiccati ν=0.66</th>
#       <th id="T_92915_level0_col3" class="col_heading level0 col3" >WASNARiccati ν=0.75</th>
#       <th id="T_92915_level0_col4" class="col_heading level0 col4" >WASNARiccati ν=1.0</th>
#       <th id="T_92915_level0_col5" class="col_heading level0 col5" >WASNARiccati ν=1.05</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_92915_level0_row0" class="row_heading level0 row0" >Training Accuracy</th>
#       <td id="T_92915_row0_col0" class="data row0 col0" >77.040000</td>
#       <td id="T_92915_row0_col1" class="data row0 col1" >77.030000</td>
#       <td id="T_92915_row0_col2" class="data row0 col2" >76.960000</td>
#       <td id="T_92915_row0_col3" class="data row0 col3" >76.840000</td>
#       <td id="T_92915_row0_col4" class="data row0 col4" >76.440000</td>
#       <td id="T_92915_row0_col5" class="data row0 col5" >76.360000</td>
#     </tr>
#     <tr>
#       <th id="T_92915_level0_row1" class="row_heading level0 row1" >Test Accuracy</th>
#       <td id="T_92915_row1_col0" class="data row1 col0" >77.210000</td>
#       <td id="T_92915_row1_col1" class="data row1 col1" >77.200000</td>
#       <td id="T_92915_row1_col2" class="data row1 col2" >77.160000</td>
#       <td id="T_92915_row1_col3" class="data row1 col3" >77.010000</td>
#       <td id="T_92915_row1_col4" class="data row1 col4" >76.580000</td>
#       <td id="T_92915_row1_col5" class="data row1 col5" >76.470000</td>
#     </tr>
#   </tbody>
# </table>
