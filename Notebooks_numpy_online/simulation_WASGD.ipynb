# %%
import sys
sys.path.append('..')

# %%
from config_simulation import (
    algorithms,
    simulation_linear_regression,
    simulation_logistic_regression,
    simulation_geometric_median,
    simulation_spherical_distribution,
    simulation_p_means,
    eval_covtype,
    n,
    N,
    nu_list,
    gamma_list,
)


optimizer_class = algorithms.WASGD
nu_list = nu_list[2:] # diverge on linear regression for nu <= 0.5
optimizer_list = [optimizer_class(nu=nu, c_nu=5.0, add_iter_theta=200) for nu in nu_list]

# %%
simulation = simulation_linear_regression(optimizer_list=optimizer_list)
simulation.run_multiple_track_errors(N=N, n=n)

# %%
simulation = simulation_logistic_regression(optimizer_list=optimizer_list)
simulation.run_multiple_track_errors(N=N, n=n)

# %%
simulation = simulation_geometric_median(optimizer_list=optimizer_list)
simulation.run_multiple_track_errors(N=N, n=n)

# %%
simulation = simulation_spherical_distribution(optimizer_list=optimizer_list)
simulation.run_multiple_track_errors(N=N, n=n)

# %%
simulation = simulation_p_means(optimizer_list=optimizer_list)
simulation.run_multiple_track_errors(N=N, n=n)

# %%
eval = eval_covtype(optimizer_list=optimizer_list)
_, _ = eval.run_track_time()
# Out:
# Optimizers:   0%|          | 0/4 [00:00<?, ?it/s]
# Data:   0%|          | 0/464809 [00:00<?, ?it/s]
# <style type="text/css">
# #T_97338_row0_col1, #T_97338_row1_col1 {
#   font-weight: bold;
# }
# </style>
# <table id="T_97338">
#   <caption>Accuracy on covtype dataset</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_97338_level0_col0" class="col_heading level0 col0" >WASGD ν=0.66</th>
#       <th id="T_97338_level0_col1" class="col_heading level0 col1" >WASGD ν=0.75</th>
#       <th id="T_97338_level0_col2" class="col_heading level0 col2" >WASGD ν=1.0</th>
#       <th id="T_97338_level0_col3" class="col_heading level0 col3" >WASGD ν=1.05</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_97338_level0_row0" class="row_heading level0 row0" >Training Accuracy</th>
#       <td id="T_97338_row0_col0" class="data row0 col0" >72.850000</td>
#       <td id="T_97338_row0_col1" class="data row0 col1" >72.900000</td>
#       <td id="T_97338_row0_col2" class="data row0 col2" >72.570000</td>
#       <td id="T_97338_row0_col3" class="data row0 col3" >72.480000</td>
#     </tr>
#     <tr>
#       <th id="T_97338_level0_row1" class="row_heading level0 row1" >Test Accuracy</th>
#       <td id="T_97338_row1_col0" class="data row1 col0" >73.080000</td>
#       <td id="T_97338_row1_col1" class="data row1 col1" >73.170000</td>
#       <td id="T_97338_row1_col2" class="data row1 col2" >72.870000</td>
#       <td id="T_97338_row1_col3" class="data row1 col3" >72.780000</td>
#     </tr>
#   </tbody>
# </table>
