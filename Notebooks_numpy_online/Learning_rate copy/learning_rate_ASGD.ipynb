# %%
import sys
sys.path.extend(['..', '../..'])

# %%
from config_simulation import (
    algo,
    simulation_linear_regression,
    simulation_logistic_regression,
    simulation_geometric_median,
    simulation_spherical_distribution,
    simulation_p_means,
    eval_covtype,
    n,
    N,
    alpha_list,
    gamma_list,
)


optimizer_class = algo.WASGD
alpha_list = alpha_list[2:]
optimizer_list = [optimizer_class(alpha=alpha, c_alpha = 5.0, tau=0.0, add_iter_theta=200) for alpha in alpha_list]

# %%
simulation = simulation_linear_regression(optimizer_list=optimizer_list)
simulation.run_multiple_track_errors(N=N, n=n)
# Out:
#   0%|          | 0/20 [00:00<?, ?it/s]
# Optimizers:   0%|          | 0/4 [00:00<?, ?it/s]
# Data:   0%|          | 0/10000 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[3], line 2
#       1 simulation = simulation_linear_regression(optimizer_list=optimizer_list)
# ----> 2 simulation.run_multiple_track_errors(N=N, n=n)
#
# File ~/stochastic_optimization/Notebooks_numpy_online/Learning_rate/../../simulation/simulation.py:371, in Simulation.run_multiple_track_errors(self, N, n, eval_time)
#     368 self.generate_initial_theta(e=e)
#     370 # Run the experiment for each optimizer
# --> 371 theta_errors, hessian_inv_errors = self.run_track_errors(
#     372     pbars=[optimizer_pbar, data_pbar]
#     373 )
#     375 # Average the errors over the runs
#     376 for name, errors in theta_errors.items():
#
# File ~/stochastic_optimization/Notebooks_numpy_online/Learning_rate/../../simulation/simulation.py:201, in Simulation.run_track_errors(self, pbars)
#     199 for data in data_loader:
#     200     optimizer.step(data, self.theta, self.g)
# --> 201     self.logging_estimation_error(theta_errors, hessian_inv_errors, optimizer)
#     202     data_pbar.update(batch_size)
#     204 optimizer_pbar.update(1)
#
# File ~/stochastic_optimization/Notebooks_numpy_online/Learning_rate/../../simulation/simulation.py:121, in Simulation.logging_estimation_error(self, theta_errors, hessian_inv_errors, optimizer)
#     118     if self.use_torch:
#     119         self.initial_theta = torch.as_tensor(self.initial_theta, device=self.device)
# --> 121 def logging_estimation_error(
#     122     self,
#     123     theta_errors: dict[str, list],
#     124     hessian_inv_errors: dict[str, list],
#     125     optimizer,
#     126 ):
#     127     """
#     128     Log the estimation error of theta and hessian inverse with either numpy or torch tensors
#     129     """
#     130     # Log the estimation error of theta
#
# KeyboardInterrupt:

# %%
simulation = simulation_logistic_regression(optimizer_list=optimizer_list)
simulation.run_multiple_track_errors(N=N, n=n)

# %%
simulation = simulation_geometric_median(optimizer_list=optimizer_list)
simulation.run_multiple_track_errors(N=N, n=n)

# %%
simulation = simulation_spherical_distribution(optimizer_list=optimizer_list)
simulation.run_multiple_track_errors(N=N, n=n)

# %%
simulation = simulation_p_means(optimizer_list=optimizer_list)
simulation.run_multiple_track_errors(N=N, n=n)

# %%
eval = eval_covtype(optimizer_list=optimizer_list)
_, _ = eval.run_track_time()
# Out:
# Optimizers:   0%|          | 0/4 [00:00<?, ?it/s]
# Data:   0%|          | 0/464809 [00:00<?, ?it/s]
# <style type="text/css">
# #T_f0928_row0_col1, #T_f0928_row1_col2 {
#   font-weight: bold;
# }
# </style>
# <table id="T_f0928">
#   <caption>Accuracy on covtype dataset</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_f0928_level0_col0" class="col_heading level0 col0" >ASGD ν=0.66</th>
#       <th id="T_f0928_level0_col1" class="col_heading level0 col1" >ASGD ν=0.75</th>
#       <th id="T_f0928_level0_col2" class="col_heading level0 col2" >ASGD ν=1.0</th>
#       <th id="T_f0928_level0_col3" class="col_heading level0 col3" >ASGD ν=1.05</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_f0928_level0_row0" class="row_heading level0 row0" >Training Accuracy</th>
#       <td id="T_f0928_row0_col0" class="data row0 col0" >72.530000</td>
#       <td id="T_f0928_row0_col1" class="data row0 col1" >72.550000</td>
#       <td id="T_f0928_row0_col2" class="data row0 col2" >72.480000</td>
#       <td id="T_f0928_row0_col3" class="data row0 col3" >72.390000</td>
#     </tr>
#     <tr>
#       <th id="T_f0928_level0_row1" class="row_heading level0 row1" >Test Accuracy</th>
#       <td id="T_f0928_row1_col0" class="data row1 col0" >72.710000</td>
#       <td id="T_f0928_row1_col1" class="data row1 col1" >72.740000</td>
#       <td id="T_f0928_row1_col2" class="data row1 col2" >72.750000</td>
#       <td id="T_f0928_row1_col3" class="data row1 col3" >72.660000</td>
#     </tr>
#   </tbody>
# </table>
