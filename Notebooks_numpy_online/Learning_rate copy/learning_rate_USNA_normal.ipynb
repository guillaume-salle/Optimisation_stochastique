# %%
import sys
sys.path.extend(['..', '../..'])

# %%
from config_simulation import (
    algo,
    simulation_linear_regression,
    simulation_logistic_regression,
    simulation_geometric_median,
    simulation_spherical_distribution,
    simulation_p_means,
    eval_covtype,
    n,
    N,
    alpha_list,
    gamma_list,
)


optimizer_class = algo.USNA
optimizer_list = [optimizer_class(gamma=gamma, c_nu=5.0, add_iter_theta=200, generate_Z="normal") for gamma in gamma_list]

# %%
simulation = simulation_linear_regression(optimizer_list=optimizer_list)
simulation.run_multiple_track_errors(N=N, n=n)

# %%
simulation = simulation_logistic_regression(optimizer_list=optimizer_list)
simulation.run_multiple_track_errors(N=N, n=n)

# %%
simulation = simulation_geometric_median(optimizer_list=optimizer_list)
simulation.run_multiple_track_errors(N=N, n=n)

# %%
simulation = simulation_spherical_distribution(optimizer_list=optimizer_list)
simulation.run_multiple_track_errors(N=N, n=n)

# %%
simulation = simulation_p_means(optimizer_list=optimizer_list)
simulation.run_multiple_track_errors(N=N, n=n)

# %%
eval = eval_covtype(optimizer_list=optimizer_list)
_, _ = eval.run_track_time()
# Out:
# Optimizers:   0%|          | 0/6 [00:00<?, ?it/s]
# Data:   0%|          | 0/464809 [00:00<?, ?it/s]
# <style type="text/css">
# #T_ee34e_row0_col0, #T_ee34e_row1_col1 {
#   font-weight: bold;
# }
# </style>
# <table id="T_ee34e">
#   <caption>Accuracy on covtype dataset</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_ee34e_level0_col0" class="col_heading level0 col0" >USNA ν=1.0 γ=0.45 Z~normal</th>
#       <th id="T_ee34e_level0_col1" class="col_heading level0 col1" >USNA ν=1.0 γ=0.5 Z~normal</th>
#       <th id="T_ee34e_level0_col2" class="col_heading level0 col2" >USNA ν=1.0 γ=0.66 Z~normal</th>
#       <th id="T_ee34e_level0_col3" class="col_heading level0 col3" >USNA ν=1.0 γ=0.75 Z~normal</th>
#       <th id="T_ee34e_level0_col4" class="col_heading level0 col4" >USNA ν=1.0 γ=1.0 Z~normal</th>
#       <th id="T_ee34e_level0_col5" class="col_heading level0 col5" >USNA ν=1.0 γ=1.05 Z~normal</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_ee34e_level0_row0" class="row_heading level0 row0" >Training Accuracy</th>
#       <td id="T_ee34e_row0_col0" class="data row0 col0" >68.050000</td>
#       <td id="T_ee34e_row0_col1" class="data row0 col1" >67.890000</td>
#       <td id="T_ee34e_row0_col2" class="data row0 col2" >64.650000</td>
#       <td id="T_ee34e_row0_col3" class="data row0 col3" >59.480000</td>
#       <td id="T_ee34e_row0_col4" class="data row0 col4" >59.700000</td>
#       <td id="T_ee34e_row0_col5" class="data row0 col5" >63.640000</td>
#     </tr>
#     <tr>
#       <th id="T_ee34e_level0_row1" class="row_heading level0 row1" >Test Accuracy</th>
#       <td id="T_ee34e_row1_col0" class="data row1 col0" >68.240000</td>
#       <td id="T_ee34e_row1_col1" class="data row1 col1" >68.260000</td>
#       <td id="T_ee34e_row1_col2" class="data row1 col2" >64.870000</td>
#       <td id="T_ee34e_row1_col3" class="data row1 col3" >59.570000</td>
#       <td id="T_ee34e_row1_col4" class="data row1 col4" >59.460000</td>
#       <td id="T_ee34e_row1_col5" class="data row1 col5" >63.580000</td>
#     </tr>
#   </tbody>
# </table>

# %%
optimizer_list = [optimizer_class(nu=nu, c_nu=5.0, add_iter_theta=200, generate_Z="normal") for nu in nu_list]
eval = eval_covtype(optimizer_list=optimizer_list)
_, _ = eval.run_track_time()
# Out:
# Optimizers:   0%|          | 0/6 [00:00<?, ?it/s]
# Data:   0%|          | 0/464809 [00:00<?, ?it/s]
# <style type="text/css">
# #T_2866a_row0_col3, #T_2866a_row1_col3 {
#   font-weight: bold;
# }
# </style>
# <table id="T_2866a">
#   <caption>Accuracy on covtype dataset</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_2866a_level0_col0" class="col_heading level0 col0" >USNA ν=0.45 γ=0.75 Z~normal</th>
#       <th id="T_2866a_level0_col1" class="col_heading level0 col1" >USNA ν=0.5 γ=0.75 Z~normal</th>
#       <th id="T_2866a_level0_col2" class="col_heading level0 col2" >USNA ν=0.66 γ=0.75 Z~normal</th>
#       <th id="T_2866a_level0_col3" class="col_heading level0 col3" >USNA ν=0.75 γ=0.75 Z~normal</th>
#       <th id="T_2866a_level0_col4" class="col_heading level0 col4" >USNA ν=1.0 γ=0.75 Z~normal</th>
#       <th id="T_2866a_level0_col5" class="col_heading level0 col5" >USNA ν=1.05 γ=0.75 Z~normal</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_2866a_level0_row0" class="row_heading level0 row0" >Training Accuracy</th>
#       <td id="T_2866a_row0_col0" class="data row0 col0" >69.820000</td>
#       <td id="T_2866a_row0_col1" class="data row0 col1" >52.290000</td>
#       <td id="T_2866a_row0_col2" class="data row0 col2" >68.410000</td>
#       <td id="T_2866a_row0_col3" class="data row0 col3" >70.660000</td>
#       <td id="T_2866a_row0_col4" class="data row0 col4" >49.470000</td>
#       <td id="T_2866a_row0_col5" class="data row0 col5" >43.750000</td>
#     </tr>
#     <tr>
#       <th id="T_2866a_level0_row1" class="row_heading level0 row1" >Test Accuracy</th>
#       <td id="T_2866a_row1_col0" class="data row1 col0" >69.880000</td>
#       <td id="T_2866a_row1_col1" class="data row1 col1" >52.450000</td>
#       <td id="T_2866a_row1_col2" class="data row1 col2" >68.570000</td>
#       <td id="T_2866a_row1_col3" class="data row1 col3" >70.960000</td>
#       <td id="T_2866a_row1_col4" class="data row1 col4" >49.360000</td>
#       <td id="T_2866a_row1_col5" class="data row1 col5" >43.640000</td>
#     </tr>
#   </tbody>
# </table>
