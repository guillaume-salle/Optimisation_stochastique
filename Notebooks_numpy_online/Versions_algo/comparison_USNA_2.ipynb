# %%
import sys
sys.path.extend(['..', '../..'])

# %%
from config_simulation import (
    algo,
    simulation_linear_regression,
    simulation_logistic_regression,
    simulation_geometric_median,
    simulation_spherical_distribution,
    simulation_p_means,
    eval_covtype,
    N,
    n,
)

from functools import partial
optimizer_list = [
    # USNA
    # partial(algo.USNA, averaged=False, lr_add_iter=10),
    # partial(algo.USNA, averaged=False, lr_add_iter=10, new_version=True),
    # partial(algo.USNA, averaged=False, lr_add_iter=10, new_version=True, compute_hessian_param_avg=True),

    # UWASNA
    # partial(algo.USNA, averaged=True, lr_add_iter=10),
    partial(algo.USNA, averaged=True, lr_add_iter=10, new_version=True),
    partial(algo.USNA, averaged=True, lr_add_iter=10, new_version=True, compute_hessian_param_avg=True),
]

# %%
# N = 2
# n = 1000

# %%
simulation = simulation_linear_regression(optimizer_list=optimizer_list)
simulation.run_multiple_track_errors(N=N, n=n)

# %%
simulation.run_multiple_track_time(N=N, n=n)

# %%
simulation = simulation_logistic_regression(optimizer_list=optimizer_list)
simulation.run_multiple_track_errors(N=N, n=n)

# %%
simulation.run_multiple_track_time(N=N, n=n)

# %%
simulation = simulation_geometric_median(optimizer_list=optimizer_list)
simulation.run_multiple_track_errors(N=20, n=n)

# %%
simulation.run_multiple_track_time(N=N, n=n)

# %%
simulation = simulation_spherical_distribution( optimizer_list=optimizer_list)
simulation.run_multiple_track_errors(N=N, n=n)

# %%
simulation.run_multiple_track_time(N=N, n=n)

# %%
simulation = simulation_p_means(optimizer_list=optimizer_list)
simulation.run_multiple_track_errors(N=N, n=n)

# %%
simulation.run_multiple_track_time(N=N, n=n)

# %%
eval = eval_covtype(optimizer_list=optimizer_list)
_, _ = eval.run_track_time()
# Out:
# Optimizers:   0%|          | 0/2 [00:00<?, ?it/s]
# Data:   0%|          | 0/464809 [00:00<?, ?it/s]
# <style type="text/css">
# #T_8997e_row0_col0, #T_8997e_row1_col1, #T_8997e_row2_col1 {
#   font-weight: bold;
# }
# </style>
# <table id="T_8997e">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_8997e_level0_col0" class="col_heading level0 col0" >UWASNA NV α=0.67</th>
#       <th id="T_8997e_level0_col1" class="col_heading level0 col1" >UWASNA AP NV α=0.67</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_8997e_level0_row0" class="row_heading level0 row0" >Execution Time</th>
#       <td id="T_8997e_row0_col0" class="data row0 col0" >13.496047</td>
#       <td id="T_8997e_row0_col1" class="data row0 col1" >15.545455</td>
#     </tr>
#     <tr>
#       <th id="T_8997e_level0_row1" class="row_heading level0 row1" >Training Accuracy</th>
#       <td id="T_8997e_row1_col0" class="data row1 col0" >0.573446</td>
#       <td id="T_8997e_row1_col1" class="data row1 col1" >0.725274</td>
#     </tr>
#     <tr>
#       <th id="T_8997e_level0_row2" class="row_heading level0 row2" >Test Accuracy</th>
#       <td id="T_8997e_row2_col0" class="data row2 col0" >0.573333</td>
#       <td id="T_8997e_row2_col1" class="data row2 col1" >0.728251</td>
#     </tr>
#   </tbody>
# </table>

# %%
eval = eval_covtype(optimizer_list=optimizer_list)
_, _ = eval.run_track_time()
# Out:
# Optimizers:   0%|          | 0/2 [00:00<?, ?it/s]
# Data:   0%|          | 0/464809 [00:00<?, ?it/s]
# <style type="text/css">
# #T_20dd4_row0_col0, #T_20dd4_row1_col1, #T_20dd4_row2_col0 {
#   font-weight: bold;
# }
# </style>
# <table id="T_20dd4">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_20dd4_level0_col0" class="col_heading level0 col0" >UWASNA NV α=0.67</th>
#       <th id="T_20dd4_level0_col1" class="col_heading level0 col1" >UWASNA AP NV α=0.67</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_20dd4_level0_row0" class="row_heading level0 row0" >Execution Time</th>
#       <td id="T_20dd4_row0_col0" class="data row0 col0" >15.061364</td>
#       <td id="T_20dd4_row0_col1" class="data row0 col1" >16.245806</td>
#     </tr>
#     <tr>
#       <th id="T_20dd4_level0_row1" class="row_heading level0 row1" >Training Accuracy</th>
#       <td id="T_20dd4_row1_col0" class="data row1 col0" >0.725378</td>
#       <td id="T_20dd4_row1_col1" class="data row1 col1" >0.725446</td>
#     </tr>
#     <tr>
#       <th id="T_20dd4_level0_row2" class="row_heading level0 row2" >Test Accuracy</th>
#       <td id="T_20dd4_row2_col0" class="data row2 col0" >0.728544</td>
#       <td id="T_20dd4_row2_col1" class="data row2 col1" >0.728363</td>
#     </tr>
#   </tbody>
# </table>

# %%
eval = eval_covtype(optimizer_list=optimizer_list)
_, _ = eval.run_track_time()
# Out:
# Optimizers:   0%|          | 0/2 [00:00<?, ?it/s]
# Data:   0%|          | 0/464809 [00:00<?, ?it/s]
# <style type="text/css">
# #T_87d0f_row0_col0, #T_87d0f_row1_col0, #T_87d0f_row2_col0 {
#   font-weight: bold;
# }
# </style>
# <table id="T_87d0f">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_87d0f_level0_col0" class="col_heading level0 col0" >UWASNA NV α=0.67</th>
#       <th id="T_87d0f_level0_col1" class="col_heading level0 col1" >UWASNA AP NV α=0.67</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_87d0f_level0_row0" class="row_heading level0 row0" >Execution Time</th>
#       <td id="T_87d0f_row0_col0" class="data row0 col0" >13.957319</td>
#       <td id="T_87d0f_row0_col1" class="data row0 col1" >16.341023</td>
#     </tr>
#     <tr>
#       <th id="T_87d0f_level0_row1" class="row_heading level0 row1" >Training Accuracy</th>
#       <td id="T_87d0f_row1_col0" class="data row1 col0" >0.728803</td>
#       <td id="T_87d0f_row1_col1" class="data row1 col1" >0.727116</td>
#     </tr>
#     <tr>
#       <th id="T_87d0f_level0_row2" class="row_heading level0 row2" >Test Accuracy</th>
#       <td id="T_87d0f_row2_col0" class="data row2 col0" >0.731995</td>
#       <td id="T_87d0f_row2_col1" class="data row2 col1" >0.730868</td>
#     </tr>
#   </tbody>
# </table>
