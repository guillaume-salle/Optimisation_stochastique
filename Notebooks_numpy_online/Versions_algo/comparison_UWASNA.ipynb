# %%
import sys
sys.path.extend(['..', '../..'])

# %%
from config_simulation import (
    algo,
    simulation_linear_regression,
    simulation_logistic_regression,
    simulation_geometric_median,
    simulation_spherical_distribution,
    simulation_p_means,
    eval_covtype,
    N,
    n,
)

from functools import partial
optimizer_list = [
    partial(algo.USNA_variants, averaged=True, lr_add_iter=50, algo="article"),
    partial(algo.USNA_variants, averaged=True, lr_add_iter=50, algo="article_v2"),
    partial(algo.USNA, averaged=True, lr_add_iter=50),
    partial(algo.USNA, averaged=True, lr_add_iter=50, proj=True),
]

# %%
# N = 2
# n = 1000
N = 10

# %%
simulation = simulation_linear_regression(optimizer_list=optimizer_list)
simulation.run_multiple_track_errors(N=N, n=n)

# %%
simulation.run_multiple_track_time(N=N, n=n)

# %%
simulation = simulation_logistic_regression(optimizer_list=optimizer_list)
simulation.run_multiple_track_errors(N=N, n=n)

# %%
simulation.run_multiple_track_time(N=N, n=n)
# Out:
#   0%|          | 0/10 [00:00<?, ?it/s]
# Optimizers:   0%|          | 0/4 [00:00<?, ?it/s]
# Data:   0%|          | 0/10000 [00:00<?, ?it/s]

# %%
simulation = simulation_geometric_median(optimizer_list=optimizer_list)
simulation.run_multiple_track_errors(N=20, n=n)
# Out:
#   0%|          | 0/20 [00:00<?, ?it/s]
# Optimizers:   0%|          | 0/4 [00:00<?, ?it/s]
# Data:   0%|          | 0/10000 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[12], line 2
#       1 simulation = simulation_geometric_median(optimizer_list=optimizer_list)
# ----> 2 simulation.run_multiple_track_errors(N=20, n=n)
#
# File ~/Optimisation_stochastique/Notebooks_numpy_online/../simulation/simulation.py:388, in Simulation.run_multiple_track_errors(self, N, n, eval_time)
#     385 self.generate_initial_param(variance=variance)
#     387 # Run the experiment for each optimizer
# --> 388 param_errors, matrix_errors = self.run_track_errors(
#     389     pbars=[optimizer_pbar, data_pbar]
#     390 )
#     392 # Average the errors over the runs
#     393 for name, errors in param_errors.items():
#
# File ~/Optimisation_stochastique/Notebooks_numpy_online/../simulation/simulation.py:214, in Simulation.run_track_errors(self, pbars)
#     212 # Run the optimizer on the dataset
#     213 for data in data_loader:
# --> 214     optimizer.step(data)
#     215     self.logging_estimation_error(param_errors, matrix_errors, optimizer)
#     216     data_pbar.update(batch_size)
#
# File ~/Optimisation_stochastique/Notebooks_numpy_online/../algorithms_numpy/USNA.py:88, in USNA.step(self, data)
#      85 self.param_not_averaged -= learning_rate_theta * self.matrix @ grad
#      87 if self.averaged:
# ---> 88     self.update_averaged_param()
#
# File ~/Optimisation_stochastique/Notebooks_numpy_online/../algorithms_numpy/BaseOptimizer.py:62, in BaseOptimizer.update_averaged_param(self)
#      53     """
#      54     Perform one optimization step.
#      55     Should be implemented by subclasses.
#    (...)
#      58         data (np.ndarray | Tuple[np.ndarray, np.ndarray]): The input data for the optimization step.
#      59     """
#      60     pass
# ---> 62 def update_averaged_param(self) -> None:
#      63     """
#      64     Update the averaged parameter using the current parameter and the sum of weights.
#      65     """
#      66     if self.log_weight > 0:
#
# KeyboardInterrupt:

# %%
simulation.run_multiple_track_time(N=N, n=n)

# %%
simulation = simulation_spherical_distribution( optimizer_list=optimizer_list)
simulation.run_multiple_track_errors(N=N, n=n)

# %%
simulation.run_multiple_track_time(N=N, n=n)

# %%
simulation = simulation_p_means(optimizer_list=optimizer_list)
simulation.run_multiple_track_errors(N=N, n=n)

# %%
simulation.run_multiple_track_time(N=N, n=n)

# %%
eval = eval_covtype(optimizer_list=optimizer_list)
_, _ = eval.run_track_time()
# Out:
# Optimizers:   0%|          | 0/4 [00:00<?, ?it/s]
# Data:   0%|          | 0/464809 [00:00<?, ?it/s]
# <style type="text/css">
# #T_51bc4_row0_col2, #T_51bc4_row1_col2, #T_51bc4_row2_col2 {
#   font-weight: bold;
# }
# </style>
# <table id="T_51bc4">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_51bc4_level0_col0" class="col_heading level0 col0" >UWASNA α=0.67</th>
#       <th id="T_51bc4_level0_col1" class="col_heading level0 col1" >UWASNA AM α=0.67</th>
#       <th id="T_51bc4_level0_col2" class="col_heading level0 col2" >UWASNA NV α=0.67</th>
#       <th id="T_51bc4_level0_col3" class="col_heading level0 col3" >UWASNA AM NV α=0.67</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_51bc4_level0_row0" class="row_heading level0 row0" >Execution Time</th>
#       <td id="T_51bc4_row0_col0" class="data row0 col0" >15.770836</td>
#       <td id="T_51bc4_row0_col1" class="data row0 col1" >17.808724</td>
#       <td id="T_51bc4_row0_col2" class="data row0 col2" >14.201689</td>
#       <td id="T_51bc4_row0_col3" class="data row0 col3" >15.994095</td>
#     </tr>
#     <tr>
#       <th id="T_51bc4_level0_row1" class="row_heading level0 row1" >Training Accuracy</th>
#       <td id="T_51bc4_row1_col0" class="data row1 col0" >0.724936</td>
#       <td id="T_51bc4_row1_col1" class="data row1 col1" >0.725431</td>
#       <td id="T_51bc4_row1_col2" class="data row1 col2" >0.726107</td>
#       <td id="T_51bc4_row1_col3" class="data row1 col3" >0.725027</td>
#     </tr>
#     <tr>
#       <th id="T_51bc4_level0_row2" class="row_heading level0 row2" >Test Accuracy</th>
#       <td id="T_51bc4_row2_col0" class="data row2 col0" >0.728002</td>
#       <td id="T_51bc4_row2_col1" class="data row2 col1" >0.728286</td>
#       <td id="T_51bc4_row2_col2" class="data row2 col2" >0.728699</td>
#       <td id="T_51bc4_row2_col3" class="data row2 col3" >0.728105</td>
#     </tr>
#   </tbody>
# </table>

# %%
eval = eval_covtype(optimizer_list=optimizer_list)
_, _ = eval.run_track_time()
# Out:
# Optimizers:   0%|          | 0/4 [00:00<?, ?it/s]
# Data:   0%|          | 0/464809 [00:00<?, ?it/s]
# <style type="text/css">
# #T_f0524_row0_col2, #T_f0524_row1_col0, #T_f0524_row2_col0 {
#   font-weight: bold;
# }
# </style>
# <table id="T_f0524">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_f0524_level0_col0" class="col_heading level0 col0" >UWASNA α=0.67</th>
#       <th id="T_f0524_level0_col1" class="col_heading level0 col1" >UWASNA AM α=0.67</th>
#       <th id="T_f0524_level0_col2" class="col_heading level0 col2" >UWASNA NV α=0.67</th>
#       <th id="T_f0524_level0_col3" class="col_heading level0 col3" >UWASNA AM NV α=0.67</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_f0524_level0_row0" class="row_heading level0 row0" >Execution Time</th>
#       <td id="T_f0524_row0_col0" class="data row0 col0" >15.789460</td>
#       <td id="T_f0524_row0_col1" class="data row0 col1" >17.836441</td>
#       <td id="T_f0524_row0_col2" class="data row0 col2" >14.305256</td>
#       <td id="T_f0524_row0_col3" class="data row0 col3" >16.415249</td>
#     </tr>
#     <tr>
#       <th id="T_f0524_level0_row1" class="row_heading level0 row1" >Training Accuracy</th>
#       <td id="T_f0524_row1_col0" class="data row1 col0" >0.728125</td>
#       <td id="T_f0524_row1_col1" class="data row1 col1" >0.725483</td>
#       <td id="T_f0524_row1_col2" class="data row1 col2" >0.725259</td>
#       <td id="T_f0524_row1_col3" class="data row1 col3" >0.726096</td>
#     </tr>
#     <tr>
#       <th id="T_f0524_level0_row2" class="row_heading level0 row2" >Test Accuracy</th>
#       <td id="T_f0524_row2_col0" class="data row2 col0" >0.731315</td>
#       <td id="T_f0524_row2_col1" class="data row2 col1" >0.728441</td>
#       <td id="T_f0524_row2_col2" class="data row2 col2" >0.728260</td>
#       <td id="T_f0524_row2_col3" class="data row2 col3" >0.729060</td>
#     </tr>
#   </tbody>
# </table>

# %%
eval = eval_covtype(optimizer_list=optimizer_list)
_, _ = eval.run_track_time()
# Out:
# Optimizers:   0%|          | 0/4 [00:00<?, ?it/s]
# Data:   0%|          | 0/464809 [00:00<?, ?it/s]
# <style type="text/css">
# #T_dbcd2_row0_col2, #T_dbcd2_row1_col2, #T_dbcd2_row2_col2 {
#   font-weight: bold;
# }
# </style>
# <table id="T_dbcd2">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_dbcd2_level0_col0" class="col_heading level0 col0" >UWASNA α=0.67</th>
#       <th id="T_dbcd2_level0_col1" class="col_heading level0 col1" >UWASNA AM α=0.67</th>
#       <th id="T_dbcd2_level0_col2" class="col_heading level0 col2" >UWASNA NV α=0.67</th>
#       <th id="T_dbcd2_level0_col3" class="col_heading level0 col3" >UWASNA AM NV α=0.67</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_dbcd2_level0_row0" class="row_heading level0 row0" >Execution Time</th>
#       <td id="T_dbcd2_row0_col0" class="data row0 col0" >15.885544</td>
#       <td id="T_dbcd2_row0_col1" class="data row0 col1" >17.984020</td>
#       <td id="T_dbcd2_row0_col2" class="data row0 col2" >14.373893</td>
#       <td id="T_dbcd2_row0_col3" class="data row0 col3" >16.035389</td>
#     </tr>
#     <tr>
#       <th id="T_dbcd2_level0_row1" class="row_heading level0 row1" >Training Accuracy</th>
#       <td id="T_dbcd2_row1_col0" class="data row1 col0" >0.725565</td>
#       <td id="T_dbcd2_row1_col1" class="data row1 col1" >0.725218</td>
#       <td id="T_dbcd2_row1_col2" class="data row1 col2" >0.726838</td>
#       <td id="T_dbcd2_row1_col3" class="data row1 col3" >0.725502</td>
#     </tr>
#     <tr>
#       <th id="T_dbcd2_level0_row2" class="row_heading level0 row2" >Test Accuracy</th>
#       <td id="T_dbcd2_row2_col0" class="data row2 col0" >0.728518</td>
#       <td id="T_dbcd2_row2_col1" class="data row2 col1" >0.728217</td>
#       <td id="T_dbcd2_row2_col2" class="data row2 col2" >0.729792</td>
#       <td id="T_dbcd2_row2_col3" class="data row2 col3" >0.728708</td>
#     </tr>
#   </tbody>
# </table>
