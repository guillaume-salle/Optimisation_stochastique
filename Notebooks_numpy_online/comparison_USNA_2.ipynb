# %%
import sys
sys.path.append('..')

# %%
from config_simulation import (
    algo,
    simulation_linear_regression,
    simulation_logistic_regression,
    simulation_geometric_median,
    simulation_spherical_distribution,
    simulation_p_means,
    eval_covtype,
    N,
    n,
)

optimizer_list = [
    algo.USNA(c_nu=5.0),
    algo.USNA(c_nu=5.0, algo="right", generate_Z="normal"),
    algo.USNA(c_nu=5.0, generate_Z="canonic deterministic"),
    algo.USNA(c_nu=5.0, sym=False),
]


import copy
optimizer_list_without_riccati = copy.deepcopy(optimizer_list)

# %%
# N = 2
# n = 1000

# %%
simulation = simulation_linear_regression(optimizer_list=optimizer_list)
simulation.run_multiple_track_errors(N=N, n=n)

# %%
simulation.run_multiple_track_time(N=N, n=n)

# %%
simulation = simulation_logistic_regression(optimizer_list=optimizer_list)
simulation.run_multiple_track_errors(N=N, n=n)

# %%
simulation.run_multiple_track_time(N=N, n=n)

# %%
simulation = simulation_geometric_median(optimizer_list=optimizer_list)
simulation.run_multiple_track_errors(N=20, n=n)

# %%
simulation.run_multiple_track_time(N=N, n=n)

# %%
simulation = simulation_spherical_distribution(
    optimizer_list=optimizer_list_without_riccati
)
simulation.run_multiple_track_errors(N=N, n=n)

# %%
simulation.run_multiple_track_time(N=N, n=n)

# %%
simulation = simulation_p_means(optimizer_list=optimizer_list_without_riccati)
simulation.run_multiple_track_errors(N=N, n=n)

# %%
simulation.run_multiple_track_time(N=N, n=n)

# %%
eval = eval_covtype(optimizer_list=optimizer_list)
_, _ = eval.run_track_time()
# Out:
# Optimizers:   0%|          | 0/4 [00:00<?, ?it/s]
# Data:   0%|          | 0/464809 [00:00<?, ?it/s]
# <style type="text/css">
# #T_895e6_row0_col2, #T_895e6_row1_col2, #T_895e6_row2_col3 {
#   font-weight: bold;
# }
# </style>
# <table id="T_895e6">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_895e6_level0_col0" class="col_heading level0 col0" >USNA α=1.0</th>
#       <th id="T_895e6_level0_col1" class="col_heading level0 col1" >USNA α=1.0 Z~normal right</th>
#       <th id="T_895e6_level0_col2" class="col_heading level0 col2" >USNA α=1.0 Z~canonic deterministic</th>
#       <th id="T_895e6_level0_col3" class="col_heading level0 col3" >USNA α=1.0 NS</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_895e6_level0_row0" class="row_heading level0 row0" >Execution Time</th>
#       <td id="T_895e6_row0_col0" class="data row0 col0" >14.331968</td>
#       <td id="T_895e6_row0_col1" class="data row0 col1" >20.629511</td>
#       <td id="T_895e6_row0_col2" class="data row0 col2" >12.977806</td>
#       <td id="T_895e6_row0_col3" class="data row0 col3" >13.624307</td>
#     </tr>
#     <tr>
#       <th id="T_895e6_level0_row1" class="row_heading level0 row1" >Training Accuracy</th>
#       <td id="T_895e6_row1_col0" class="data row1 col0" >0.722792</td>
#       <td id="T_895e6_row1_col1" class="data row1 col1" >0.563739</td>
#       <td id="T_895e6_row1_col2" class="data row1 col2" >0.746582</td>
#       <td id="T_895e6_row1_col3" class="data row1 col3" >0.746535</td>
#     </tr>
#     <tr>
#       <th id="T_895e6_level0_row2" class="row_heading level0 row2" >Test Accuracy</th>
#       <td id="T_895e6_row2_col0" class="data row2 col0" >0.723518</td>
#       <td id="T_895e6_row2_col1" class="data row2 col1" >0.565820</td>
#       <td id="T_895e6_row2_col2" class="data row2 col2" >0.748208</td>
#       <td id="T_895e6_row2_col3" class="data row2 col3" >0.748337</td>
#     </tr>
#   </tbody>
# </table>
