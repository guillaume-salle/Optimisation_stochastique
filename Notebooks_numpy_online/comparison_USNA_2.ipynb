# %%
import sys
sys.path.append('..')

# %%
from config_simulation import (
    algorithms,
    simulation_linear_regression,
    simulation_logistic_regression,
    simulation_geometric_median,
    simulation_spherical_distribution,
    simulation_p_means,
    eval_covtype,
    N,
    n,
)

SGD = algorithms.SGD
WASGD = algorithms.WASGD
SNARiccati = algorithms.SNARiccati
WASNARiccati = algorithms.WASNARiccati
USNA = algorithms.USNA
UWASNA = algorithms.UWASNA
SNA = algorithms.SNA
WASNA = algorithms.WASNA


optimizer_list = [
    USNA(c_nu=5.0, algo="article", generate_Z="normal"),
    USNA(c_nu=5.0, algo="article", generate_Z="canonic deterministic"),
    USNA(c_nu=5.0, algo="bruno", generate_Z="canonic deterministic"),
    USNA(c_nu=5.0, algo="guillaume", generate_Z="canonic deterministic"),
]


import copy
optimizer_list_without_riccati = copy.deepcopy(optimizer_list)

# %%
# N = 2
# n = 1000

# %%
simulation = simulation_linear_regression(optimizer_list=optimizer_list)
simulation.run_multiple_track_errors(N=N, n=n)

# %%
simulation.run_multiple_track_time(N=N, n=n)

# %%
simulation = simulation_logistic_regression(optimizer_list=optimizer_list)
simulation.run_multiple_track_errors(N=N, n=n)

# %%
simulation.run_multiple_track_time(N=N, n=n)

# %%
simulation = simulation_geometric_median(optimizer_list=optimizer_list)
simulation.run_multiple_track_errors(N=20, n=n)

# %%
simulation.run_multiple_track_time(N=N, n=n)

# %%
simulation = simulation_spherical_distribution(
    optimizer_list=optimizer_list_without_riccati
)
simulation.run_multiple_track_errors(N=N, n=n)

# %%
simulation.run_multiple_track_time(N=N, n=n)

# %%
simulation = simulation_p_means(optimizer_list=optimizer_list_without_riccati)
simulation.run_multiple_track_errors(N=N, n=n)

# %%
simulation.run_multiple_track_time(N=N, n=n)

# %%
eval = eval_covtype(optimizer_list=optimizer_list)
_, _ = eval.run_track_time()
# Out:
# Optimizers:   0%|          | 0/3 [00:00<?, ?it/s]
# Data:   0%|          | 0/464809 [00:00<?, ?it/s]
# <style type="text/css">
# #T_5b0a9_row0_col2, #T_5b0a9_row1_col2, #T_5b0a9_row2_col2 {
#   font-weight: bold;
# }
# </style>
# <table id="T_5b0a9">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_5b0a9_level0_col0" class="col_heading level0 col0" >USNA Z~canonic deterministic</th>
#       <th id="T_5b0a9_level0_col1" class="col_heading level0 col1" >USNA Z~canonic deterministic bruno</th>
#       <th id="T_5b0a9_level0_col2" class="col_heading level0 col2" >USNA Z~canonic deterministic guillaume</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_5b0a9_level0_row0" class="row_heading level0 row0" >Execution Time</th>
#       <td id="T_5b0a9_row0_col0" class="data row0 col0" >13.535576</td>
#       <td id="T_5b0a9_row0_col1" class="data row0 col1" >19.195037</td>
#       <td id="T_5b0a9_row0_col2" class="data row0 col2" >8.591574</td>
#     </tr>
#     <tr>
#       <th id="T_5b0a9_level0_row1" class="row_heading level0 row1" >Training Accuracy</th>
#       <td id="T_5b0a9_row1_col0" class="data row1 col0" >0.517793</td>
#       <td id="T_5b0a9_row1_col1" class="data row1 col1" >0.629672</td>
#       <td id="T_5b0a9_row1_col2" class="data row1 col2" >0.726946</td>
#     </tr>
#     <tr>
#       <th id="T_5b0a9_level0_row2" class="row_heading level0 row2" >Test Accuracy</th>
#       <td id="T_5b0a9_row2_col0" class="data row2 col0" >0.518188</td>
#       <td id="T_5b0a9_row2_col1" class="data row2 col1" >0.631834</td>
#       <td id="T_5b0a9_row2_col2" class="data row2 col2" >0.728785</td>
#     </tr>
#   </tbody>
# </table>
