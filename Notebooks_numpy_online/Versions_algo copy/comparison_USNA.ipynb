# %%
import sys
sys.path.extend(['..', '../..'])

# %%
from config_simulation import (
    algo,
    simulation_linear_regression,
    simulation_logistic_regression,
    simulation_geometric_median,
    simulation_spherical_distribution,
    simulation_p_means,
    eval_covtype,
    N,
    n,
)

from functools import partial
optimizer_list = [
    partial(algo.USNA_variants, averaged=False, lr_add_iter=50, algo="article"),
    partial(algo.USNA_variants, averaged=False, lr_add_iter=50, algo="article_v2"),
    partial(algo.USNA, averaged=False, lr_add_iter=50),
    partial(algo.USNA, averaged=False, lr_add_iter=50, proj=True),
]

# %%
# N = 2
# n = 1000
N = 10

# %%
simulation = simulation_linear_regression(optimizer_list=optimizer_list)
simulation.run_multiple_track_errors(N=N, n=n)

# %%
simulation.run_multiple_track_time(N=N, n=n)

# %%
simulation = simulation_logistic_regression(optimizer_list=optimizer_list)
simulation.run_multiple_track_errors(N=N, n=n)

# %%
simulation.run_multiple_track_time(N=N, n=n)

# %%
simulation = simulation_geometric_median(optimizer_list=optimizer_list)
simulation.run_multiple_track_errors(N=20, n=n)

# %%
simulation.run_multiple_track_time(N=N, n=n)

# %%
simulation = simulation_spherical_distribution( optimizer_list=optimizer_list)
simulation.run_multiple_track_errors(N=N, n=n)

# %%
simulation.run_multiple_track_time(N=N, n=n)

# %%
simulation = simulation_p_means(optimizer_list=optimizer_list)
simulation.run_multiple_track_errors(N=N, n=n)

# %%
simulation.run_multiple_track_time(N=N, n=n)

# %%
eval = eval_covtype(optimizer_list=optimizer_list)
_, _ = eval.run_track_time()
# Out:
# Optimizers:   0%|          | 0/4 [00:00<?, ?it/s]
# Data:   0%|          | 0/464809 [00:00<?, ?it/s]
# <style type="text/css">
# #T_d8952_row0_col1, #T_d8952_row1_col0, #T_d8952_row2_col0 {
#   font-weight: bold;
# }
# </style>
# <table id="T_d8952">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_d8952_level0_col0" class="col_heading level0 col0" >USNA α=1.0 article</th>
#       <th id="T_d8952_level0_col1" class="col_heading level0 col1" >USNA α=1.0 article_v2</th>
#       <th id="T_d8952_level0_col2" class="col_heading level0 col2" >USNA α=1.0</th>
#       <th id="T_d8952_level0_col3" class="col_heading level0 col3" >USNA P α=1.0</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_d8952_level0_row0" class="row_heading level0 row0" >Execution Time</th>
#       <td id="T_d8952_row0_col0" class="data row0 col0" >10.416443</td>
#       <td id="T_d8952_row0_col1" class="data row0 col1" >10.313131</td>
#       <td id="T_d8952_row0_col2" class="data row0 col2" >13.566329</td>
#       <td id="T_d8952_row0_col3" class="data row0 col3" >12.234149</td>
#     </tr>
#     <tr>
#       <th id="T_d8952_level0_row1" class="row_heading level0 row1" >Training Accuracy</th>
#       <td id="T_d8952_row1_col0" class="data row1 col0" >0.608254</td>
#       <td id="T_d8952_row1_col1" class="data row1 col1" >0.553812</td>
#       <td id="T_d8952_row1_col2" class="data row1 col2" >0.583209</td>
#       <td id="T_d8952_row1_col3" class="data row1 col3" >0.595436</td>
#     </tr>
#     <tr>
#       <th id="T_d8952_level0_row2" class="row_heading level0 row2" >Test Accuracy</th>
#       <td id="T_d8952_row2_col0" class="data row2 col0" >0.609279</td>
#       <td id="T_d8952_row2_col1" class="data row2 col1" >0.554925</td>
#       <td id="T_d8952_row2_col2" class="data row2 col2" >0.584735</td>
#       <td id="T_d8952_row2_col3" class="data row2 col3" >0.595165</td>
#     </tr>
#   </tbody>
# </table>

# %%
eval = eval_covtype(optimizer_list=optimizer_list)
_, _ = eval.run_track_time()
# Out:
# Optimizers:   0%|          | 0/4 [00:00<?, ?it/s]
# Data:   0%|          | 0/464809 [00:00<?, ?it/s]
# <style type="text/css">
# #T_0132a_row0_col1, #T_0132a_row1_col0, #T_0132a_row2_col0 {
#   font-weight: bold;
# }
# </style>
# <table id="T_0132a">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_0132a_level0_col0" class="col_heading level0 col0" >USNA α=1.0 article</th>
#       <th id="T_0132a_level0_col1" class="col_heading level0 col1" >USNA α=1.0 article_v2</th>
#       <th id="T_0132a_level0_col2" class="col_heading level0 col2" >USNA α=1.0</th>
#       <th id="T_0132a_level0_col3" class="col_heading level0 col3" >USNA P α=1.0</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_0132a_level0_row0" class="row_heading level0 row0" >Execution Time</th>
#       <td id="T_0132a_row0_col0" class="data row0 col0" >10.181045</td>
#       <td id="T_0132a_row0_col1" class="data row0 col1" >10.114975</td>
#       <td id="T_0132a_row0_col2" class="data row0 col2" >13.350390</td>
#       <td id="T_0132a_row0_col3" class="data row0 col3" >11.852000</td>
#     </tr>
#     <tr>
#       <th id="T_0132a_level0_row1" class="row_heading level0 row1" >Training Accuracy</th>
#       <td id="T_0132a_row1_col0" class="data row1 col0" >0.679406</td>
#       <td id="T_0132a_row1_col1" class="data row1 col1" >0.531694</td>
#       <td id="T_0132a_row1_col2" class="data row1 col2" >0.467766</td>
#       <td id="T_0132a_row1_col3" class="data row1 col3" >0.620149</td>
#     </tr>
#     <tr>
#       <th id="T_0132a_level0_row2" class="row_heading level0 row2" >Test Accuracy</th>
#       <td id="T_0132a_row2_col0" class="data row2 col0" >0.680766</td>
#       <td id="T_0132a_row2_col1" class="data row2 col1" >0.532404</td>
#       <td id="T_0132a_row2_col2" class="data row2 col2" >0.468663</td>
#       <td id="T_0132a_row2_col3" class="data row2 col3" >0.621464</td>
#     </tr>
#   </tbody>
# </table>

# %%
eval = eval_covtype(optimizer_list=optimizer_list)
_, _ = eval.run_track_time()
# Out:
# Optimizers:   0%|          | 0/4 [00:00<?, ?it/s]
# Data:   0%|          | 0/464809 [00:00<?, ?it/s]
# <style type="text/css">
# #T_376a0_row0_col0, #T_376a0_row1_col1, #T_376a0_row2_col1 {
#   font-weight: bold;
# }
# </style>
# <table id="T_376a0">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_376a0_level0_col0" class="col_heading level0 col0" >USNA α=1.0 article</th>
#       <th id="T_376a0_level0_col1" class="col_heading level0 col1" >USNA α=1.0 article_v2</th>
#       <th id="T_376a0_level0_col2" class="col_heading level0 col2" >USNA α=1.0</th>
#       <th id="T_376a0_level0_col3" class="col_heading level0 col3" >USNA P α=1.0</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_376a0_level0_row0" class="row_heading level0 row0" >Execution Time</th>
#       <td id="T_376a0_row0_col0" class="data row0 col0" >10.180316</td>
#       <td id="T_376a0_row0_col1" class="data row0 col1" >10.195527</td>
#       <td id="T_376a0_row0_col2" class="data row0 col2" >13.472660</td>
#       <td id="T_376a0_row0_col3" class="data row0 col3" >11.968616</td>
#     </tr>
#     <tr>
#       <th id="T_376a0_level0_row1" class="row_heading level0 row1" >Training Accuracy</th>
#       <td id="T_376a0_row1_col0" class="data row1 col0" >0.553212</td>
#       <td id="T_376a0_row1_col1" class="data row1 col1" >0.688623</td>
#       <td id="T_376a0_row1_col2" class="data row1 col2" >0.605683</td>
#       <td id="T_376a0_row1_col3" class="data row1 col3" >0.683192</td>
#     </tr>
#     <tr>
#       <th id="T_376a0_level0_row2" class="row_heading level0 row2" >Test Accuracy</th>
#       <td id="T_376a0_row2_col0" class="data row2 col0" >0.554487</td>
#       <td id="T_376a0_row2_col1" class="data row2 col1" >0.689982</td>
#       <td id="T_376a0_row2_col2" class="data row2 col2" >0.608134</td>
#       <td id="T_376a0_row2_col3" class="data row2 col3" >0.683752</td>
#     </tr>
#   </tbody>
# </table>
