# %%
import sys
sys.path.append('..')

# %%
from config_simulation import (
    algo,
    simulation_linear_regression,
    simulation_linear_regression_toeplitz,
    simulation_linear_regression_toeplitz_diag,
    simulation_logistic_regression,
    simulation_logistic_regression_toeplitz,
    simulation_logistic_regression_toeplitz_diag,
    simulation_geometric_median,
    simulation_spherical_distribution,
    simulation_p_means,
    eval_covtype,
    N,
    n,
)

from functools import partial
optimizer_list = [
    # WASGD
    partial(algo.SGD, averaged=True, lr_add_iter=10),

    # WAAdaGrad
    partial(algo.AdaGrad, averaged=True, lr_add_iter=10),
    
    # SNA and WASNA
    partial(algo.SNA, lr_add_iter=10),
    partial(algo.SNA, averaged=True, lr_add_iter=10),
    
    # USNA and UWASNA
    partial(algo.USNA, lr_add_iter=10, proj=True),
    partial(algo.USNA, averaged=True, lr_add_iter=10, proj=True),
]

# %%
# N = 2
# n = 1000

# %%
simulation = simulation_linear_regression(optimizer_list=optimizer_list)
simulation.run_multiple_track_errors(N=N, n=n)
# Out:
#   0%|          | 0/10 [00:00<?, ?it/s]
# Optimizers:   0%|          | 0/6 [00:00<?, ?it/s]
# Data:   0%|          | 0/10000 [00:00<?, ?it/s]

# %%
simulation.run_multiple_track_time(N=N, n=n)
# Out:
#   0%|          | 0/10 [00:00<?, ?it/s]
# Optimizers:   0%|          | 0/6 [00:00<?, ?it/s]
# Data:   0%|          | 0/10000 [00:00<?, ?it/s]

# %%
simulation = simulation_linear_regression_toeplitz(optimizer_list=optimizer_list)
simulation.run_multiple_track_errors(N=N, n=n)
# Out:
#   0%|          | 0/10 [00:00<?, ?it/s]
# Optimizers:   0%|          | 0/6 [00:00<?, ?it/s]
# Data:   0%|          | 0/10000 [00:00<?, ?it/s]

# %%
simulation.run_multiple_track_time(N=N, n=n)
# Out:
#   0%|          | 0/10 [00:00<?, ?it/s]
# Optimizers:   0%|          | 0/6 [00:00<?, ?it/s]
# Data:   0%|          | 0/10000 [00:00<?, ?it/s]

# %%
simulation = simulation_linear_regression_toeplitz_diag(optimizer_list=optimizer_list)
simulation.run_multiple_track_errors(N=N, n=n)
# Out:
#   0%|          | 0/10 [00:00<?, ?it/s]
# Optimizers:   0%|          | 0/6 [00:00<?, ?it/s]
# Data:   0%|          | 0/10000 [00:00<?, ?it/s]

# %%
simulation.run_multiple_track_time(N=N, n=n)
# Out:
#   0%|          | 0/10 [00:00<?, ?it/s]
# Optimizers:   0%|          | 0/6 [00:00<?, ?it/s]
# Data:   0%|          | 0/10000 [00:00<?, ?it/s]
# Excluded optimizers (diverged) for r=1: ['ASGD α=0.67', 'ASNA α=0.67']
# Excluded optimizers (diverged) for r=5: ['ASGD α=0.67', 'ASNA α=0.67']

# %%
simulation = simulation_logistic_regression(optimizer_list=optimizer_list)
simulation.run_multiple_track_errors(N=N, n=n)
# Out:
#   0%|          | 0/10 [00:00<?, ?it/s]
# Optimizers:   0%|          | 0/6 [00:00<?, ?it/s]
# Data:   0%|          | 0/10000 [00:00<?, ?it/s]

# %%
simulation.run_multiple_track_time(N=N, n=n)
# Out:
#   0%|          | 0/10 [00:00<?, ?it/s]
# Optimizers:   0%|          | 0/6 [00:00<?, ?it/s]
# Data:   0%|          | 0/10000 [00:00<?, ?it/s]

# %%
simulation = simulation_logistic_regression_toeplitz(optimizer_list=optimizer_list)
simulation.run_multiple_track_errors(N=N, n=n)
# Out:
#   0%|          | 0/10 [00:00<?, ?it/s]
# Optimizers:   0%|          | 0/6 [00:00<?, ?it/s]
# Data:   0%|          | 0/10000 [00:00<?, ?it/s]

# %%
simulation.run_multiple_track_time(N=N, n=n)
# Out:
#   0%|          | 0/10 [00:00<?, ?it/s]
# Optimizers:   0%|          | 0/6 [00:00<?, ?it/s]
# Data:   0%|          | 0/10000 [00:00<?, ?it/s]

# %%
simulation = simulation_logistic_regression_toeplitz_diag(optimizer_list=optimizer_list)
simulation.run_multiple_track_errors(N=N, n=n)
# Out:
#   0%|          | 0/10 [00:00<?, ?it/s]
# Optimizers:   0%|          | 0/6 [00:00<?, ?it/s]
# Data:   0%|          | 0/10000 [00:00<?, ?it/s]

# %%
simulation.run_multiple_track_time(N=N, n=n)
# Out:
#   0%|          | 0/10 [00:00<?, ?it/s]
# Optimizers:   0%|          | 0/6 [00:00<?, ?it/s]
# Data:   0%|          | 0/10000 [00:00<?, ?it/s]

# %%
simulation = simulation_geometric_median(optimizer_list=optimizer_list)
simulation.run_multiple_track_errors(N=N, n=n)
# Out:
#   0%|          | 0/10 [00:00<?, ?it/s]
# Optimizers:   0%|          | 0/6 [00:00<?, ?it/s]
# Data:   0%|          | 0/10000 [00:00<?, ?it/s]

# %%
simulation.run_multiple_track_time(N=N, n=n)
# Out:
#   0%|          | 0/10 [00:00<?, ?it/s]
# Optimizers:   0%|          | 0/6 [00:00<?, ?it/s]
# Data:   0%|          | 0/10000 [00:00<?, ?it/s]
# Excluded optimizers (diverged) for r=5: ['USNA P α=1.0']

# %%
simulation = simulation_spherical_distribution( optimizer_list=optimizer_list)
simulation.run_multiple_track_errors(N=N, n=n)
# Out:
#   0%|          | 0/10 [00:00<?, ?it/s]
# Optimizers:   0%|          | 0/6 [00:00<?, ?it/s]
# Data:   0%|          | 0/10000 [00:00<?, ?it/s]

# %%
simulation.run_multiple_track_time(N=N, n=n)
# Out:
#   0%|          | 0/10 [00:00<?, ?it/s]
# Optimizers:   0%|          | 0/6 [00:00<?, ?it/s]
# Data:   0%|          | 0/10000 [00:00<?, ?it/s]
# Excluded optimizers (diverged) for r=1: ['USNA P α=1.0']

# %%
simulation = simulation_p_means(optimizer_list=optimizer_list)
simulation.run_multiple_track_errors(N=N, n=n)
# Out:
#   0%|          | 0/10 [00:00<?, ?it/s]
# Optimizers:   0%|          | 0/6 [00:00<?, ?it/s]
# Data:   0%|          | 0/10000 [00:00<?, ?it/s]

# %%
simulation.run_multiple_track_time(N=N, n=n)
# Out:
#   0%|          | 0/10 [00:00<?, ?it/s]
# Optimizers:   0%|          | 0/6 [00:00<?, ?it/s]
# Data:   0%|          | 0/10000 [00:00<?, ?it/s]

# %%
eval = eval_covtype(optimizer_list=optimizer_list)
_, _ = eval.run_track_time()
# Out:
# Optimizers:   0%|          | 0/6 [00:00<?, ?it/s]
# Data:   0%|          | 0/464809 [00:00<?, ?it/s]
# <style type="text/css">
# #T_31a34_row0_col0, #T_31a34_row1_col2, #T_31a34_row2_col2 {
#   font-weight: bold;
# }
# </style>
# <table id="T_31a34">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_31a34_level0_col0" class="col_heading level0 col0" >ASGD α=0.67</th>
#       <th id="T_31a34_level0_col1" class="col_heading level0 col1" >AAda α=0.67</th>
#       <th id="T_31a34_level0_col2" class="col_heading level0 col2" >SNA α=1.0</th>
#       <th id="T_31a34_level0_col3" class="col_heading level0 col3" >ASNA α=0.67</th>
#       <th id="T_31a34_level0_col4" class="col_heading level0 col4" >USNA P α=1.0</th>
#       <th id="T_31a34_level0_col5" class="col_heading level0 col5" >AUSNA P α=0.67</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_31a34_level0_row0" class="row_heading level0 row0" >Execution Time</th>
#       <td id="T_31a34_row0_col0" class="data row0 col0" >5.363338</td>
#       <td id="T_31a34_row0_col1" class="data row0 col1" >5.814654</td>
#       <td id="T_31a34_row0_col2" class="data row0 col2" >15.795778</td>
#       <td id="T_31a34_row0_col3" class="data row0 col3" >16.940655</td>
#       <td id="T_31a34_row0_col4" class="data row0 col4" >12.011960</td>
#       <td id="T_31a34_row0_col5" class="data row0 col5" >13.449124</td>
#     </tr>
#     <tr>
#       <th id="T_31a34_level0_row1" class="row_heading level0 row1" >Training Accuracy</th>
#       <td id="T_31a34_row1_col0" class="data row1 col0" >0.729334</td>
#       <td id="T_31a34_row1_col1" class="data row1 col1" >0.759678</td>
#       <td id="T_31a34_row1_col2" class="data row1 col2" >0.765708</td>
#       <td id="T_31a34_row1_col3" class="data row1 col3" >0.723973</td>
#       <td id="T_31a34_row1_col4" class="data row1 col4" >0.743531</td>
#       <td id="T_31a34_row1_col5" class="data row1 col5" >0.724833</td>
#     </tr>
#     <tr>
#       <th id="T_31a34_level0_row2" class="row_heading level0 row2" >Test Accuracy</th>
#       <td id="T_31a34_row2_col0" class="data row2 col0" >0.731702</td>
#       <td id="T_31a34_row2_col1" class="data row2 col1" >0.761702</td>
#       <td id="T_31a34_row2_col2" class="data row2 col2" >0.767201</td>
#       <td id="T_31a34_row2_col3" class="data row2 col3" >0.728458</td>
#       <td id="T_31a34_row2_col4" class="data row2 col4" >0.744946</td>
#       <td id="T_31a34_row2_col5" class="data row2 col5" >0.728088</td>
#     </tr>
#   </tbody>
# </table>

# %%
eval = eval_covtype(optimizer_list=optimizer_list)
_, _ = eval.run_track_time()
# Out:
# Optimizers:   0%|          | 0/6 [00:00<?, ?it/s]
# Data:   0%|          | 0/464809 [00:00<?, ?it/s]
# <style type="text/css">
# #T_fa17d_row0_col0, #T_fa17d_row1_col2, #T_fa17d_row2_col2 {
#   font-weight: bold;
# }
# </style>
# <table id="T_fa17d">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_fa17d_level0_col0" class="col_heading level0 col0" >ASGD α=0.67</th>
#       <th id="T_fa17d_level0_col1" class="col_heading level0 col1" >AAda α=0.67</th>
#       <th id="T_fa17d_level0_col2" class="col_heading level0 col2" >SNA α=1.0</th>
#       <th id="T_fa17d_level0_col3" class="col_heading level0 col3" >ASNA α=0.67</th>
#       <th id="T_fa17d_level0_col4" class="col_heading level0 col4" >USNA P α=1.0</th>
#       <th id="T_fa17d_level0_col5" class="col_heading level0 col5" >AUSNA P α=0.67</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_fa17d_level0_row0" class="row_heading level0 row0" >Execution Time</th>
#       <td id="T_fa17d_row0_col0" class="data row0 col0" >5.314557</td>
#       <td id="T_fa17d_row0_col1" class="data row0 col1" >5.876876</td>
#       <td id="T_fa17d_row0_col2" class="data row0 col2" >16.031685</td>
#       <td id="T_fa17d_row0_col3" class="data row0 col3" >17.061521</td>
#       <td id="T_fa17d_row0_col4" class="data row0 col4" >12.213721</td>
#       <td id="T_fa17d_row0_col5" class="data row0 col5" >13.342377</td>
#     </tr>
#     <tr>
#       <th id="T_fa17d_level0_row1" class="row_heading level0 row1" >Training Accuracy</th>
#       <td id="T_fa17d_row1_col0" class="data row1 col0" >0.729334</td>
#       <td id="T_fa17d_row1_col1" class="data row1 col1" >0.759678</td>
#       <td id="T_fa17d_row1_col2" class="data row1 col2" >0.765708</td>
#       <td id="T_fa17d_row1_col3" class="data row1 col3" >0.723973</td>
#       <td id="T_fa17d_row1_col4" class="data row1 col4" >0.713540</td>
#       <td id="T_fa17d_row1_col5" class="data row1 col5" >0.725694</td>
#     </tr>
#     <tr>
#       <th id="T_fa17d_level0_row2" class="row_heading level0 row2" >Test Accuracy</th>
#       <td id="T_fa17d_row2_col0" class="data row2 col0" >0.731702</td>
#       <td id="T_fa17d_row2_col1" class="data row2 col1" >0.761702</td>
#       <td id="T_fa17d_row2_col2" class="data row2 col2" >0.767201</td>
#       <td id="T_fa17d_row2_col3" class="data row2 col3" >0.728458</td>
#       <td id="T_fa17d_row2_col4" class="data row2 col4" >0.715722</td>
#       <td id="T_fa17d_row2_col5" class="data row2 col5" >0.729146</td>
#     </tr>
#   </tbody>
# </table>
