# %%
import sys
sys.path.append('..')

# %%
from config_simulation import (
    algorithms,
    simulation_linear_regression,
    simulation_logistic_regression,
    simulation_geometric_median,
    simulation_spherical_distribution,
    simulation_p_means,
    eval_covtype,
    n,
    N,
    nu_list,
    gamma_list,
)


optimizer_class = algorithms.SNA
optimizer_list = [algorithms.SNA(nu=nu) for nu in nu_list]
optimizer_class_riccati = algorithms.SNARiccati
optimizer_list_riccati = [optimizer_class_riccati(nu=nu) for nu in nu_list]

# %%
simulation = simulation_linear_regression(optimizer_list=optimizer_list_riccati)
simulation.run_multiple_datasets(N=N, n=n)

# %%
simulation = simulation_logistic_regression(optimizer_list=optimizer_list_riccati)
simulation.run_multiple_datasets(N=N, n=n)

# %%
simulation = simulation_geometric_median(optimizer_list=optimizer_list_riccati)
simulation.run_multiple_datasets(N=N, n=n)

# %%
simulation = simulation_spherical_distribution(optimizer_list=optimizer_list)
simulation.run_multiple_datasets(N=N, n=n)

# %%
simulation = simulation_p_means(optimizer_list=optimizer_list)
simulation.run_multiple_datasets(N=N, n=n)

# %%
eval = eval_covtype(optimizer_list=optimizer_list_riccati)
_, _ = eval.run()
# Out:
# <style type="text/css">
# #T_71224_row0_col2, #T_71224_row1_col2 {
#   font-weight: bold;
# }
# </style>
# <table id="T_71224">
#   <caption>Accuracy on covtype dataset</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_71224_level0_col0" class="col_heading level0 col0" >SNARiccati ν=0.45</th>
#       <th id="T_71224_level0_col1" class="col_heading level0 col1" >SNARiccati ν=0.5</th>
#       <th id="T_71224_level0_col2" class="col_heading level0 col2" >SNARiccati ν=0.66</th>
#       <th id="T_71224_level0_col3" class="col_heading level0 col3" >SNARiccati ν=0.75</th>
#       <th id="T_71224_level0_col4" class="col_heading level0 col4" >SNARiccati ν=1.0</th>
#       <th id="T_71224_level0_col5" class="col_heading level0 col5" >SNARiccati ν=1.05</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_71224_level0_row0" class="row_heading level0 row0" >Training Accuracy</th>
#       <td id="T_71224_row0_col0" class="data row0 col0" >70.750000</td>
#       <td id="T_71224_row0_col1" class="data row0 col1" >67.930000</td>
#       <td id="T_71224_row0_col2" class="data row0 col2" >77.130000</td>
#       <td id="T_71224_row0_col3" class="data row0 col3" >77.070000</td>
#       <td id="T_71224_row0_col4" class="data row0 col4" >76.520000</td>
#       <td id="T_71224_row0_col5" class="data row0 col5" >76.460000</td>
#     </tr>
#     <tr>
#       <th id="T_71224_level0_row1" class="row_heading level0 row1" >Test Accuracy</th>
#       <td id="T_71224_row1_col0" class="data row1 col0" >70.670000</td>
#       <td id="T_71224_row1_col1" class="data row1 col1" >68.360000</td>
#       <td id="T_71224_row1_col2" class="data row1 col2" >77.310000</td>
#       <td id="T_71224_row1_col3" class="data row1 col3" >77.220000</td>
#       <td id="T_71224_row1_col4" class="data row1 col4" >76.650000</td>
#       <td id="T_71224_row1_col5" class="data row1 col5" >76.600000</td>
#     </tr>
#   </tbody>
# </table>
