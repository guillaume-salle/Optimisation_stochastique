# %%
import sys
sys.path.append('..')

# %%
from config_simulation import (
    algo,
    simulation_linear_regression,
    simulation_logistic_regression,
    simulation_geometric_median,
    simulation_spherical_distribution,
    simulation_p_means,
    eval_covtype,
    N,
    n,
)

optimizer_list = [
    algo.UWASNA(c_nu=5.0, algo='article', generate_Z="normal"),
    algo.UWASNA(c_nu=5.0, algo='article'),
    algo.UWASNA(c_nu=5.0, algo='article v2', generate_Z="normal"),
    algo.UWASNA(c_nu=5.0, algo='article v2'),
    algo.UWASNA(c_nu=5.0, algo='right'), 
    algo.UWASNA(c_nu=5.0, algo='rapport'), 
    algo.UWASNA(c_nu=5.0, algo='proj'), 
]

import copy
optimizer_list_without_riccati = copy.deepcopy(optimizer_list)

# %%
# N = 2
# n = 1000

# %%
simulation = simulation_linear_regression(optimizer_list=optimizer_list)
simulation.run_multiple_track_errors(N=N, n=n)

# %%
simulation.run_multiple_track_time(N=N, n=n)

# %%
simulation = simulation_logistic_regression(optimizer_list=optimizer_list)
simulation.run_multiple_track_errors(N=N, n=n)

# %%
simulation.run_multiple_track_time(N=N, n=n)

# %%
simulation = simulation_geometric_median(optimizer_list=optimizer_list)
simulation.run_multiple_track_errors(N=20, n=n)

# %%
simulation.run_multiple_track_time(N=N, n=n)

# %%
simulation = simulation_spherical_distribution(
    optimizer_list=optimizer_list_without_riccati
)
simulation.run_multiple_track_errors(N=N, n=n)

# %%
simulation.run_multiple_track_time(N=N, n=n)

# %%
simulation = simulation_p_means(optimizer_list=optimizer_list_without_riccati)
simulation.run_multiple_track_errors(N=N, n=n)

# %%
simulation.run_multiple_track_time(N=N, n=n)

# %%
eval = eval_covtype(optimizer_list=optimizer_list)
_, _ = eval.run_track_time()
# Out:
# Optimizers:   0%|          | 0/7 [00:00<?, ?it/s]
# Data:   0%|          | 0/464809 [00:00<?, ?it/s]
# <style type="text/css">
# #T_1b17f_row0_col6, #T_1b17f_row1_col0, #T_1b17f_row2_col0 {
#   font-weight: bold;
# }
# </style>
# <table id="T_1b17f">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_1b17f_level0_col0" class="col_heading level0 col0" >UWASNA α=0.75 γ=0.75 Z~normal article</th>
#       <th id="T_1b17f_level0_col1" class="col_heading level0 col1" >UWASNA α=0.75 γ=0.75 article</th>
#       <th id="T_1b17f_level0_col2" class="col_heading level0 col2" >UWASNA α=0.75 γ=0.75 Z~normal article v2</th>
#       <th id="T_1b17f_level0_col3" class="col_heading level0 col3" >UWASNA α=0.75 γ=0.75 article v2</th>
#       <th id="T_1b17f_level0_col4" class="col_heading level0 col4" >UWASNA α=0.75 γ=0.75 right</th>
#       <th id="T_1b17f_level0_col5" class="col_heading level0 col5" >UWASNA α=0.75 γ=0.75</th>
#       <th id="T_1b17f_level0_col6" class="col_heading level0 col6" >UWASNA α=0.75 γ=0.75 proj</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_1b17f_level0_row0" class="row_heading level0 row0" >Execution Time</th>
#       <td id="T_1b17f_row0_col0" class="data row0 col0" >24.295831</td>
#       <td id="T_1b17f_row0_col1" class="data row0 col1" >22.818219</td>
#       <td id="T_1b17f_row0_col2" class="data row0 col2" >25.484142</td>
#       <td id="T_1b17f_row0_col3" class="data row0 col3" >23.713490</td>
#       <td id="T_1b17f_row0_col4" class="data row0 col4" >25.492923</td>
#       <td id="T_1b17f_row0_col5" class="data row0 col5" >23.752920</td>
#       <td id="T_1b17f_row0_col6" class="data row0 col6" >21.626589</td>
#     </tr>
#     <tr>
#       <th id="T_1b17f_level0_row1" class="row_heading level0 row1" >Training Accuracy</th>
#       <td id="T_1b17f_row1_col0" class="data row1 col0" >0.726692</td>
#       <td id="T_1b17f_row1_col1" class="data row1 col1" >0.725924</td>
#       <td id="T_1b17f_row1_col2" class="data row1 col2" >0.726365</td>
#       <td id="T_1b17f_row1_col3" class="data row1 col3" >0.726146</td>
#       <td id="T_1b17f_row1_col4" class="data row1 col4" >0.726186</td>
#       <td id="T_1b17f_row1_col5" class="data row1 col5" >0.726100</td>
#       <td id="T_1b17f_row1_col6" class="data row1 col6" >0.725272</td>
#     </tr>
#     <tr>
#       <th id="T_1b17f_level0_row2" class="row_heading level0 row2" >Test Accuracy</th>
#       <td id="T_1b17f_row2_col0" class="data row2 col0" >0.729749</td>
#       <td id="T_1b17f_row2_col1" class="data row2 col1" >0.728664</td>
#       <td id="T_1b17f_row2_col2" class="data row2 col2" >0.729241</td>
#       <td id="T_1b17f_row2_col3" class="data row2 col3" >0.729035</td>
#       <td id="T_1b17f_row2_col4" class="data row2 col4" >0.729078</td>
#       <td id="T_1b17f_row2_col5" class="data row2 col5" >0.728837</td>
#       <td id="T_1b17f_row2_col6" class="data row2 col6" >0.728097</td>
#     </tr>
#   </tbody>
# </table>
