# %%
import sys
sys.path.append('..')

# %%
from config_simulation import (
    algorithms,
    simulation_linear_regression,
    simulation_logistic_regression,
    simulation_geometric_median,
    simulation_spherical_distribution,
    simulation_p_means,
    eval_covtype,
    N,
    n,
)

SGD = algorithms.SGD
WASGD = algorithms.WASGD
SNARiccati = algorithms.SNARiccati
WASNARiccati = algorithms.WASNARiccati
USNA = algorithms.USNA
UWASNA = algorithms.UWASNA
SNA = algorithms.SNA
WASNA = algorithms.WASNA


optimizer_list = [
    UWASNA(c_nu = 5.0),
    UWASNA(c_nu = 5.0, compute_hessian_theta_avg=False),
    UWASNA(c_nu = 5.0, use_hessian_avg=False),
    UWASNA(c_nu = 5.0, compute_hessian_theta_avg=False, use_hessian_avg=False),
    UWASNA(c_nu = 5.0, generate_Z="normal"),
    UWASNA(c_nu = 5.0, sym=False),
    UWASNA(c_nu = 5.0, compute_hessian_theta_avg=False, use_hessian_avg=False, sym=False),
]

import copy
optimizer_list_without_riccati = copy.deepcopy(optimizer_list)

# %%
# N = 2
# n = 1000

# %%
simulation = simulation_linear_regression(optimizer_list=optimizer_list)
simulation.run_multiple_track_errors(N=N, n=n)

# %%
simulation.run_multiple_track_time(N=N, n=n)

# %%
simulation = simulation_logistic_regression(optimizer_list=optimizer_list)
simulation.run_multiple_track_errors(N=N, n=n)

# %%
simulation.run_multiple_track_time(N=N, n=n)

# %%
simulation = simulation_geometric_median(optimizer_list=optimizer_list)
simulation.run_multiple_track_errors(N=20, n=n)

# %%
simulation.run_multiple_track_time(N=N, n=n)

# %%
simulation = simulation_spherical_distribution(
    optimizer_list=optimizer_list_without_riccati
)
simulation.run_multiple_track_errors(N=N, n=n)

# %%
simulation.run_multiple_track_time(N=N, n=n)

# %%
simulation = simulation_p_means(optimizer_list=optimizer_list_without_riccati)
simulation.run_multiple_track_errors(N=N, n=n)

# %%
simulation.run_multiple_track_time(N=N, n=n)

# %%
eval = eval_covtype(optimizer_list=optimizer_list)
_, _ = eval.run_track_time()
# Out:
# Optimizers:   0%|          | 0/7 [00:00<?, ?it/s]
# Data:   0%|          | 0/464809 [00:00<?, ?it/s]
# <style type="text/css">
# #T_aad75_row0_col6, #T_aad75_row1_col3, #T_aad75_row2_col3 {
#   font-weight: bold;
# }
# </style>
# <table id="T_aad75">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_aad75_level0_col0" class="col_heading level0 col0" >UWASNA ν=0.75 γ=0.75</th>
#       <th id="T_aad75_level0_col1" class="col_heading level0 col1" >UWASNA ν=0.75 γ=0.75 NAT</th>
#       <th id="T_aad75_level0_col2" class="col_heading level0 col2" >UWASNA ν=0.75 γ=0.75 NAH</th>
#       <th id="T_aad75_level0_col3" class="col_heading level0 col3" >UWASNA ν=0.75 γ=0.75 NAT NAH</th>
#       <th id="T_aad75_level0_col4" class="col_heading level0 col4" >UWASNA ν=0.75 γ=0.75 Z~normal</th>
#       <th id="T_aad75_level0_col5" class="col_heading level0 col5" >UWASNA ν=0.75 γ=0.75 NS</th>
#       <th id="T_aad75_level0_col6" class="col_heading level0 col6" >UWASNA ν=0.75 γ=0.75 NAT NAH NS</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_aad75_level0_row0" class="row_heading level0 row0" >Execution Time</th>
#       <td id="T_aad75_row0_col0" class="data row0 col0" >17.880953</td>
#       <td id="T_aad75_row0_col1" class="data row0 col1" >15.512980</td>
#       <td id="T_aad75_row0_col2" class="data row0 col2" >15.084279</td>
#       <td id="T_aad75_row0_col3" class="data row0 col3" >12.770018</td>
#       <td id="T_aad75_row0_col4" class="data row0 col4" >23.070292</td>
#       <td id="T_aad75_row0_col5" class="data row0 col5" >17.088088</td>
#       <td id="T_aad75_row0_col6" class="data row0 col6" >12.312978</td>
#     </tr>
#     <tr>
#       <th id="T_aad75_level0_row1" class="row_heading level0 row1" >Training Accuracy</th>
#       <td id="T_aad75_row1_col0" class="data row1 col0" >0.727832</td>
#       <td id="T_aad75_row1_col1" class="data row1 col1" >0.725567</td>
#       <td id="T_aad75_row1_col2" class="data row1 col2" >0.726062</td>
#       <td id="T_aad75_row1_col3" class="data row1 col3" >0.728278</td>
#       <td id="T_aad75_row1_col4" class="data row1 col4" >0.726746</td>
#       <td id="T_aad75_row1_col5" class="data row1 col5" >0.725063</td>
#       <td id="T_aad75_row1_col6" class="data row1 col6" >0.727989</td>
#     </tr>
#     <tr>
#       <th id="T_aad75_level0_row2" class="row_heading level0 row2" >Test Accuracy</th>
#       <td id="T_aad75_row2_col0" class="data row2 col0" >0.731014</td>
#       <td id="T_aad75_row2_col1" class="data row2 col1" >0.728484</td>
#       <td id="T_aad75_row2_col2" class="data row2 col2" >0.728871</td>
#       <td id="T_aad75_row2_col3" class="data row2 col3" >0.731306</td>
#       <td id="T_aad75_row2_col4" class="data row2 col4" >0.729637</td>
#       <td id="T_aad75_row2_col5" class="data row2 col5" >0.727486</td>
#       <td id="T_aad75_row2_col6" class="data row2 col6" >0.730971</td>
#     </tr>
#   </tbody>
# </table>
