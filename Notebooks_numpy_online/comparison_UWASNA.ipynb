# %%
import sys
sys.path.append('..')

# %%
from config_simulation import (
    algorithms,
    simulation_linear_regression,
    simulation_logistic_regression,
    simulation_geometric_median,
    simulation_spherical_distribution,
    simulation_p_means,
    eval_covtype,
)

SGD = algorithms.SGD
WASGD = algorithms.WASGD
SNARiccati = algorithms.SNARiccati
WASNARiccati = algorithms.WASNARiccati
USNA = algorithms.USNA
UWASNA = algorithms.UWASNA
SNA = algorithms.SNA
WASNA = algorithms.WASNA


N = 20
n = 10_000

optimizer_list = [
    UWASNA(c_nu = 5.0),
    UWASNA(c_nu = 5.0, compute_hessian_theta_avg=False),
    UWASNA(c_nu = 5.0, use_hessian_avg=False),
    UWASNA(c_nu = 5.0, compute_hessian_theta_avg=False, use_hessian_avg=False),
    UWASNA(c_nu = 5.0, generate_Z="normal"),
    UWASNA(c_nu = 5.0, sym=False),
    UWASNA(c_nu = 5.0, compute_hessian_theta_avg=False, use_hessian_avg=False, sym=False),
]

import copy
optimizer_list_without_riccati = copy.deepcopy(optimizer_list)

# %%
# N = 2
# n = 1000

# %%
simulation = simulation_linear_regression(optimizer_list=optimizer_list)
simulation.run_multiple_track_errors(N=N, n=n)

# %%
simulation.run_multiple_track_time(N=N, n=n)

# %%
simulation = simulation_logistic_regression(optimizer_list=optimizer_list)
simulation.run_multiple_track_errors(N=N, n=n)

# %%
simulation.run_multiple_track_time(N=N, n=n)

# %%
simulation = simulation_geometric_median(optimizer_list=optimizer_list)
simulation.run_multiple_track_errors(N=20, n=n)

# %%
simulation.run_multiple_track_time(N=N, n=n)

# %%
simulation = simulation_spherical_distribution(
    optimizer_list=optimizer_list_without_riccati
)
simulation.run_multiple_track_errors(N=N, n=n)

# %%
simulation.run_multiple_track_time(N=N, n=n)

# %%
simulation = simulation_p_means(optimizer_list=optimizer_list_without_riccati)
simulation.run_multiple_track_errors(N=N, n=n)

# %%
simulation.run_multiple_track_time(N=N, n=n)

# %%
eval = eval_covtype(optimizer_list=optimizer_list)
_, _ = eval.run_track_time()
# Out:
# <style type="text/css">
# #T_e8634_row0_col6, #T_e8634_row1_col6 {
#   font-weight: bold;
# }
# </style>
# <table id="T_e8634">
#   <caption>Accuracy on covtype dataset, d=55, batch_size=d^0</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_e8634_level0_col0" class="col_heading level0 col0" >UWASNA ν=0.75 γ=0.75</th>
#       <th id="T_e8634_level0_col1" class="col_heading level0 col1" >UWASNA ν=0.75 γ=0.75 NAT</th>
#       <th id="T_e8634_level0_col2" class="col_heading level0 col2" >UWASNA ν=0.75 γ=0.75 NAH</th>
#       <th id="T_e8634_level0_col3" class="col_heading level0 col3" >UWASNA ν=0.75 γ=0.75 NAT NAH</th>
#       <th id="T_e8634_level0_col4" class="col_heading level0 col4" >UWASNA ν=0.75 γ=0.75 Z~normal</th>
#       <th id="T_e8634_level0_col5" class="col_heading level0 col5" >UWASNA ν=0.75 γ=0.75 NS</th>
#       <th id="T_e8634_level0_col6" class="col_heading level0 col6" >UWASNA ν=0.75 γ=0.75 NAT NAH NS</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_e8634_level0_row0" class="row_heading level0 row0" >Training Accuracy</th>
#       <td id="T_e8634_row0_col0" class="data row0 col0" >0.726006</td>
#       <td id="T_e8634_row0_col1" class="data row0 col1" >0.726406</td>
#       <td id="T_e8634_row0_col2" class="data row0 col2" >0.726350</td>
#       <td id="T_e8634_row0_col3" class="data row0 col3" >0.726720</td>
#       <td id="T_e8634_row0_col4" class="data row0 col4" >0.726744</td>
#       <td id="T_e8634_row0_col5" class="data row0 col5" >0.726589</td>
#       <td id="T_e8634_row0_col6" class="data row0 col6" >0.727353</td>
#     </tr>
#     <tr>
#       <th id="T_e8634_level0_row1" class="row_heading level0 row1" >Test Accuracy</th>
#       <td id="T_e8634_row1_col0" class="data row1 col0" >0.729043</td>
#       <td id="T_e8634_row1_col1" class="data row1 col1" >0.729215</td>
#       <td id="T_e8634_row1_col2" class="data row1 col2" >0.729207</td>
#       <td id="T_e8634_row1_col3" class="data row1 col3" >0.729542</td>
#       <td id="T_e8634_row1_col4" class="data row1 col4" >0.729775</td>
#       <td id="T_e8634_row1_col5" class="data row1 col5" >0.729275</td>
#       <td id="T_e8634_row1_col6" class="data row1 col6" >0.730153</td>
#     </tr>
#   </tbody>
# </table>
