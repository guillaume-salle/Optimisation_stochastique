# %%
from config_simulation import (
    simulation_linear_regression,
    simulation_logistic_regression,
    simulation_geometric_median,
    simulation_spherical_distribution,
    simulation_p_means,
    eval_covtype,
    n,
    N,
    nu_list,
    gamma_list,
)
from optimization_algorithms import WASGD


optimizer_class = WASGD
optimizer_list = [optimizer_class(nu=nu) for nu in nu_list]

# %%
simulation = simulation_linear_regression(optimizer_list=optimizer_list)
simulation.run_multiple_datasets(N=N, n=n)

# %%
simulation = simulation_logistic_regression(optimizer_list=optimizer_list)
simulation.run_multiple_datasets(N=N, n=n)

# %%
simulation = simulation_geometric_median(optimizer_list=optimizer_list)
simulation.run_multiple_datasets(N=N, n=n)

# %%
simulation = simulation_spherical_distribution(optimizer_list=optimizer_list)
simulation.run_multiple_datasets(N=N, n=n)

# %%
simulation = simulation_p_means(optimizer_list=optimizer_list)
simulation.run_multiple_datasets(N=N, n=n)

# %%
eval = eval_covtype(optimizer_list=optimizer_list)
_, _ = eval.run()
# Out:
# Optimizers:   0%|          | 0/6 [00:00<?, ?it/s]
# Data:   0%|          | 0/464809 [00:00<?, ?it/s]
# <style type="text/css">
# #T_32949_row0_col3, #T_32949_row1_col3 {
#   font-weight: bold;
# }
# </style>
# <table id="T_32949">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_32949_level0_col0" class="col_heading level0 col0" >WASGD ν=0.45</th>
#       <th id="T_32949_level0_col1" class="col_heading level0 col1" >WASGD ν=0.5</th>
#       <th id="T_32949_level0_col2" class="col_heading level0 col2" >WASGD ν=0.66</th>
#       <th id="T_32949_level0_col3" class="col_heading level0 col3" >WASGD ν=0.75</th>
#       <th id="T_32949_level0_col4" class="col_heading level0 col4" >WASGD</th>
#       <th id="T_32949_level0_col5" class="col_heading level0 col5" >WASGD ν=1.05</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_32949_level0_row0" class="row_heading level0 row0" >Training Accuracy</th>
#       <td id="T_32949_row0_col0" class="data row0 col0" >72.610000</td>
#       <td id="T_32949_row0_col1" class="data row0 col1" >72.710000</td>
#       <td id="T_32949_row0_col2" class="data row0 col2" >72.880000</td>
#       <td id="T_32949_row0_col3" class="data row0 col3" >72.900000</td>
#       <td id="T_32949_row0_col4" class="data row0 col4" >72.380000</td>
#       <td id="T_32949_row0_col5" class="data row0 col5" >72.290000</td>
#     </tr>
#     <tr>
#       <th id="T_32949_level0_row1" class="row_heading level0 row1" >Test Accuracy</th>
#       <td id="T_32949_row1_col0" class="data row1 col0" >72.780000</td>
#       <td id="T_32949_row1_col1" class="data row1 col1" >72.880000</td>
#       <td id="T_32949_row1_col2" class="data row1 col2" >73.140000</td>
#       <td id="T_32949_row1_col3" class="data row1 col3" >73.230000</td>
#       <td id="T_32949_row1_col4" class="data row1 col4" >72.620000</td>
#       <td id="T_32949_row1_col5" class="data row1 col5" >72.550000</td>
#     </tr>
#   </tbody>
# </table>
