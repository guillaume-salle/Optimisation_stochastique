# %%
import numpy as np
from functools import partial

from simulation import Simulation
from objective_functions import LogisticRegression, LinearRegression
from optimization_algorithms import SNA
from datasets import generate_logistic_regression, generate_linear_regression

# %%
N = 10  # number of runs for averaging the results
n = int(1e5)
objective_function = LogisticRegression(bias=True)
true_theta = np.array([0, 3, -9, 4, -9, 15, 0, -7, 1, 0])
# true_theta = np.array([-2., -1., 0., 1., 2.])  # cf slides, and set bi

optimizer_class = SNA
mu_list = [0.45, 0.5, 0.66, 0.75, 1.0, 1.05]
optimizer_list = [optimizer_class(mu=mu) for mu in mu_list]

e = 1

simulation = Simulation(
    objective_function,
    optimizer_list,
    e,
    true_theta=true_theta,
    generate_dataset=partial(generate_logistic_regression, bias=True),
)

# %%
# One run
simulation.dataset = simulation.generate_dataset(n, true_theta)
simulation.generate_initial_theta()
err, _ = simulation.run(plot=True)
# Out:
# Optimizers:   0%|          | 0/6 [00:00<?, ?it/s]
# Data:   0%|          | 0/100000 [00:00<?, ?it/s]

# %%
simulation.run_multiple_datasets(num_runs=N, n=n)
# Out:
# Runs:   0%|          | 0/10 [00:00<?, ?it/s]
# Optimizers:   0%|          | 0/6 [00:00<?, ?it/s]
# Data:   0%|          | 0/100000 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 simulation.run_multiple_datasets(num_runs=N, n=n)
#
# File ~/stochastic_optimization/simulation/simulation.py:165, in Simulation.run_multiple_datasets(self, num_runs, n)
#     163 first_X, _ = self.dataset[0]
#     164 self.generate_initial_theta()
# --> 165 theta_errors, hessian_inv_errors = self.run([optimizer_pbar, data_pbar])
#     167 # Aggregate the errors
#     168 for name, errors in theta_errors.items():
#
# File ~/stochastic_optimization/simulation/simulation.py:114, in Simulation.run(self, pbars, plot)
#     112 data_pbar.reset()
#     113 for X, Y in self.dataset:
# --> 114     optimizer.step(X, Y, self.theta, self.g)
#     115     self.log_estimation_error(theta_errors, hessian_inv_errors, optimizer)
#     116     data_pbar.update(1)
#
# File ~/stochastic_optimization/optimization_algorithms/SNA.py:45, in SNA.step(self, X, Y, theta_estimate, g)
#      41 """
#      42 Perform one optimization step
#      43 """
#      44 self.iter += 1
# ---> 45 grad, hessian = g.grad_and_hessian(X, Y, theta_estimate)
#      46 self.hessian_bar += hessian
#      47 try:
#
# File ~/stochastic_optimization/objective_functions/LogisticRegression.py:66, in LogisticRegression.grad_and_hessian(self, X, Y, h)
#      52 """
#      53 Compute the gradient and the Hessian of the logistic loss
#      54 Does not work for a batch of data because of the outer product
#      55 """
#      56 # For batch data, should work
#      57 # n, d = X.shape
#      58 # phi = np.hstack([np.ones(n, 1), X]) if self.bias else X
#    (...)
#      64
#      65 # For a single data point
# ---> 66 phi = np.hstack([np.ones((1,)), X]) if self.bias else X
#      67 dot_product = np.dot(phi, h)
#      68 p = sigmoid(dot_product)
#
# File ~/AppImage/anaconda3/envs/env/lib/python3.12/site-packages/numpy/core/numeric.py:192, in ones(shape, dtype, order, like)
#     189     return _ones_with_like(like, shape, dtype=dtype, order=order)
#     191 a = empty(shape, dtype, order)
# --> 192 multiarray.copyto(a, 1, casting='unsafe')
#     193 return a
#
# KeyboardInterrupt:

# %%
objective_function = LinearRegression(bias=False)
simulation = Simulation(
    objective_function,
    optimizer_list,
    e,
    true_theta=true_theta,
    generate_dataset=partial(generate_linear_regression, bias=False),
)

# %%
# One run
simulation.dataset = simulation.generate_dataset(n, true_theta)
simulation.generate_initial_theta()
_, _ = simulation.run(plot=True)
# Out:
# Optimizers:   0%|          | 0/6 [00:00<?, ?it/s]
# Data:   0%|          | 0/100000 [00:00<?, ?it/s]

# %%
simulation.run_multiple_datasets(num_runs=N, n=n)
# Out:
# Runs:   0%|          | 0/10 [00:00<?, ?it/s]
# Optimizers:   0%|          | 0/6 [00:00<?, ?it/s]
# Data:   0%|          | 0/100000 [00:00<?, ?it/s]
